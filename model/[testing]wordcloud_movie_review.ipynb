# %%
import nltk
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from wordcloud import WordCloud, STOPWORDS
import numpy as np
from PIL import Image

# %%
from konlpy.corpus import kobill
files_ko = kobill.fileids()
doc_ko = kobill.open('ratings_test.txt').read()

# %%
from konlpy.tag import Okt
t = Okt()
tokens_ko = t.nouns(doc_ko)

# %%
ko = nltk.Text(tokens_ko, name='네이버 영화 리뷰')

# %%
print(len(ko.tokens))           # returns number of tokens (document length)
print(len(set(ko.tokens)))   # returns number of unique tokens
ko.vocab()                        # returns frequency distribution
# Out:
# 300478
# 23041
# FreqDist({'영화': 17302, '정말': 3198, '진짜': 2936, '이': 2731, '점': 2646, '평점': 2226, '연기': 2197, '것': 2141, '최고': 2014, '생각': 1824, ...})

# %%
plt.figure(figsize=(15,8))
ko.plot(50) # Plot sorted frequency of top 50 tokens
plt.show()

# %%
stop_words = ['.', '(', ')', ',', "'", '%', '-', 'X', ').', '×','이','점','왜','때','더',
              '내','말','거','그','좀','뭐','수','볼','나','걸','의','자','에','안','번',
              '호','을','이','다','만','로','가','를','것','듯','중']

ko = [each_word for each_word in ko if each_word not in stop_words]

# %%
ko = nltk.Text(ko, name='네이버 영화 리뷰')
plt.figure(figsize=(15,8))
ko.plot(50)     # Plot sorted frequency of top 50 tokens
plt.show()

# %%
plt.figure(figsize=(15,8))
ko.dispersion_plot(['영화', '주인공', '개'])

# %%
ko.concordance('주인공')
# Out:
# Displaying 25 of 802 matches:
#  시간 몇번 볼때 후 속편 드 결말 한번 본적 업 성경 의인 지혜롭 주인공 남자 컴플렉스 엉망 직장 해고 부인 거부 모든 터전 불륜 아이 놈
# 화 빛 발 감동 영화 라스트 장면 이불 기억 꼭 다시 보고 파일 두 주인공 관계 로맨스 요술 마법 뭘 헤라클레스 인물 묘사 저따위 기리 죠 배
#  나름 최선 다해 한하유 마음 연애 더빙 참고 이건 진짜 정신 여자 주인공 스토리 완전 어거지 뭔가 스토리 영화 하나 사람 돈 걱정 제로 비현
# 실적 세상 설정 책 먼저 접 폭풍 언덕 살 사랑 밀도 알 서브 보이 주인공 영화 벤자민 지지 지지 여주 편 짜임새 개인 로버트 쇼 눈독 평점
# 스트 너 클린트 이스트 우드 감독 존경 일 시간 준 지혜 전달 영화 주인공 꽤 얼굴 진짜 포스터 가끔 주연 액스멘 부활 대한민국 해군 혐오 최
# 최대 다수 행복 젊은이 목숨 가족 슬픔 중하 때문 손바닥 하늘 하늘 주인공 마지막 거인 아오이 유우 앞 았 느낌 이영화 보고 개 나소 누구 영
# 구 관객 우롱 천하 슈렉 속편 거듭 힘 주군의태양 파스타 내용 여자 주인공 이이해 가안 남자 여자 사람 여자 양심 때문 죽음 평점 시대 앞서
#  배우 연기 오지 시나리오작가 상 감독 무슨 이야기 복선 장치 목잡 주인공 감정 과잉 실소 머금 다른 드라마 왜케 이건 킬링 임용 오빠 더멋
#  수박 겉 식 영화 누구 그레이스 켈리 대한 영화 왕비 여배우 로서 주인공 갈등 모나코 프랑스 간의 문제 사이 중심 잡지 못 채 진행 개 쩐다
# 못 채 진행 개 쩐다 감동 영화 간만 영화 원 스릴러 감동 영화 굿 주인공 하나 하나 알 장면 주인공 시점 관점 하나 마다 장면 정말 기분 소
# 영화 간만 영화 원 스릴러 감동 영화 굿 주인공 하나 하나 알 장면 주인공 시점 관점 하나 마다 장면 정말 기분 소름 소설 정말 명작 후속작
# ...

# %%
data = ko.vocab().most_common(150)

wordcloud = WordCloud(font_path='c:/Windows/Fonts/NanumGothic.ttf',
                      relative_scaling = 0.2,
                      background_color='white',
                      ).generate_from_frequencies(dict(data))
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
