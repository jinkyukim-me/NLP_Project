# %%
from text import gettext,summarytext,wordcloud
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\jungs\Anaconda3\envs\py36\lib\site-packages\tensorflow\python\util\deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead

# %%
data_path = 'E:\\NLP_Project\\model\\data.txt\\data1.txt'
book_mask_path = './1.png'
font_path = 'E:\\NLP_Project\\model\\font\\KBLZ.ttf'

# %%
gettext.get_texts(data_path)
texts = gettext.get_texts(data_path)
summarytext.summary_text(texts)
wordcloud.wordcloud(data_path,book_mask_path,font_path)
# Out:
# 나는 네가 너무 좋아서 너를 대하기가 어렵고 힘들었다
# ['나는', '네가', '마음', '너를', '내가', '너의', '좋아', '너는', '않았', '생각']
