# %%
import difflib
import numpy as np
import krwordrank
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter
from konlpy.tag import Okt
from PIL import Image
from pykospacing import spacing
import krwordrank
from krwordrank.sentence import summarize_with_sentences
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\jungs\Anaconda3\envs\py36\lib\site-packages\tensorflow\python\util\deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead

# %% [markdown]
# 데이터 전처리(엔터를 기준으로 한 문장으로 인식)

# %%
okt = Okt()
noun = []
sent = []
for i in range(1,188):
    data_path = 'E:\\news\\news\\뉴스전체\\뉴스_'+str(i)+'.txt'
    def get_texts(data_path):
        file = open(data_path, 'r',encoding='UTF-8')
        data =file.readlines()
        data_list = []
        for sentence in data:
            list_sentence1 = sentence.replace('\n','').split('\n')
            for list_sentence2 in list_sentence1:
                list_sentence = list_sentence2.replace('다.','다.  .').split('  .')
                for lines in list_sentence:
                    line = lines.strip()
                    data_list.append(line)
        texts = list(set(data_list))
        if '' in texts:
            texts.remove('')
        return texts
    texts = get_texts(data_path)
    penalty = lambda x:0 if (25 <= len(x) <= 120) else 1
    keywords, sents = summarize_with_sentences(
        texts,
        penalty=penalty,
        stopwords={},
        diversity=0.5,
        num_keywords=8,
        num_keysents=2,
        scaling=lambda x:1,
        verbose=False,
        min_count = 1)
    ex_a = ""
    for s in sents:
        ex_a += s
    sent.append(ex_a)
    ex_n = okt.nouns(ex_a)
    ex_n.sort()
    noun.append(ex_n)
# Out:
# C:\Users\jungs\Anaconda3\envs\py36\lib\site-packages\jpype\_core.py:210: UserWarning:
# -------------------------------------------------------------------------------
# Deprecated: convertStrings was not specified when starting the JVM. The default
# behavior in JPype will be False starting in JPype 0.8. The recommended setting
# for new code is convertStrings=False.  The legacy value of True was assumed for
# this session. If you are a user of an application that reported this warning,
# please file a ticket with the developer.
# -------------------------------------------------------------------------------
#
#   """)

# %%
sent_before = []
noun_before = []
for j in range(1,188):
    data_path1 = 'E:\\news\\news\\요약전체\\요약_'+str(j)+'.txt'
    def get_texts1(data_path):
        file = open(data_path, 'r',encoding='UTF-8')
        data =file.read()
        return data
    data = get_texts1(data_path1)
    ex_aa = ""
    ex_aa = data.replace("\n",'')
    sent_before.append(ex_aa)
    ex_bb = okt.nouns(ex_aa)
    ex_bb.sort()
    noun_before.append(ex_bb)

# %%
n=1
a=0
a1=0
for  i in range(0,187):
    print(sent[i])
    print(sent_before[i])
    s = difflib.SequenceMatcher(lambda x: x == " ", sent[i], sent_before[i])
    result = round(s.ratio(), 4)
    s1 = difflib.SequenceMatcher(lambda x: x == " ", noun[i], noun_before[i])
    result1 = round(s1.ratio(), 4)
    print("문장 정확도는 {:0.2f}%         number:".format(result*100)+str(n))
    print("형태소 정확도는 {:0.2f}%         number:".format(result1*100)+str(n))
    a = a+result
    b = (a*100)/n
    print("문장 최종 정확도는"+"%0.2f"%b+"%         number:"+str(n))
    a1 = a1+result1
    b1 = (a1*100)/n
    print("형태소 최종 정확도는"+"%0.2f"%b1+"%         number:"+str(n))
    n = n+1
# Out:
# 현대차는 5일, 전국 영업점에서 전날부터 사전계약에 들어갔던 더 뉴 그랜저의 첫날 계약 대수가 1만 7,294대로 나타났다고 밝혔다.이러한 기록은 지난 2016년 11월 출시한 6세대 그랜저가 갖고 있던 역대 최다 첫날 사전계약 대수 15,973대를 1,000대 이상 초과한 것이다.
# 현대자동차의 '더 뉴 그랜저'가 사전계약 첫날에만 1만 7,294대의 계약 기록을 세우며 역대 최다 신기록을 세웠다.현대차는 5일, 전국 영업점에서 전날부터 사전계약에 들어갔던 더 뉴 그랜저의 첫날 계약 대수가 1만 7,294대로 나타났다고 밝혔다.
# 문장 정확도는 49.83%         number:1
# 형태소 정확도는 75.47%         number:1
# 문장 최종 정확도는49.83%         number:1
# 형태소 최종 정확도는75.47%         number:1
# 달문은 소설 이토록 고고한 연예의 주인공 '달문'(達文)의 생애를 다뤘다.드라마 '불멸의 이순신'과 영화 '조선명탐정'의 원작자로 잘 알려진 김탁환이 쓴 역사소설 '이토록 고고한 연예'를 토대로 구성진 판소리와 역동적인 영상기법이 더해진 작품이다.
# 서울문화재단이 우리 고유의 국악 콘텐츠인 판소리와 문학, 시각예술을 결합한 웹판소리 '달문, 한없이 좋은 사람'을 새로운 유형의 문화 콘텐츠로 개발해 선보인다.드라마 '불멸의 이순신'과 영화 '조선명탐정'의 원작자로 잘 알려진 김탁환이 쓴 역사소설 '이토록 고고한 연예'를 토대로 구성진 판소리와 역동적인 영상기법이 더해진 작품이다.
# 문장 정확도는 67.90%         number:2
# 형태소 정확도는 66.67%         number:2
# 문장 최종 정확도는58.87%         number:2
# 형태소 최종 정확도는71.07%         number:2
# 지난달 23일 새벽 1시 40분쯤 영국 에식스주의 한 산업단지에서 39구의 시신이 담긴 화물 트럭 컨테이너가 발견됐고,영국 경찰은 희생자들이 모두 베트남 국적으로 추정된다고 밝혔습니다.레 티 투 항 베트남 외교부 대변인도 오늘 새벽 긴급 성명을 내고 "심각한 비극"이라며 "희생자 가족에게 위로의 말을 전한다"고 밝혔습니다.
# 지난달 영국에서 냉동 컨테이너안에 숨진 채 발견된 39명이 모두 베트남 출신으로 추정된다는 현지 경찰의 발표에 베트남이 큰 충격에 빠졌습니다.쩐 응옥 안 영국 주재 베트남 대사는 "영국경찰의 공식 통보를 받고 충격을 받았으며 매우 슬프다"고 말했습니다.
# 문장 정확도는 34.16%         number:3
# 형태소 정확도는 33.80%         number:3
# 문장 최종 정확도는50.63%         number:3
# 형태소 최종 정확도는58.65%         number:3
# ◇피아노 앞의 여자들/버지니아 로이드 지음·정은지 옮김/340쪽·1만6000원·앨리스“나도, 할머니 앨리스도 위기에 대한 대응은 가능성을 여는 것이 아닌, 닫아버리는 것이었다.
# 그러나 소년들보다 더 적은 수의 소녀들이 직업 음악가가 된다.피아노 앞의 소녀들은 어떻게 됐을까?어릴 때 아버지가 데리고 간 재즈 트리오 연주에 매혹됐고, 피아니스트의 꿈을 키웠다.
# 문장 정확도는 16.08%         number:4
# 형태소 정확도는 10.53%         number:4
# 문장 최종 정확도는41.99%         number:4
# 형태소 최종 정확도는46.62%         number:4
# 배춧값이 크게 올라 이른바 ‘김포족(김장을 포기하는 사람들)’이 늘면서 포장김치가 인기를 끌고 있다.CU 측은 “올해 유달리 잦았던 태풍의 영향으로 배추, 열무, 무 등 김장의 주재료 가격이 치솟으면서 김장 부담이 커진 데 맞춰 포장김치 예약 주문 서비스를 업계에서 가장 먼저 시작하게 됐다”고 설명했다.
# 배춧값이 크게 올라 이른바 '김포족'이 늘면서 포장김치가 인기를 끌고 있다.배춧값이 평년의 두 배 가까이 폭등하면서 소비자들은 김장 대신 포장김치를 찾고 있다.이마트에 따르면 배추 가격이 한창 오르던 지난 달 24일까지 포장김치 매출액은 지난 해 같은 기간보다 10.1% 증가했다.
# 문장 정확도는 36.09%         number:5
# 형태소 정확도는 38.36%         number:5
# 문장 최종 정확도는40.81%         number:5
# 형태소 최종 정확도는44.97%         number:5
# 황상훈 동해해경 수색구조계장은 "해군 청해진함에서 포화잠수를 활용해 헬기 동체에 대한 정밀탐색 등 추가 실종자 확인에 나설 것"이라며 "합리적인 방안으로 인양도 실시할 예정"이라고 말했다.실종자는 상의 탈의 상태였으며 검은색 긴바지를 착용하고 있었다.
# 독도 인근 해상에서 추락한 소방헬기의 동체와 꼬리 부분이 약 90m 떨어진 채로 발견됐다.지금까지 동체 내부에서 1명, 꼬리 부분 인근에서 2명의 실종자 시신이 발견됐다.
# 문장 정확도는 15.32%         number:6
# 형태소 정확도는 10.91%         number:6
# 문장 최종 정확도는36.56%         number:6
# 형태소 최종 정확도는39.29%         number:6
# 길이로는 약 0.7cm 정도. 또다른 국내 항공사의 737 NG 균열 역시 비슷한 크기다.세계에서 가장 많이 팔리고, 가장 많이 운항한다는 737-NG기종에서다.
# "항공기에 금이 간다." 상상만 해도 아찔한 일이다.미 연방항공청는 감항지시서를 통해, 이러한 균열이 항공기의 구조적 안정성에 영향을 미쳐 항공기의 통제력을 잃을 수 있다고 경고했다.국내 항공사에서 재직 중인 한 정비전문가는 "갈빗대처럼 항공기의 골격이 있는데 동체와 날개를 연결해 주는 부위"라면서 "현재 균열은 해당 부품을 고정하는 볼트 4개 중에 뒤쪽 한 곳에서 동일하게 발생하고 있다"고 설명했다.
# 문장 정확도는 7.59%         number:7
# 형태소 정확도는 10.00%         number:7
# 문장 최종 정확도는32.42%         number:7
# 형태소 최종 정확도는35.11%         number:7
# "입주 점검 후 전세와 매매가가 10%씩 뛰었어요. 단지 내부와 아파트 평형대가 괜찮게 나와서인지 집주인이 거래 금액을 높이는 추세예요."(인덕원 푸르지오 엘센트로 인근 중개소 관계자)이 단지는 분양 당시(2016년) 최고 32.41대 1의 청약경쟁률로 1순위 당해에 마감될 정도로 인기를 끌었다.
# 다른 동네 집값은 다 오르는데 왜 우리 집만 그대로일까.최근에는 신축 단지 선호 현상과 더불어 인덕원역 개발 소식이 투자 열기를 달구고 있다.단지에서 도보 10분 거리에 있는 서울 지하철 4호선 인덕원역에 '인덕원~동탄복선전철', '월곶~판교 복선전철' 등이 정차하며 개발을 앞두고 있어서다.
# 문장 정확도는 11.55%         number:8
# 형태소 정확도는 8.96%         number:8
# 문장 최종 정확도는29.81%         number:8
# 형태소 최종 정확도는31.84%         number:8
# 한편 삼성전자는 중국 5G(5세대) 이동통신 서비스 시작일인 1일에 맞춰 지난달 18일 유동 인구가 100만 명에 달하는 상하이 최대 번화가 난징둥루에 초대형 플래그십 매장을 열었다.화웨이는 중국 스마트폰 시장에서 높은 점유율을 차지하고 있다.
# 삼성전자가 오는 8일 중국에서 세계 첫 폴더블 스마트폰 '갤럭시 폴드'를 공식 출시한다.2일 삼성 갤럭시 웨이보는 "갤럭시 폴드는 단순한 신제품이 아니고, 우리는 휴대전화의 형태를 바꿨다"면서 제품 출시일을 알렸다.
# 문장 정확도는 14.06%         number:9
# 형태소 정확도는 11.76%         number:9
# 문장 최종 정확도는28.06%         number:9
# 형태소 최종 정확도는29.61%         number:9
# 유 이사장은 이날 노무현재단 전북지역위원회가 창립 8주년을 기념해 전주교육대에서 연 시민학교 대담에서 "검찰이 조국 전 장관의 80대 노모를 소환 조사하고 딸을 기소하겠다고 으름장을 놓는다.유 이사장은 언론개혁에 대해 "정부가 할 수 있는 영역이 아니다.
# 유시민 노무현재단 이사장은 2일 조국 전 법무부 장관 가족에 대한 검찰 수사에 대해 "잔인무도하다"고 밝혔다.유 이사장은 이날 노무현재단 전북지역위원회가 창립 8주년을 기념해 전주교육대에서 연 시민학교 대담에서 "검찰이 조국 전 장관의 80대 노모를 소환 조사하고 딸을 기소하겠다고 으름장을 놓는다.조국 일가족의 혐의점에 비해 무지무지하게 잔인하다"며 이같이 말했다.
# 문장 정확도는 58.79%         number:10
# 형태소 정확도는 70.13%         number:10
# 문장 최종 정확도는31.14%         number:10
# 형태소 최종 정확도는33.66%         number:10
# 조국 전 법무부 장관의 사퇴를 요구해 온 대학생 단체 '공정추진위원회'도 이날 오후 6시부터 광화문역 앞에서 '우리가 원하는 공정한 대한민국' 집회를 개최할 예정이다.또 인터넷 커뮤니티 '루리웹' 회원들로 구성된 '북유게사람들'은 오후 6시부터 서초동 서울중앙지검 부근에서 검찰 개혁, 공수처 설치 등을 요구하는 시민 참여 문화제를 진행한다.
# 11월의 첫 토요일인 2일 광화문 광장에서는 문재인 대통령의 퇴진과 고위공직자범죄수사처 설치 반대를 주장하는 보수 성향 시민단체의 집회가 열렸다.전광훈 목사가 주도하는 대한민국바로세우기국민운동본부는 이날 오후 1시부터 광화문 교보빌딩 앞에서 '문재인 퇴진 국민대회'를 열고 문 대통령의 하야를 요구했다.
# 문장 정확도는 18.89%         number:11
# 형태소 정확도는 18.82%         number:11
# 문장 최종 정확도는30.02%         number:11
# 형태소 최종 정확도는32.31%         number:11
# 이언주 국회의원(무소속, 경기 광명을)은 2일 "북핵을 폐기하고 우리한테 필요한 도움이라면 과거사고 나발이고 무조건 (미국·일본에) 손잡고 도움을 청해야 한다"고 주장했다.연설대에 오른 황영호 위원장은 문재인 대통령을 향해 "조국이라는 희대의 사기꾼·악마같은 놈을 법무부장관으로 임명했다"면서 "미친X 아니냐"고 강한 어조로 비판하기도 했다.
# 이언주 국회의원은 2일 "북핵을 폐기하고 우리한테 필요한 도움이라면 과거사고 나발이고 무조건 손잡고 도움을 청해야 한다"고 주장했다.이 의원은 이날 충북 청주시 상당공원 인근에서 열린 '문재인 정권 규탄 집회'에 참석해 현 정부의 외교정책을 비판하며 이 같이 말했다.
# 문장 정확도는 51.18%         number:12
# 형태소 정확도는 45.33%         number:12
# 문장 최종 정확도는31.79%         number:12
# 형태소 최종 정확도는33.39%         number:12
# 문화재청 궁능유적본부 덕수궁관리소는 오는 8일 낮 12시15분부터 오후 1시까지 서울 덕수궁 돌담길에서 '덕수궁 돌담길 음악회'를 개최한다고 5일 밝혔다.덕수궁을 찾은 관람객 누구나 무료로 감상할 수 있으며 자세한 사항은 덕수궁관리소 누리집에서 확인할 수 있다.
# 문화재청 궁능유적본부 덕수궁관리소는 오는 8일 낮 12시15분부터 오후 1시까지 서울 덕수궁 돌담길에서 '덕수궁 돌담길 음악회'를 개최한다고 5일 밝혔다.문화재청은 지난해 12월 막혀 있던 덕수궁 돌담길 70m 구간의 궁 안쪽에 보행로를 만들어 연결했다.
# 문장 정확도는 64.58%         number:13
# 형태소 정확도는 65.57%         number:13
# 문장 최종 정확도는34.31%         number:13
# 형태소 최종 정확도는35.87%         number:13
# 핼러윈 파티장에서 총격 사건이 발생해 4명이 숨지는 등 미국의 대표적 축제일인 '핼러윈 데이'가 핏빛으로 물들었다.무엇 때문에 총기 폭력이 일어났는지 조사 중"이라고 말했다.
# 핼러윈 파티장에서 총격 사건이 발생해 4명이 숨지는 등 미국의 대표적 축제일인 '핼러윈 데이'가 핏빛으로 물들었다.캘리포니아주 샌프란시스코 베이 지역 인근 부촌의 한 주택에서 지난달 31일 밤 10시 45분쯤 총격 사건이 발생했다.
# 문장 정확도는 63.72%         number:14
# 형태소 정확도는 59.57%         number:14
# 문장 최종 정확도는36.41%         number:14
# 형태소 최종 정확도는37.56%         number:14
# 삼성전자(005930)가 갤럭시 폴드에 이어 ‘클램셸’ 형태의 새로운 폴더블폰을 공개하며 2세대 폼팩터 전쟁의 문을 열었다.이에 더해 삼성전자는 지난달 29일(현지시간) 미국 캘리포니아주 새너제이에서 열린 삼성 개발자 콘퍼런스(SDC) 2019에서 위아래로 여닫는 2세대 폴더블폰을 공개했다.
# 삼성전자가 갤럭시 폴드에 이어 '클램셸' 형태의 새로운 폴더블폰을 공개하며 2세대 폼팩터 전쟁의 문을 열었다.내년 전세계 320만대 규모로 성장한 폴더블폰 시장에서 앞으로 여러 제조사들이 앞다투어 새로운 폼팩터를 출시할 것으로 보인다.
# 문장 정확도는 48.30%         number:15
# 형태소 정확도는 54.24%         number:15
# 문장 최종 정확도는37.20%         number:15
# 형태소 최종 정확도는38.67%         number:15
# 그런데 정말로 정부가 세금 때문에 액상형 전자담배에 대한 강력중단을 권고했을까요. 박능후 장관은 지난달 28일 국회에 출석해 “미국에서 판매되는 액상형 전자담배와 우리나라 것과는 성분 면에서 차이가 좀 있다.액상형 전자담배에 붙는 세금이 다른 담배와 비교해 저렴한 것은 사실입니다.
# 지난달 23일 11시 정부서울청사 브리핑룸에는 긴장감이 감돌았습니다.그런데 정말로 정부가 세금 때문에 액상형 전자담배에 대한 강력중단을 권고했을까요.현재로선 액상형 전자담배에 대한 유해성을 제대로 가늠하기 어려울 정도로 불확실성이 큰 만큼 정부가 국민 생명을 위해 선제 대응에 나섰다는 설명입니다.
# 문장 정확도는 38.39%         number:16
# 형태소 정확도는 39.44%         number:16
# 문장 최종 정확도는37.28%         number:16
# 형태소 최종 정확도는38.72%         number:16
# 블리자드4는 시리즈의 특징을 그대로 이어 받아 어두운 스토리와 강렬한 전투, RPG 방식의 캐릭터 육성, 무한 생성되는 던전, 수많은 아이템 조합 등 '가장 디아블로다운 게임'을 표방했다.디아블로4는 PC, 플레이스테이션4, 엑스박스원으로 출시될 예정이며, 출시시기는 아직 미정이다.
# 블리자드가 자사의 대표작인 '디아블로'와 '오버워치'의 공식 후속작을 전격 공개했다.1일 블리자드 엔터테인먼트는 미국 캘리포니아주 애너하임 컨벤션센터에서 열린 '블리즈컨 2019' 행사에서 액션 롤플레잉 게임 '디아블로4'와 팀 기반 1인칭 슈팅게임 '오버워치2'를 공개했다.
# 문장 정확도는 17.31%         number:17
# 형태소 정확도는 12.70%         number:17
# 문장 최종 정확도는36.10%         number:17
# 형태소 최종 정확도는37.19%         number:17
# 31일 시장조사업체 스트래티지 애널리틱스(SA)에 따르면 삼성전자는 3분기 스마트폰 7820만대를 판매하며 글로벌 점유율 21.3%로 1위를 차지했다.미국 제재에도 거대 내수 시장인 중국을 바짝 조인 화웨이는 삼성전자의 1위 자리를 호시탐탐 넘보고 있다.
# 삼성전자 대 화웨이의 시대가 왔다.지난해 2분기 처음으로 애플을 꺾고 2위로 올라선 화웨이는 삼성전자는 3%P차로 맹추격하고 있기 때문이다.미국 제재에도 거대 내수 시장인 중국을 바짝 조인 화웨이는 삼성전자의 1위 자리를 호시탐탐 넘보고 있다.
# 문장 정확도는 54.68%         number:18
# 형태소 정확도는 53.57%         number:18
# 문장 최종 정확도는37.13%         number:18
# 형태소 최종 정확도는38.10%         number:18
# 국회예산정책처 추산 결과 공무원 17만4000명을 증원하면 향후 30년간 327조7847억원의 인건비(9급 기준·공무원연금 부담액 제외)가 필요하다.2일 인사혁신처에 따르면 정부는 오는 6일 ‘2020년도 국가공무원 공채 시험일정’을 공표할 계획이다.
# 내년도 공무원 채용 시험일정이 다음 주에 발표된다.'현장민생공무원 일자리 연도별 충원계획'에 따라 지방직이 2018~2019년에 각각 1만5000명 가량 증원됐다.지방직이 1만5000명 증원되고 국가직이 정부안대로 통과되면 내년도 전체 공무원 증원 규모는 3만3815명이 된다.
# 문장 정확도는 14.92%         number:19
# 형태소 정확도는 23.33%         number:19
# 문장 최종 정확도는35.97%         number:19
# 형태소 최종 정확도는37.32%         number:19
# 투룸의 경우 6억8000만원 정도예요. 세대분리형 구조가 다른 아파트보다 커요.가벽이 있는 가구도 있고 문으로 통합되는 가구도 있고요. 4932가구 중에 33가구만 이 같은 분리형 가구입니다.
# 작업하시는 분들 작업실로 쓰기도 좋고요.월세라면 보증금 1000만원에 월 100만원 정도라고 하는데, 100만원은 조금 세고 80만~90만원 정도 되는 것 같습니다.아파트니까 조경 좋고, 주차도 하기 쉽고, 오피스텔 원룸에 사는 것보단 훨씬 편하죠.
# 문장 정확도는 11.38%         number:20
# 형태소 정확도는 11.11%         number:20
# 문장 최종 정확도는34.74%         number:20
# 형태소 최종 정확도는36.01%         number:20
# '뉴요커'인 도널드 트럼프 미국 대통령이 세금 문제로 최근 자신의 주소지를 뉴욕에서 플로리다로 옮긴 사실이 알려진 가운데, 트럼프 대통령이 원하는 대로 뉴욕을 떠나기 위해서는 혹독한 회계감사를 받아야 할 전망이다.이 때문에 트럼프 대통령도 2020년 대선 출정식을 지난 6월 18일 플로리다주 올랜도 암웨이센터에서 개최하며 플로리다에 신경을 쓰고 있다.
# '뉴요커'인 도널드 트럼프 미국 대통령이 세금 문제로 최근 자신의 주소지를 뉴욕에서 플로리다로 옮긴 사실이 알려진 가운데, 트럼프 대통령이 원하는 대로 뉴욕을 떠나기 위해서는 혹독한 회계감사를 받아야 할 전망이다.AP통신은 1일 트럼프 대통령이 뉴욕에서 플로리다로 주소지를 옮기기 위해서는 뉴욕주의 회계감사라는 '전투'를 치러야 할 것이라고 보도했다.
# 문장 정확도는 69.21%         number:21
# 형태소 정확도는 70.42%         number:21
# 문장 최종 정확도는36.38%         number:21
# 형태소 최종 정확도는37.65%         number:21
# MBC TV는 다음 달 초 새 파일럿 프로그램 '우리지금만담'을 선보인다.'연애미수'는 매주 토요일 0시 50분 방송하며 네이버 브이라이브와 네이버TV에서 매주 월·화요일 오후 6시에 선공개한다.
# MBC TV는 드라마 '연애미수'가 첫 방송 전부터 일본에 선판매됐다고 5일 밝혔다.청춘 로맨스극인 이 작품에는 손상연, 양혜지, 신윤섭, 조기성 등 신예들이 출연하지만 일본 유통사는 풋풋한 사랑 이야기를 높게 평가했다고 MBC는 전했다.
# 문장 정확도는 19.01%         number:22
# 형태소 정확도는 12.50%         number:22
# 문장 최종 정확도는35.59%         number:22
# 형태소 최종 정확도는36.51%         number:22
# 2일 금융투자업계에 따르면 ㈜두산, 두산중공업, 두산인프라코어, 두산밥캣 등 두산그룹 주요 계열사가 실적이 악화하고 개선이 불확실해지면서 주가가 하락세를 보이고 있다.이들 4사의 3분기 실적은 시장 전망치를 밑도는 어닝 쇼크를 기록했다.
# 두산그룹의 주요 상장 계열사 주가가 실적 악화 우려로 급락세를 보이고 있다.실적 개선이 묘연하며 단기간 주가 회복이 쉽지 않을 전망이다.2일 금융투자업계에 따르면 ㈜두산, 두산중공업, 두산인프라코어, 두산밥캣 등 두산그룹 주요 계열사가 실적이 악화하고 개선이 불확실해지면서 주가가 하락세를 보이고 있다.
# 문장 정확도는 61.79%         number:23
# 형태소 정확도는 62.86%         number:23
# 문장 최종 정확도는36.73%         number:23
# 형태소 최종 정확도는37.65%         number:23
# 기술지원이 종료된 ‘윈도우XP’ 운영체제(OS)와 같은 보안에 취약한 OS를 사용하고 있었다는 점이다.민간은 물론이고 공공기관에서도 상당수의 PC가 윈도우7을 사용하고 있다.
# 2017년 랜섬웨어인 '워너크라이'는 순식간에 전 세계 PC를 강타했다.기술지원이 종료된 '윈도우XP' 운영체제와 같은 보안에 취약한 OS를 사용하고 있었다는 점이다.마이크로소프트 윈도우7의 기술지원 종료가 두 달여 앞으로 다가오면서 '워너크라이'와 같은 사태에 대한 우려가 제기되고 있다.
# 문장 정확도는 49.42%         number:24
# 형태소 정확도는 46.81%         number:24
# 문장 최종 정확도는37.26%         number:24
# 형태소 최종 정확도는38.04%         number:24
# 이어 “저와 소속한 정당은 다르지만, 정의당에서 이자스민 전 의원이 의미 있는 일을 할 수 있길 바라며 변함없이 응원한다”고 부연했다.금 의원은 이주민에 대한 차별과 혐오를 우리 사회가 해결해야 할 가장 중요한 이슈 중 하나로 꼽았다.
# 금태섭 더불어민주당 의원이 자유한국당을 탈당하고 정의당에 입당한 필리핀 출신의 귀화인 이자스민 전 의원을 응원한다고 밝혀 주목을 받았다.금 의원은 이민자를 위한 정책 활동을 펼친 이자스민 의원을 치켜 세우면서 소수자를 품어야 할 진보 정당인 민주당이 이런 가치를 놓친 것이 아쉽다고 밝혔다.금 의원은 2일 페이스북에 "2012년 보수정당인 새누리당이 이주여성 이자스민을 비례대표 후보로 공천한 것은 정말 혜안을 보여준 일이며, 이 일에 대해서만은 아낌없이 박수를 보냈다"면서 "진보적 가치를 추구하는 우리 민주당이 먼저 이런 생각을 하지 못한 것은 참 안타깝다"고 했다.
# 문장 정확도는 19.11%         number:25
# 형태소 정확도는 22.47%         number:25
# 문장 최종 정확도는36.53%         number:25
# 형태소 최종 정확도는37.41%         number:25
# 시장조사기관 트렌드포스에 따르면 TSMC의 올 3·4분기 글로벌 파운드리 시장 점유율은 직전분기 대비 1.3%포인트 늘어난 50.5%로 삼성전자(18.5%)와 격차도 크다.시장조사기관인 SA에 따르면 지난해 모바일 AP 시장에서 화웨이는 10%의 점유율로 퀄컴(37%)·미디어텍(23%)·애플(14%)·삼성전자(12%)에 이어 5위를 기록중이다.
# 중국 통신장비 업체인 화웨이와 대만 파운드리 업체인 TSMC 간의 밀월이 강화되며 삼성전자의 '2030년 시스템 반도체 1위' 달성이 쉽지 않을 것이란 전망이 나온다.화웨이는 미국 정부의 제재 속에서도 초미세 공정에 기반한 모바일 애플리케이션프로세서 개발에 속도를 내고 있으며 TSMC는 글로벌 스마트폰 시장 점유율 2위 업체인 화웨이를 등에 업고 공격적 투자를 단행중이다.
# 문장 정확도는 18.91%         number:26
# 형태소 정확도는 23.08%         number:26
# 문장 최종 정확도는35.85%         number:26
# 형태소 최종 정확도는36.86%         number:26
# 하지만 입법 취지와는 다르게 채무자가 돈을 갚지 않을 경우 채권자가 그 부동산의 소유권을 이전받는 방법으로 채권을 만족시키기 위해 이른바 ‘양도담보’를 목적으로 소유권가등기를 설정하는 경우가 많아졌습니다.반면 담보가등기가 아니라는 취지로 신고하거나 법원의 최고에도 불구하고 아무런 신고도 하지 않은 가등기권자는 배당을 받을 수 없습니다.
# Q. 선순위의 소유권가등기는 낙찰자에게 인수되고 담보가등기는 순위를 불문하고 소멸한다고 배웠습니다.법률에 따르면 등기상 소유권가등기로 표시되더라도 사실상 금전채권을 담보하기 위한 목적으로 설정된 가등기라면 그 효력을 저당권과 같게 봅니다.경매부동산에 설정된 모든 저당권은 부동산이 매각되면서 소멸하지만, 소유권가등기는 금전채권이 아닌 청구권을 보전하기 위해 설정한 등기라서 소유권가등기가 최선순위 설정권리보다 선순위일 경우 낙찰자에게 부담이 승계됩니다.
# 문장 정확도는 9.07%         number:27
# 형태소 정확도는 28.24%         number:27
# 문장 최종 정확도는34.86%         number:27
# 형태소 최종 정확도는36.54%         number:27
# 최 회장은 이날 행사에서 "포스코의 철강 부산물인 슬래그가 맛 좋은 쌀을 만드는 친환경 비료로 새로 태어나 농가소득 증대는 물론 토질 개량과 온실가스 감축에도 기여할 것으로 기대한다"고 말했다.현대제철은 2014년부터 2018년 상반기까지 미세먼지 배출량이 기준을 넘은 업체를 대상으로 부과된 32억4000만원 가운데 절반에 가까운 16억1400만원을 홀로 냈다.
# 철강업계가 친환경 행보에 박차를 가하고있다.이 같은 철강업체의 친환경경영은 미세먼지 등 오염물질 다배출원에 대한 관심이 높아지면서 이에 대응할 필요성이 생겼기 때문이기도 하다.올해 초 환경부가 발표한 사업장별 오염물질 배출량 조사 결과에 따르면, 지난해 오염물질 배출량이 가장 많은 사업장은 현대제철 당진제철소로 나타났다.
# 문장 정확도는 13.05%         number:28
# 형태소 정확도는 15.79%         number:28
# 문장 최종 정확도는34.08%         number:28
# 형태소 최종 정확도는35.80%         number:28
# 최근 집값이 가파르게 상승한 서울 강남 3구(강남·서초·송파구)와 이른바 마용성(마포·용산·성동) 지역 등이 유력한 대상지로 거론된다.국토교통부는 6일 오전 10시 주거정책심의위원회(주정심)를 개최해 민간택지 분양가상한제 적용지역을 결정하고 이날 오전 11시30분 결과를 발표할 예정이다.
# 분양가상한제가 적용되는 민간택지가 오는 6일 결정된다.최근 집값이 가파르게 상승한 서울 강남 3구와 이른바 마용성 지역 등이 유력한 대상지로 거론된다.국토교통부는 6일 오전 10시 주거정책심의위원회를 개최해 민간택지 분양가상한제 적용지역을 결정하고 이날 오전 11시30분 결과를 발표할 예정이다.
# 문장 정확도는 82.82%         number:29
# 형태소 정확도는 82.50%         number:29
# 문장 최종 정확도는35.76%         number:29
# 형태소 최종 정확도는37.41%         number:29
# 오는 6일 민간택지 분양가 상한제의 적용 지역을 결정하는 주거정책심의위윈회를 앞두고 서울 강남4구(강남·서초·송파·가동)와 마용성(마포·용산·성동) 등이 적용 지역으로 유력하게 거론되고 있다.주택시장 안정이 최우선 과제인 국토부는 가격 상승이 높고, 투기 심리를 자극할 수 있는 지역에 대해선 예외 없이 상한제를 적용해야 한다는 분위기다.
# 오는 6일 민간택지 분양가 상한제의 적용 지역을 결정하는 주거정책심의위윈회를 앞두고 서울 강남4구와 마용성 등이 적용 지역으로 유력하게 거론되고 있다.특히 아파트, 공장 등 건물에 대한 건축 공사는 9월까지 16개월 연속 감소하며 건설투자의 하락세를 원인이 됐다.기재부 관계자는 "건설로 경기 부양을 하는 것이 문제가 있다는 지적에는 공감한다"면서도 "하지만 내년 경제성장률이 올해보다 더 좋지 않을 수 있다는 전망이 나오는 상황에서 굳이 건설투자 감소를 불러올 수 있는 정책을 대대적으로 펼치는 것에 대해선 의문"이라고 설명했다.
# 문장 정확도는 36.63%         number:30
# 형태소 정확도는 42.48%         number:30
# 문장 최종 정확도는35.79%         number:30
# 형태소 최종 정확도는37.58%         number:30
# 개인 간 대출 거래를 제도권으로 끌어들이는 일명 'P2P법'이 국회 본회의를 통과되면서 관련 스타트업 대표가 박용만 대한상공회의소 회장에게 감사인사를 전했다.지난달 31일 P2P금융의 법적 근거가 되는 '온란인투자연계금융업 및 이용자 보호에 관한 법'이 국회 본회의를 통과하면서 업계에서는 P2P산업이 활성화 될 기반이 마련됐다는 평가가 나온다.
# 개인 간 대출 거래를 제도권으로 끌어들이는 일명 'P2P법'이 국회 본회의를 통과되면서 관련 스타트업 대표가 박용만 대한상공회의소 회장에게 감사인사를 전했다.2일 대한상의에 따르면 김성준 렌딧 대표는 지난달 31일 박용만 대한상의 회장의 페이스북 담벼락에 "드디어 큰 사건이 하나 터졌다.많은 분들께서 도와주신 덕분"이라며 "열심히 해서 꼭 좋은 모습 보여드리겠다"는 글을 남겼다.
# 문장 정확도는 49.26%         number:31
# 형태소 정확도는 51.85%         number:31
# 문장 최종 정확도는36.23%         number:31
# 형태소 최종 정확도는38.04%         number:31
# 이날 연예매체 디스패치는 원호가 2013년 10월 서울 강남의 한 지인 집에서 함께 대마를 흡연했으며, 경찰이 이와 관련한 내사를 진행 중이라며 보도했다.경찰은 현재 제기된 의혹에 대해 살펴보고 있으며 아직 원호를 소환하지 않은 것으로 전해졌다.
# 대마 흡연 의혹이 불거진 보이 그룹 '몬스타엑스' 전 멤버 원호에 대해 경찰이 사실관계를 들여다보고 있다.1일 경찰에 따르면 서울지방경찰청 광역수사대는 원호의 대마 흡연 의혹과 관련해 내사 중이다.
# 문장 정확도는 19.43%         number:32
# 형태소 정확도는 45.28%         number:32
# 문장 최종 정확도는35.70%         number:32
# 형태소 최종 정확도는38.27%         number:32
# 문화재청 창덕궁관리소는 창덕궁의 으뜸전각인 인정전 내부에 직접 들어가 볼 수 있는 '창덕궁 정전, 인정전에 들다' 특별관람을 오는 6일부터 30일까지 매주 수·토요일(1일 4회) 운영한다고 5일 밝혔다.인정전 안쪽에는 어좌(御座)가 마련돼있고 그 뒤로 삼라만상을 상징하는 해와 달 그리고 다섯 개의 봉우리가 그려진 '일월오봉병'이라는 병풍이 둘러져 있다.
# 창덕궁의 으뜸전각인 인정전의 내부가 가을을 맞아 다시 공개된다.문화재청 창덕궁관리소는 창덕궁의 으뜸전각인 인정전 내부에 직접 들어가 볼 수 있는 '창덕궁 정전, 인정전에 들다' 특별관람을 오는 6일부터 30일까지 매주 수·토요일 운영한다고 5일 밝혔다.
# 문장 정확도는 62.54%         number:33
# 형태소 정확도는 64.52%         number:33
# 문장 최종 정확도는36.51%         number:33
# 형태소 최종 정확도는39.06%         number:33
# 더불어민주당 장종화 청년대변인이 지난달 31일 발표한 ‘82년생 김지영’이라는 제목의 논평에 대한 비판이 나오고 있다.장 대변인은 또 “김지영같이 ‘세상 차별은 혼자 다 겪는’ 일이 없도록 우리 주변의 차별을 하나하나 없애가야 할 일이다.
# 더불어민주당 장종화 청년대변인이 지난달 31일 발표한 '82년생 김지영'이라는 제목의 논평에 대한 비판이 나오고 있다.장 대변인은 해당 논평에서 "영화 82년생 김지영의 존재 자체가 소위 '페미니즘'의 상징이 되고 공격의 대상이 되었다.그러나 우리 사회가 들여다보아야 할 문제는 그 지점이 아니다"고 밝혔다.장 대변인은 "김지영이 겪었던 일 중에 한두가지는 우리 모두 봤거나, 들었거나, 겪었다"며 "이는 거꾸로 '82년생 장종화'를 영화로 만들어도 똑같을 것"이라고 말했다.
# 문장 정확도는 41.10%         number:34
# 형태소 정확도는 42.86%         number:34
# 문장 최종 정확도는36.65%         number:34
# 형태소 최종 정확도는39.17%         number:34
# 지난해 개정한 관세법에 따르면 광역 지방자치단체별 외국인 관광객이 전년보다 20만명 이상 증가하거나 매출액이 2000억원 이상 늘어나는 두 가지 요건 가운데 한 가지만 충족돼도 신규 면세점 특허를 내줄 수 있다.중국인 단체관광객이 사드 보복을 기점으로 발을 끊으면서 면세점 시장이 보따리상(다이궁) 위주로 재편됐다.
# 두산그룹이 4년만에 면세사업을 포기하면서 이달 예정된 서울 시내면세점 입찰 흥행에도 비상이 걸린 상황이다.두산에 이어 올 상반기 한화도 면세사업 철수를 선언하면서 '대기업도 못견디는 시장'이라는 이미지가 더 강해졌기 때문이다.
# 문장 정확도는 12.58%         number:35
# 형태소 정확도는 6.15%         number:35
# 문장 최종 정확도는35.96%         number:35
# 형태소 최종 정확도는38.23%         number:35
# 'FCMM데이'는 일년에 딱 한 번 진행되는 파격 할인 행사로 구스패딩부터, 인기품목인 플리스 자켓, 4계절 필수템인 후드, 팬츠까지 신상을 포함한 전상품을 최대 90% 할인된 가격에 판매한다.FCMM이 1일부터 오는 3일까지 'FCMM 데이' 이벤트를 진행한다.
# FCMM이 1일부터 오는 3일까지 'FCMM 데이' 이벤트를 진행한다.'FCMM데이'는 일년에 딱 한 번 진행되는 파격 할인 행사로 구스패딩부터, 인기품목인 플리스 자켓, 4계절 필수템인 후드, 팬츠까지 신상을 포함한 전상품을 최대 90% 할인된 가격에 판매한다.
# 문장 정확도는 73.47%         number:36
# 형태소 정확도는 100.00%         number:36
# 문장 최종 정확도는37.00%         number:36
# 형태소 최종 정확도는39.95%         number:36
# 배우 홍석천은 지난 2016년 채널A ‘풍문으로 들었소’에서 “임세령과 같은 동네 주민인데, 이정재와 임세령 커플이 함께 있는 모습을 많이 봤다”라며, 임 전무에 대해 “재벌 패션의 1인자”라고 표현하기도 했다.과거 공개된 사진에서 임 전무는 560만 원의 릴리 마들레디나 오버넥 셔츠, 3700만 원의 버버리 본 보야지 엔조틱 롱 브라운, 2600만 원의 에르메스 저니 사이드 블랙 포 백을 착용해 눈길을 끈 바 있다.
# 임세령 대상 전무가 연인 사이인 배우 이정재와 동반 출국하는 현장이 포착되면서, 그의 패션에 또다시 관심이 쏠리고 있다.지난 1일 한 매체는 이정재와 임 전무 커플이 인천국제공항을 통해 출국하는 모습을 전했다.
# 문장 정확도는 14.77%         number:37
# 형태소 정확도는 27.03%         number:37
# 문장 최종 정확도는36.40%         number:37
# 형태소 최종 정확도는39.60%         number:37
# 검찰이 "근거를 대라"고 반박하자, 유 이사장은 지난달 29일 자신의 유튜브 방송에서 밝힐 수 없는 취재원으로부터 전해 들었다는 윤 총장의 사석(私席) 발언을 공개했다.스스로 바뀌어야 하는데 그럴 가능성이 없어 매운 어려운 일"이라며 "기자들이 조직구성원으로 해야 할 역할에만 머물지 말고 자존감을 갖고 일해야 한다"고 했다.
# 유시민 노무현재단 이사장이 조국 전 법무장관 가족에 대한 검찰 수사를 두고 "조국 일가족의 혐의점에 비해 무지무지하게 잔인하다"고 밝혔다.유 이사장은 검찰의 조 전 장관 자택 압수수색 이후부터 윤 총장이 대통령에게 비공식 면담을 요청해 조 전 장관 임명을 막으려했다는 의혹을 제기해왔다.검찰이 "근거를 대라"고 반박하자, 유 이사장은 지난달 29일 자신의 유튜브 방송에서 밝힐 수 없는 취재원으로부터 전해 들었다는 윤 총장의 사석 발언을 공개했다.
# 문장 정확도는 41.20%         number:38
# 형태소 정확도는 45.24%         number:38
# 문장 최종 정확도는36.53%         number:38
# 형태소 최종 정확도는39.75%         number:38
# 경찰이 2일 화성연쇄살인 사건의 피의자 이모(56)씨가 추가 자백한 초등생 김모(당시 8살, 38살)양의 시신 발굴작업을 진행중인 가운데 현재까지 35% 작업을 마무리했다고 밝혔다.반기수 전담본부장 현장 지휘...과학수사대 등 36명 투입
# 경찰이 2일 화성연쇄살인 사건의 피의자 이모씨가 추가 자백한 초등생 김모양의 시신 발굴작업을 진행중인 가운데 현재까지 35% 작업을 마무리했다고 밝혔다.이날 경찰은 150여개의 구역 중 50% 발굴을 목표로 경기남부청 과학수사대와 기동대 등 36명을 투입해 오전 9시부터 5인 1조 4개 조가 각 구획별로 분석작업을 벌였다.
# 문장 정확도는 64.33%         number:39
# 형태소 정확도는 57.14%         number:39
# 문장 최종 정확도는37.24%         number:39
# 형태소 최종 정확도는40.19%         number:39
# 국회 법제사법위원장인 여상규 의원은 "공수처와 비슷한 기관을 둔 나라는 아프리카 탄자니아 정도로, 공수처법을 발로 깔아뭉개야 한다"며 "(공수처는) 야당 의원들을 미행할 것이다.그는 "한두 명이 의사결정을 하는 것이 아니라, 많은 분의 의견을 묻는 열린 방식의 영입을 해야 한다"며 사실상 황 대표를 겨냥했다.
# 자유한국당은 주말인 2일 경남에서 고위공직자범죄수사처 설치법안과 준연동형 비례대표제를 골자로 한 선거법 개정안 저지를 위한 여론전을 벌였다.오는 11월 한 달간 주말마다 전국을 돌며 '공수처·선거법 반대' 여론을 달구기 위한 첫 순서다.황교안 대표는 이날 오후 경남 창원 마산합포구청 대회의실에서 열린 '공수처 저지 및 국회의원 정수 축소 촉구를 위한 좌파독재 실정 보고대회'에서 "경제를 망가뜨리고, 안보를 파탄에 빠뜨리고, 민생을 죽을 지경으로 만든 정부가 공수처법, 선거법을 자기들 마음대로 통과시키겠다고 한다"며 "좌파독재정권을 만들겠다는 것"이라고 밝혔다.
# 문장 정확도는 9.82%         number:40
# 형태소 정확도는 11.54%         number:40
# 문장 최종 정확도는36.56%         number:40
# 형태소 최종 정확도는39.48%         number:40
# 동반자가 샷을 하면 반드시 충분한 거리를 두고 뒤에 있어야 한다.보통 골프장 측은 사고를 대비해 미리 보험에 가입한다.
# 최근 골프장 안전사고와 관련해 아마추어 골퍼들이 눈여겨볼 만한 법원 판결이 나왔다."골프장 측은 골퍼 책임을 최대한 찾으려 할 것이고 골퍼는 골프장과 캐디의 잘못을 따져 부담을 줄이려고 합니다.강동근 변호사는 "골프장에선 본인, 동반자, 캐디, 다른 홀 골퍼, 골프장 등이 서로 가해자나 피해자가 될 수 있다"며 "복잡한 상황이 얽힌 큰 사고는 현장을 보전해 전문가를 통해 해결할 수밖에 없다"고 밝혔다.
# 문장 정확도는 8.22%         number:41
# 형태소 정확도는 13.11%         number:41
# 문장 최종 정확도는35.86%         number:41
# 형태소 최종 정확도는38.83%         number:41
# 한편, 에히메현에는 국내 저비용항공사(LCC) 제주항공이 취항하고 있다.2일 마이니치 신문에 따르면 일본 시코쿠 북서부에 위치한 에히메현은 현과 현 내 공기업, 교육위원회 직원들에게 이같이 권유하며 '10~12월 석 달간 600명'이라는 구체적인 목표까지 세워 한국 행을 권했다.
# 일본의 한 지방자치단체가 직원들에게 사비를 들여 한국 여행을 갈 것을 권유하고 있다.2일 마이니치 신문에 따르면 일본 시코쿠 북서부에 위치한 에히메현은 현과 현 내 공기업, 교육위원회 직원들에게 이같이 권유하며 '10~12월 석 달간 600명'이라는 구체적인 목표까지 세워 한국 행을 권했다.에히메현이 직원들에게 한국 여행을 권유한 이유는 일본과 서울을 오가는 항공편의 좌석 점유율이 낮아지며 직항 항공편이 폐지될 것을 우려해서다.
# 문장 정확도는 61.96%         number:42
# 형태소 정확도는 61.73%         number:42
# 문장 최종 정확도는36.49%         number:42
# 형태소 최종 정확도는39.38%         number:42
# 그러나 개발 부서 해체로 2021년부터는 당분간 삼성이 자체 설계한 CPU 코어는 보기 어렵게 될 것으로 전망된다.삼성전자는 스마트폰 두뇌에 해당하는 애플리케이션프로세서(AP) 경쟁력 강화를 위해 코어 설계 능력 향상에 투자를 해 왔다.
# 삼성전자가 자체 추진해 온 중앙처리장치 코어 개발에서 손을 뗀다. 코어는 CPU에서 데이터 연산 처리를 담당하는 핵심 반도체다.삼성전자는 시스템반도체 사업 강화의 일환으로 수년전부터 CPU 코어 내재화를 추진했지만 선택과 집중을 위해 CPU 코어 개발을 중단하기로 했다.
# 문장 정확도는 24.03%         number:43
# 형태소 정확도는 23.73%         number:43
# 문장 최종 정확도는36.20%         number:43
# 형태소 최종 정확도는39.01%         number:43
# 오는 11월 8일 롯데콘서트홀 ‘차이콥스키 교향곡 4번’ 공연에서 뮐러쇼트는 프로코피예프가 교향곡 7번과 함께 완성한 최후의 작품 ‘첼로와 오케스트라를 위한 신포니아 콘세르탄테(교향적 협주곡)’를 연주한다.프로코피예프의 신포니아 콘체르탄테는 바로 로스트로포비치에게 헌정된 곡이다.
# 첼리스트 다니엘 뮐러쇼트가 9년 만에 서울시향과 무대에 오른다.오는 11월 8일 롯데콘서트홀 '차이콥스키 교향곡 4번' 공연에서 뮐러쇼트는 프로코피예프가 교향곡 7번과 함께 완성한 최후의 작품 '첼로와 오케스트라를 위한 신포니아 콘세르탄테'를 연주한다.
# 문장 정확도는 68.69%         number:44
# 형태소 정확도는 74.58%         number:44
# 문장 최종 정확도는36.94%         number:44
# 형태소 최종 정확도는39.82%         number:44
# 이 게임에서 플레이어는 오버워치의 윈스턴, 트레이서를 비롯한 여러 팀원들이 새로운 세대의 영웅들과 힘을 합쳐 임무 완수를 위해 나서게 된다.블리자드는 향후 PC와 플레이스테이션4, 엑스박스원으로 디아블로4를 선보일 예정이다.
# 전 세계 게임팬이 주목하는 '디아블로4'와 '오버워치2'가 드디어 베일을 벗었다.블리자드는 1일 미국 애너하임 컨벤션 센터에서 개최한 블리즈컨2019에서 디아블로4와 오버워치2를 선보였다.
# 문장 정확도는 28.70%         number:45
# 형태소 정확도는 27.27%         number:45
# 문장 최종 정확도는36.75%         number:45
# 형태소 최종 정확도는39.54%         number:45
# 삼성전자가 갤럭시 폴드에 이어 ‘클램셸’ 형태의 새로운 폴더블폰을 공개하며 2세대 폼팩터 전쟁의 문을 열었다.이에 더해 삼성전자는 지난달 29일(현지시간) 미국 캘리포니아주 새너제이에서 열린 삼성 개발자 콘퍼런스(SDC) 2019에서 위아래로 여닫는 2세대 폴더블폰을 공개했다.
# 삼성전자가 갤럭시 폴드에 이어 '클램셸' 형태의 새로운 폴더블폰을 공개하며 2세대 폼팩터 전쟁의 문을 열었다.내년 전세계 320만대 규모로 성장한 폴더블폰 시장에서 앞으로 여러 제조사들이 앞다투어 새로운 폼팩터를 출시할 것으로 보인다.
# 문장 정확도는 49.65%         number:46
# 형태소 정확도는 55.17%         number:46
# 문장 최종 정확도는37.03%         number:46
# 형태소 최종 정확도는39.88%         number:46
# 이는 파견을 금지한 ‘여객자동차운송사업’과 다른 종류이므로, 파견법에 저촉받지 않는다.하지만 여객자동차운수사업법 개정안이 국회에서 통과하기 전까지 노동부는 결론을 내리지 않을 것으로 보인다.
# 지난 달 28일 검찰이 타다를 불법으로 판단하면서, 고용노동부가 타다를 파견법 위반으로 판단할 가능성이 높아졌다.하지만 여객자동차운수사업법 개정안이 국회에서 통과하기 전까지 노동부는 결론을 내리지 않을 것으로 보인다.
# 문장 정확도는 59.03%         number:47
# 형태소 정확도는 61.22%         number:47
# 문장 최종 정확도는37.50%         number:47
# 형태소 최종 정확도는40.34%         number:47
# 켈리 부사장은 “모르겠다”고 했으나 동석한 화웨이 관계자는 “SK텔레콤 및 KT와 28㎓ 주파수를 사용하는 화웨이의 5G 기지국 장비 도입을 논의하고 있다”며 “아직 결정된 것은 없다”고 전했다.반면 켈리 부사장은 미국이 이를 따라잡으려면 시간이 오래 걸릴 것으로 봤다.
# "화웨이 장비를 배제한 미국은 5세대 이동통신 경쟁에서 뒤처질 것이다.지난 25일 중국 선전의 화웨이 본사에서 만난 화웨이의 조 켈리 국제미디어본부 부사장은 화웨이와 ZTE 등 중국산 통신장비를 배제한 미국이 5G 경쟁에서 불리할 것이라고 단언했다.
# 문장 정확도는 16.55%         number:48
# 형태소 정확도는 27.59%         number:48
# 문장 최종 정확도는37.06%         number:48
# 형태소 최종 정확도는40.07%         number:48
# 미국 IT 매체 더 버지(The Verge)는 “LG G8X 씽큐와 듀얼 스크린의 멀티태스킹 성능은 지금까지 사용해 본 모바일 제품 중 최고”라고 호평했다.LG G8X 씽큐는 안정성이 뛰어난 LG V50 씽큐 플랫폼을 바탕으로 했다.
# LG G8X 씽큐가 북미 시장 출시 초반부터 듀얼 스크린의 멀티태스킹 경험과 합리적인 가격이 호평을 받았다.LG전자는 지난 1일 북미 시장에 출시한 LG G8X 씽큐와 듀얼 스크린에 대한 외신 호평이 이어지고 있다고 밝혔다.
# 문장 정확도는 33.73%         number:49
# 형태소 정확도는 27.27%         number:49
# 문장 최종 정확도는37.00%         number:49
# 형태소 최종 정확도는39.81%         number:49
# 콘텐츠웨이브는 '프리미어12' 공식 스폰서로 참여해 생중계 권한을 확보, 1일부터 대한민국 국가대표팀 전 경기를 고화질(풀HD)로 무료 생중계한다.이어 6일 서울 고척 스카이돔에서 호주와 예선 첫 경기를 시작으로, 7일 캐나다, 8일 쿠바와 경기를 갖는다.
# 온라인동영상서비스 웨이브가 2020 도쿄올림픽 야구 본선 진출권이 달린 '2019 WBSC 프리미어 12' 경기를 온라인 독점 생중계한다.콘텐츠웨이브는 '프리미어12' 공식 스폰서로 참여해 생중계 권한을 확보, 1일부터 대한민국 국가대표팀 전 경기를 고화질로 무료 생중계한다.
# 문장 정확도는 51.85%         number:50
# 형태소 정확도는 57.63%         number:50
# 문장 최종 정확도는37.29%         number:50
# 형태소 최종 정확도는40.17%         number:50
# 게임 축제 블리즈컨2019에서 신작 디아블로4와 오버워치2, 월드오브워크래프트 새 확장팩 등이 깜짝 공개됐다.블리자드 측은 "일부 신작과 기존 서비스작 업데이트 관련 내용은 블리즈컨 기간 세션별 발표 시간을 통해 다시 소개할 계획"이라며 "신작과 기존 서비스작의 업데이트 등에 많은 관심 부탁드린다"고 말했다.
# 게임 축제 블리즈컨2019에서 신작 디아블로4와 오버워치2, 월드오브워크래프트 새 확장팩 등이 깜짝 공개됐다.블리자드엔터테인먼트는 1일 오전 10시 미국 캘리포니아 애너하임 컨벤션 센터에서 블리즈컨2019 개막을 알렸다.
# 문장 정확도는 51.35%         number:51
# 형태소 정확도는 48.57%         number:51
# 문장 최종 정확도는37.57%         number:51
# 형태소 최종 정확도는40.33%         number:51
# 한국계 미국인 제임스 박이 공동창업한 핏빗은 하루 걸음 수나 달린 거리, 소모된 칼로리양, 심장 박동수, 수면 시간과 수면의 질 등을 계측하는 스마트워치 등을 생산한다.구글, '핏빗' 인수로 스마트워치 진출...삼성·애플과 경쟁
# 웨어러블 시장의 최강자로 자리매김한 '핏빗'이 세계 최대 검색엔진 업체 구글의 모회사 '알파벳'에 인수된다고 미 언론들이 1일 보도했다.한국계 미국인 제임스 박이 공동창업한 핏빗은 하루 걸음 수나 달린 거리, 소모된 칼로리양, 심장 박동수, 수면 시간과 수면의 질 등을 계측하는 스마트워치 등을 생산한다.
# 문장 정확도는 63.30%         number:52
# 형태소 정확도는 71.23%         number:52
# 문장 최종 정확도는38.06%         number:52
# 형태소 최종 정확도는40.93%         number:52
# 블리자드4는 시리즈의 특징을 그대로 이어 받아 어두운 스토리와 강렬한 전투, RPG 방식의 캐릭터 육성, 무한 생성되는 던전, 수많은 아이템 조합 등 '가장 디아블로다운 게임'을 표방했다.이날 블리자드는 2016년 출시돼 전 세계 5000만명 이상의 이용자들 끌어모으며 선풍적인 인기를 끈 '오버워치'의 정식 후속작 '오버워치2'도 공개했다.
# 블리자드가 자사의 대표작인 '디아블로'와 '오버워치'의 공식 후속작을 전격 공개했다.1일 블리자드 엔터테인먼트는 미국 캘리포니아주 애너하임 컨벤션센터에서 열린 '블리즈컨 2019' 행사에서 액션 롤플레잉 게임 '디아블로4'와 팀 기반 1인칭 슈팅게임 '오버워치2'를 공개했다.
# 문장 정확도는 24.35%         number:53
# 형태소 정확도는 29.73%         number:53
# 문장 최종 정확도는37.80%         number:53
# 형태소 최종 정확도는40.71%         number:53
# VCNC는 재판에서 판결이 날 때까지 운행은 강행하겠다는 입장이지만 드라이버들 사이에서는 언제 운행을 멈출지, 혹은 이대로 운행을 계속해도 피해가 없을지 노심초사하고 있다.1일 기자가 만난 타다를 운행하는 드라이버 A씨는 "타다측에서 기소와 관련해 드라이버 앱 공지를 받았지만 드라이버 입장에서 어떻게 되는 건지 불안하다"고 토로했다.
# 검찰이 여객자동차 운수사업법 위반 혐의로 이재웅 쏘카대표와 박재욱 VCNC 대표, 각 법인을 기소한 가운데 '타다' 드라이버 사이에서 불안감이 커지고 있다.VCNC는 재판에서 판결이 날 때까지 운행은 강행하겠다는 입장이지만 드라이버들 사이에서는 언제 운행을 멈출지, 혹은 이대로 운행을 계속해도 피해가 없을지 노심초사하고 있다.
# 문장 정확도는 51.89%         number:54
# 형태소 정확도는 52.31%         number:54
# 문장 최종 정확도는38.07%         number:54
# 형태소 최종 정확도는40.93%         number:54
# 대한민국 임시정부 수립 100주년을 기념해 제작된 뮤지컬 '도산 안창호'가 오는 16~17일 양일 간 나루아트센터 대극장에서 공연된다.흥사단은 우리가 잘 알지 못했던 도산의 정신과 업적, 나라의 중요성과 독립운동가의 헌신을 뮤지컬을 통해 알리고자 이 작품을 제작했다.
# 대한민국 임시정부 수립 100주년을 기념해 제작된 뮤지컬 '도산 안창호'가 오는 16~17일 양일 간 나루아트센터 대극장에서 공연된다.흥사단은 우리가 잘 알지 못했던 도산의 정신과 업적, 나라의 중요성과 독립운동가의 헌신을 뮤지컬을 통해 알리고자 이 작품을 제작했다.
# 문장 정확도는 100.00%         number:55
# 형태소 정확도는 100.00%         number:55
# 문장 최종 정확도는39.19%         number:55
# 형태소 최종 정확도는42.00%         number:55
# 5일 중국 텐센트뉴스(텅쉰신원)와 삼성전자에 따르면, 삼성전자는 지난 4일 오후 중국 내 모바일부문 직원을 상대로 조직 개편과 유통 채널 재정비 등에 대한 설명회를 열었다.'점유율 0%대' 삼성전자, 中 스마트폰 조직개편... 현지 감원 우려
# 중국 스마트폰 사업에서 부진을 겪고 있는 삼성전자가 중국 조직을 또 개편한다.지난 9월 중국내 마지막 스마트폰 생산기지인 광둥성 후이저우 공장을 폐쇄한 데 이은 조치다.
# 문장 정확도는 21.83%         number:56
# 형태소 정확도는 28.07%         number:56
# 문장 최종 정확도는38.88%         number:56
# 형태소 최종 정확도는41.75%         number:56
# 내년 웨어러블(착용하는) 기기 시장이 스마트 워치와 스마트 의류를 중심으로 큰 폭의 성장이 예상되고 있다.가트너는 소형화 기술 발전으로 2023년에는 웨어러블 기기 10개 중 1개는 사용자의 눈에 잘 보이지 않을 정도로 작아질 것으로 내다봤다.
# 내년 웨어러블 기기 시장이 스마트 워치와 스마트 의류를 중심으로 큰 폭의 성장이 예상되고 있다.내년 웨어러블 시장 규모만 520억 달러에 달할 것으로 전망되면서 삼성전자와 애플 등의 각축전도 한층 뜨거워지고 있다.
# 문장 정확도는 54.90%         number:57
# 형태소 정확도는 58.18%         number:57
# 문장 최종 정확도는39.16%         number:57
# 형태소 최종 정확도는42.04%         number:57
# 국내에도 잘 알려진 외치(Ötzi)는 ‘아이스맨’이라는 별칭으로도 유명하다.이번에 글래스고 대학 연구팀은 외치의 마지막 여정을 과학적으로 증명해냈다.
# '유럽 최초의 피살자'로 불리는 외치의 죽기 직전 마지막 행적이 드러났다.최근 영국 글래스고 대학 연구팀은 외치의 내장과 옷, 장비 등 분석을 통해 그가 현대 이탈리아의 볼차노 인근 계곡을 등반한 것이 아닌 쉬날스탈 빙하지역 북서쪽을 오르다 사망했다는 연구결과를 발표했다.
# 문장 정확도는 25.53%         number:58
# 형태소 정확도는 24.00%         number:58
# 문장 최종 정확도는38.93%         number:58
# 형태소 최종 정확도는41.73%         number:58
# 해외에서는 휴대폰을 들고 다니면서 이용하는 사람들이 많아 청각장애인들의 의사소통에도 큰 도움이 되고 있다고 하는데요. 어떻게 사용하는 것이고 주의점은 없는지 연합뉴스 하우투에서 소개합니다.사람이 말하거나 구동 중인 동영상의 음성을 인공지능(AI)이 실시간으로 인식해 타이핑해주는 구글 드라이브의 음성입력 서비스가 큰 인기를 끌고 있습니다.
# 사람이 말하거나 구동 중인 동영상의 음성을 인공지능이 실시간으로 인식해 타이핑해주는 구글 드라이브의 음성입력 서비스가 큰 인기를 끌고 있습니다.30분짜리 강연 영상을 틀어놓고 잠시 다른 일을 본 후 30분 후에 자리에 오면 이미 타이핑이 끝나 있는 문서를 확인할 수 있는 형태인데요.
# 문장 정확도는 46.11%         number:59
# 형태소 정확도는 53.12%         number:59
# 문장 최종 정확도는39.05%         number:59
# 형태소 최종 정확도는41.92%         number:59
# 간편 송금 서비스 토스는 1일 ‘OOOOO은 수크랄페이트와 덱스판테놀의 복합체로 손상 받은 피부의 진정과 보호에 도움을 준다.OOOOO에 들어갈 닥터오킴스의 독자적 성분은?’이라는 행운퀴즈를 출제했다.
# '수크라테놀'과 관련한 토스 행운퀴즈가 등장했다.간편 송금 서비스 토스는 1일 'OOOOO은 수크랄페이트와 덱스판테놀의 복합체로 손상 받은 피부의 진정과 보호에 도움을 준다.OOOOO에 들어갈 닥터오킴스의 독자적 성분은?'이라는 행운퀴즈를 출제했다.
# 문장 정확도는 87.65%         number:60
# 형태소 정확도는 83.64%         number:60
# 문장 최종 정확도는39.86%         number:60
# 형태소 최종 정확도는42.62%         number:60
# 31일 업계에 따르면 중국 알리바바 그룹 산하 쇼핑몰 알리익스프레스에 애플 에어팟 프로와 똑같은 ‘차이팟 프로’가 현재 판매되고 있다.30일부터 정식 판매되고 있으며, 중국 내 판매가격은 1999위안(약 33만원)이다.
# 애플의 새 무선 이어폰 '에어팟 프로' 판매가 시작된 가운데 중국에서 이를 베낀 '짝퉁'이 빠르게 등장했다.완전히 똑같은 외관에 소음 제거 기능까지 지원하지만, 가격은 훨씬 저렴하다.
# 문장 정확도는 18.75%         number:61
# 형태소 정확도는 27.27%         number:61
# 문장 최종 정확도는39.51%         number:61
# 형태소 최종 정확도는42.37%         number:61
# 힌트는 포털사이트 네이버에서 '아시아나항공 우수회원'을 검색 시 확인 가능하며 정답은 '제휴카드'이다.□□□□에 들어갈 회원 등급은 무엇일까?"이며, 정답은 '플래티늄'이다.
# 간편송금 서비스 토스가 1일 '아시아나항공 우수회원'과 관련 행운퀴즈를 출제했다.마일리지가 반영되어 우수회원 자격을 보다 쉽게 획득하실 수 있다.
# 문장 정확도는 26.97%         number:62
# 형태소 정확도는 26.32%         number:62
# 문장 최종 정확도는39.31%         number:62
# 형태소 최종 정확도는42.11%         number:62
# 시장조사업체 IHS마킷은 삼성전자가 내년 스마트폰 생산 물량 3억 대 중 20%(약 6000만 대)를 ODM으로 생산할 것이란 관측을 내놨다.갤노트10·A시리즈가 효자…스마트폰, 삼성전자 50년 잔칫날 '3兆 선물'
# 삼성전자 스마트폰 사업 실적이 되살아났다.갤럭시노트10과 중저가폰인 갤럭시A 시리즈 판매 호조로 3분기 깜짝 실적을 냈다.
# 문장 정확도는 24.47%         number:63
# 형태소 정확도는 31.58%         number:63
# 문장 최종 정확도는39.08%         number:63
# 형태소 최종 정확도는41.94%         number:63
# LG전자는 "글로벌 생산지 효율화와 원가개선의 영향으로 영업손실은 전분기 대비 큰폭으로 개선됐다"고 설명했다.LG전자 스마트폰 사업이 18분기 연속 적자를 기록했으나 베트남 공장 이전을 통한 생산지 효율화와 원가개선으로 영업손실의 폭을 줄였다.
# LG전자 스마트폰 사업이 18분기 연속 적자를 기록했으나 베트남 공장 이전을 통한 생산지 효율화와 원가개선으로 영업손실의 폭을 줄였다.LG전자는 30일 3분기 실적발표를 통해 매출액 15조7007억원, 영업이익 7814억원을 기록했다고 밝혔다.
# 문장 정확도는 30.15%         number:64
# 형태소 정확도는 65.52%         number:64
# 문장 최종 정확도는38.94%         number:64
# 형태소 최종 정확도는42.31%         number:64
# 그는 이어 “쇼핑·플레이스에서 일궈낸 성공사례를 재연해 금융상품 중개 프로세스를 개선할 것”이라고 덧붙였다.국내 간편결제 시장의 최강자인 네이버가 ‘네이버파이낸셜’ 설립으로 플랫폼 기반의 금융사업을 본격화한다.
# 국내 간편결제 시장의 최강자인 네이버가 '네이버파이낸셜' 설립으로 플랫폼 기반의 금융사업을 본격화한다.내년부터 예적금 통장과 주식·보험, 신용카드, 대출 등 다양한 네이버만의 금융상품을 내놓을 계획이다.
# 문장 정확도는 47.83%         number:65
# 형태소 정확도는 64.15%         number:65
# 문장 최종 정확도는39.07%         number:65
# 형태소 최종 정확도는42.65%         number:65
# 이번 부산국악방송 개국 8주년 기념공연 ‘좋아海 사랑海’는 16일 저녁 7시부터 국악방송 FM라디오(부산 98.5㎒)와 국악방송 웹 TV, 페이스북 LIVE, 유튜브 등를 통해 전국으로 생중계된다.공개음악회 ‘좋아海 사랑海’는 젊은 소리꾼 김나니의 사회로 진행되며, 최고의 명인명창들과 재기발랄한 젊은 국악인들이 총출동한다.
# 부산국악방송이 개국 8주년을 맞아 공개음악회를 연다.부산국악방송은 16일 오후 7시 국립부산국악원 연악당에서 부산 지역 전통예술의 중심인 국립부산국악원과 공동으로 개국 8주년 기념 공개음악회 '좋아海 사랑海'를 주최한다고 5일 밝혔다.
# 문장 정확도는 19.23%         number:66
# 형태소 정확도는 38.10%         number:66
# 문장 최종 정확도는38.77%         number:66
# 형태소 최종 정확도는42.58%         number:66
# 이날 기조연설에 나선 정혜순 삼성전자 무선사업부 프레임워크개발그룹 상무는 "갤럭시 폴드는 시작에 불과하다"고 운을 뗀 뒤 "폴더블 기술의 놀라운 점은 더 콤팩트해질 수도 있다는 것"이라며 새 폼팩터를 공개했다.삼성전자가 폴더블 스마트폰 '갤럭시 폴드'에 이어 29일(현지시간) 가로 방향으로 접히는 새로운 폼팩터(하드웨어의 크기·형태)의 폴더블폰을 깜짝 공개했다.
# 삼성전자가 폴더블 스마트폰 '갤럭시 폴드'에 이어 29일 가로 방향으로 접히는 새로운 폼팩터의 폴더블폰을 깜짝 공개했다.삼성전자는 이날 미국 캘리포니아 새너제이 컨벤션센터에서 열린 '삼성 개발자 콘퍼런스 2019'에서 이처럼 새로운 형태의 폴더블폰을 선보였다.
# 문장 정확도는 27.59%         number:67
# 형태소 정확도는 49.38%         number:67
# 문장 최종 정확도는38.61%         number:67
# 형태소 최종 정확도는42.68%         number:67
# 삼성전자는 지난달 29일(현지시간) 미국 캘리포니아주 새너제이에서 열린 ‘삼성 개발자 콘퍼런스(SDC) 2019’에서 화면을 위아래로 접을 수 있는 클램셸 형태의 폴더블폰을 공개한 바 있다.삼성전자가 2020년엔 폴더블폰 생산량을 늘리겠다고 밝혔다.
# 삼성전자가 2020년엔 폴더블폰 생산량을 늘리겠다고 밝혔다.갤럭시 폴드의 흥행 이후 위아래로 여닫는 '클램셸' 형태 폴더블폰까지 공개한 삼성전자가 폴더블폰 시장 주도권을 이어갈 수 있을지 주목된다.
# 문장 정확도는 26.51%         number:68
# 형태소 정확도는 54.90%         number:68
# 문장 최종 정확도는38.43%         number:68
# 형태소 최종 정확도는42.86%         number:68
# 새로 공개한 폴더블폰 폼팩터는 가로 방향을 축으로 해 안으로 접히는 형태로, 갤럭시 폴드보다 더 얇고 가벼운 형태가 될 것으로 보인다.삼성전자가 올해 9월 갤럭시 폴드를 출시하면서 폴더블폰 시장이 본격 개화했지만, 아직 초기 단계여서 각 제조사는 저마다 다양한 디자인으로 시장에 도전장을 내고 있다.
# 삼성전자가 29일 미국 캘리포니아주 새너제이에서 열린 '삼성 개발자 콘퍼런스 2019'에서 새로운 '클램셸' 형태의 폴더블폰 시안을 공개하면서 새 폼팩터 경쟁에 관심이 쏠리고 있다.삼성전자가 올해 9월 갤럭시 폴드를 출시하면서 폴더블폰 시장이 본격 개화했지만, 아직 초기 단계여서 각 제조사는 저마다 다양한 디자인으로 시장에 도전장을 내고 있다.
# 문장 정확도는 59.44%         number:69
# 형태소 정확도는 69.44%         number:69
# 문장 최종 정확도는38.73%         number:69
# 형태소 최종 정확도는43.24%         number:69
# 애플의 차세대 무선이어폰 ‘에어팟 프로’가 새로운 미드나잇 그린을 포함해 화이트, 블랙 등 최대 8개 색상으로 출시될 예정이라고 IT매체 맥루머스가 대만 매체 이코노믹 데일리 뉴스를 인용 보도했다지난 달 말 iOS 13.2 베타 버전에서 주변 소음을 차단하는 데 도움이 되는 고무 이어팁이 포함된 새로운 디자인의 에어팟 아이콘이 발견되기도 했다.
# 애플의 차세대 무선이어폰 '에어팟 프로'가 새로운 미드나잇 그린을 포함해 화이트, 블랙 등 최대 8개 색상으로 출시될 예정이라고 IT매체 맥루머스가 대만 매체 이코노믹 데일리 뉴스를 인용 보도했다.해당 매체는 애플이 올해 휴가 쇼핑 시즌에 맞춰 에어팟 프로를 출시 할 계획으로 빠르면 다음 주에 제품을 공개할 수 있다고 전했다.
# 문장 정확도는 62.23%         number:70
# 형태소 정확도는 63.64%         number:70
# 문장 최종 정확도는39.07%         number:70
# 형태소 최종 정확도는43.54%         number:70
# '온디맨드(O2O)' 업체가 늘어나며 단기고용직인 '긱 이코노미(단기근로)' 종사자가 급증하고 있지만 정규직이 아닌 탓에 관련업계가 관리문제로 몸살을 앓고 있다.◇배달음식 고기가 빠졌다?…'배달원' 일탈에 '타다 기사' 성희롱까지
# '온디맨드' 업체가 늘어나며 단기고용직인 '긱 이코노미' 종사자가 급증하고 있지만 정규직이 아닌 탓에 관련업계가 관리문제로 몸살을 앓고 있다.검증되지 않은 이들이 긱 이코노미 시장에 유입되면서 성희롱과 욕설·바가지 금액 책정 등 피해사례가 늘어나 업체마다 이미지 타격이 적지 않지만 인건비 부담으로 직접 고용이 어렵고 간접고용인 탓에 종사자 교육도 쉽지 않은 상황이다.
# 문장 정확도는 49.70%         number:71
# 형태소 정확도는 50.00%         number:71
# 문장 최종 정확도는39.22%         number:71
# 형태소 최종 정확도는43.63%         number:71
# 애플은 이로써 1세대 에어팟(19만9천원), 2세대 에어팟(24만9천원), 3세 에어팟(32만9천원) 등의 3가지 가격의 모델을 공급하게 돼 소비자들이 다양한 선택을 할 수 있게 됐다.애플은 28일(현지시간) 인기 무선 이어폰 에어팟에 맞춤형 핏 디자인을 채용해 착용감과 밀폐감을 높이고 액티브 노이즈 캔슬링과 방수기능를 추가한 프리미엄 모델 에어팟 프로를 내놨다.
# 애플이 완전히 새롭게 디자인한 고성능 무선 이어폰 에어팟 프로를 전격 공개했다.애플은 28일 인기 무선 이어폰 에어팟에 맞춤형 핏 디자인을 채용해 착용감과 밀폐감을 높이고 액티브 노이즈 캔슬링과 방수기능를 추가한 프리미엄 모델 에어팟 프로를 내놨다.
# 문장 정확도는 62.39%         number:72
# 형태소 정확도는 71.79%         number:72
# 문장 최종 정확도는39.54%         number:72
# 형태소 최종 정확도는44.02%         number:72
# ①법률상 문언적 근거가 있어 불법이라 보기 어렵고 ②타다에 대한 이용자 선택권을 침해했으며 ③4차 산업혁명 전환기에 낡은 규제로 신산업을 형사 기소하는 일은 잘못이라는 것이다.구태언 변호사는 “4차 산업혁명의 전환기에 낡은 규제로 신산업을 형사기소하는 일은 극도로 자제해야 한다.
# 검찰이 승합차와 운전자 모두를 빌려주는 모빌리티 플랫폼 '타다' 운행이 불법이라고 판단하고 임원들을 불구속 기소하자, 벤처인들이 강력하게 반발하고 있다.검찰은 어제 여객자동차운수사업법 위반 혐의로 박재욱 VCNC 대표와 이재웅 쏘카 대표를 각각 불구속 기소했다.
# 문장 정확도는 13.91%         number:73
# 형태소 정확도는 9.68%         number:73
# 문장 최종 정확도는39.19%         number:73
# 형태소 최종 정확도는43.55%         number:73
# 이 청원인은 특히 타다를 합법화 해달라는 이유로 기존 택시의 낡고 고루한 서비스와 타다의 수준높은 서비스를 비교하며 '소비자로서 선택할 권리'를 달라고 강조해 눈길을 끌었다.검찰에 따르면 박 대표 등은 타다 스마트폰 애플리케이션(앱)을 통해 면허 없이 여객자동차 운송사업을 운영하고 자동차 대여사업자로서 법률상 허용되지 않는 유상여객운송을 한 혐의를 받고 있다.
# 불법 혐의로 검찰에 전격 불구석 기소된 '타다'를 합법화해 달라는 청와대 국민청원이 등장했다.지난 28일 한 청원인은 검찰이 타다를 운영하는 VCNC의 박재욱 대표를 불구속 기소하자 '승차거부 없고 서비스 질이 높은 타다 서비스를 합법화 시켜달라'며 청원을 냈다.
# 문장 정확도는 20.63%         number:74
# 형태소 정확도는 26.67%         number:74
# 문장 최종 정확도는38.94%         number:74
# 형태소 최종 정확도는43.32%         number:74
# 애플이 ‘노이즈 캔슬링’ 기능이 탑재된 새로운 디자인의 ‘에어팟 프로’를 공개한 가운데 한국 소비자를 해외 소비자와 차별하고 있다는 지적이 나온다.‘노이즈 캔슬링’ 기능을 이용하면 1회 충전 시 최대 4시간 30분의 재생 시간, 3시간 30분의 통화시간을 지원한다.
# 애플이 '노이즈 캔슬링' 기능이 탑재된 새로운 디자인의 '에어팟 프로'를 공개한 가운데 한국 소비자를 해외 소비자와 차별하고 있다는 지적이 나온다.28일 애플은 공식 자료를 통해 '에어팟 프로'를 30일부터 공식 스토어에서 판매한다고 밝혔다.
# 문장 정확도는 59.36%         number:75
# 형태소 정확도는 62.07%         number:75
# 문장 최종 정확도는39.21%         number:75
# 형태소 최종 정확도는43.57%         number:75
# 아이폰 11 시리즈로 글로벌 흥행을 이어가고 있는 애플이 새로운 프리미엄 무선 이어폰 ‘에어팟 프로’를 내놨다.애플은 28일(현지시간) 노이즈 캔슬링과 인이어(귀 삽입형) 디자인 등을 갖춘 에어팟 프로를 공개했다.
# 아이폰 11 시리즈로 글로벌 흥행을 이어가고 있는 애플이 새로운 프리미엄 무선 이어폰 '에어팟 프로'를 내놨다.애플은 28일 노이즈 캔슬링과 인이어 디자인 등을 갖춘 에어팟 프로를 공개했다.
# 문장 정확도는 92.44%         number:76
# 형태소 정확도는 91.30%         number:76
# 문장 최종 정확도는39.91%         number:76
# 형태소 최종 정확도는44.20%         number:76
# 오는 8~9일 이틀간 서울 대학로예술극장 대극장에서 공연되는 'OPIUM(오피움)'은 환각제로 사용되는 양귀비에서 착안, 감각이 극대화했을 때 나타나는 신체 변형과 변신을 탐구한 현대무용이다.안무를 맡은 예효승 BluePoet D.T 대표는 환각제 등이 우리 신체를 자극했을 때 신체 변화뿐 아니라 내면의 상태를 무대 위 오브제와 연결해 다양한 이미지로 구현하는데 주안점을 뒀다고 설명했다.
# 환각제 등이 우리 신체를 자극하게 됐을 때 몸은 과연 어떻게 변하게 될까.오는 8~9일 이틀간 서울 대학로예술극장 대극장에서 공연되는 'OPIUM'은 환각제로 사용되는 양귀비에서 착안, 감각이 극대화했을 때 나타나는 신체 변형과 변신을 탐구한 현대무용이다.
# 문장 정확도는 56.51%         number:77
# 형태소 정확도는 72.22%         number:77
# 문장 최종 정확도는40.13%         number:77
# 형태소 최종 정확도는44.56%         number:77
# 현생인류가 아프리카 대륙에서 출현했다는 것은 이미 알려져 있는 사실이지만 정확한 발상지와 전 세계로 퍼지게 된 원인에 대해서는 명확히 밝혀지지 않았었는데 이번 연구는 이를 규명해 냄으로써 과학계의 주목을 받고 있다.연구팀에 따르면 최초 인류는 13만년 전 칼라하리 북쪽 잠비아와 탄자니아 지역으로, 11만년 전에는 발상지 남서쪽인 나미비아와 남아공 지역의 녹지를 찾아 이동했다.
# 국내 연구진이 포함된 국제 공동연구팀이 '호모사피엔스'가 아프리카 칼라하리 지역에 처음 나타났으며, 첫 번째 인류 대이동의 원인은 기후변화였다는 사실을 밝혀냈다.호주의 가반의학연구소와 뉴사우스웨일스대, 한국의 기초과학연구원 기후물리연구단, 남아프리카공화국 로즈대, 나미비아 빈트후크중앙병원 등 10개 기관 연구진으로 구성된 국제공동연구팀은 현생인류가 20만년 전 아프리카 칼라하리 지역에서 처음 나타났고 13만년 전 기후변화 때문에 인류 대이동이 있었다는 연구 결과를 세계적인 과학저널 '네이처' 10월 29일자에 발표했다.
# 문장 정확도는 11.51%         number:78
# 형태소 정확도는 33.68%         number:78
# 문장 최종 정확도는39.76%         number:78
# 형태소 최종 정확도는44.42%         number:78
# SK텔레콤은 카카오와 3000억원 규모의 지분을 교환하고 전략적 파트너십을 체결한다고 28일 밝혔다.이와 함께 양사는 전략적 파트너십을 체결하고, 통신·커머스·디지털 콘텐츠·미래 ICT 등 4대 분야에서 양사 간 긴밀한 협력을 추진키로 했다.
# SK텔레콤은 카카오와 3000억원 규모의 지분을 교환하고 전략적 파트너십을 체결한다고 28일 밝혔다.SK텔레콤은 3000억원 규모의 자기주식을 카카오에 매각하고, 카카오는 신주를 발행해 SK텔레콤에 배정하는 방식으로 지분을 맞교환한다.
# 문장 정확도는 51.13%         number:79
# 형태소 정확도는 34.78%         number:79
# 문장 최종 정확도는39.90%         number:79
# 형태소 최종 정확도는44.30%         number:79
# 이에 지난달 말에는 싸이월드 전제완 대표가 500억∼600억원을 제시하며 블록체인 및 핀테크 업계에 매각을 추진 중이라는 보도도 나왔다.페이스북과 인스타그램을 사용하지 않는 3040세대를 중심으로 여전히 싸이월드에 향수를 느끼는 이용자가 많고, 싸이월드를 앨범으로 활용하고 있는 이용자가 적지 않다는 게 업계의 설명이다.
# '추억의 국민 SNS' 싸이월드의 월간순이용자가 100만명에 달한다는 조사 결과가 나왔다.페이스북, 인스타그램 등 글로벌 SNS에 뒤처지면서 한때 도메인이 만료돼 문을 닫는다는 소문과 우려도 있었지만, 여전히 많은 사람들이 싸이월드를 찾고 있는 것으로 나타났다.
# 문장 정확도는 30.15%         number:80
# 형태소 정확도는 18.52%         number:80
# 문장 최종 정확도는39.78%         number:80
# 형태소 최종 정확도는43.98%         number:80
# 지난 주말새 비트코인 가격이 20% 이상 폭등하며 1000만원선을 회복한 가운데, 향후 암호화폐 시장 전망에 대한 업계의 의견이 갈리고 있다.미국과 우리나라를 비롯 FATF 회원국은 비트코인을 거래하는 이들의 구체적인 거래정보를 규제당국이 모두 인지하고 있어야 한다.
# 지난 주말새 비트코인 가격이 20% 이상 폭등하며 1000만원선을 회복한 가운데, 향후 암호화폐 시장 전망에 대한 업계의 의견이 갈리고 있다.중국 정부의 블록체인 육성정책 덕에 "내년 초 비트코인 가격이 5만달러까지 폭등할 것"이라는 시각과 "오히려 각국 정부의 코인시장 관리가 더 엄격해질 것"이라는 반대의견이 팽팽하게 맞선다.
# 문장 정확도는 52.85%         number:81
# 형태소 정확도는 49.32%         number:81
# 문장 최종 정확도는39.94%         number:81
# 형태소 최종 정확도는44.04%         number:81
# 알뜰폰 최초 5G 서비스, 2년 약정 없이도 싼 가격, 은행 이용 실적에 따른 추가 할인 서비스로 이동통신 시장에서 기존 사업자들을 긴장시키는 '메기'가 될 수 있을지 주목된다.리브M은 지난 4월 금융위원회에서 규제 특례를 적용받는 혁신금융서비스로 지정받으며 탄생할 수 있었다.
# "아파트 관리비 자동이체, KB국민카드 실적에 추가 할인을 모두 적용하면 LTE 일부 요금제는 무료, 5G 요금제는 7000원까지 낮출 수 있습니다.KB국민은행이 국내 최초로 출시하는 금융-통신 융합 모델의 알뜰폰 서비스 '리브M'의 주요 내용이 공개됐다.
# 문장 정확도는 10.07%         number:82
# 형태소 정확도는 31.25%         number:82
# 문장 최종 정확도는39.58%         number:82
# 형태소 최종 정확도는43.89%         number:82
# 보고서는 또 설문조사에 응한 영국 사무직 노동자의 50%가 눈, 49%가 등, 48%가 머리 부위의 고통을 호소했다고 밝혔다.보고서는 따라서 앉은 자세를 바로잡고, 더 많이 움직이고, 규칙적으로 걷기(산책) 휴식을 취하는 등 업무 환경을 확 바꾸지 않으면 사무실은 사람들을 환자로 만드는 장소가 될 것이라고 경고했다.
# 영국의 한 연구팀이 지금의 사무직 노동자들이 미래에 겪을 수도 있을 것으로 예측한 체형의 변화다.행동미래학자 윌리엄 하이암 박사가 이끄는 연구팀은 영국과 독일, 프랑스의 사무직 노동자 3천명을 대상으로 설문조사한 결과를 바탕으로, 지금의 업무 환경을 방치할 경우 사무직 노동자들이 20년 후 신체에 어떤 변화가 일어날지를 예측한 `미래의 직장동료' 보고서를 발표했다.
# 문장 정확도는 4.19%         number:83
# 형태소 정확도는 21.05%         number:83
# 문장 최종 정확도는39.15%         number:83
# 형태소 최종 정확도는43.61%         number:83
# 유튜버에게 ‘노란 딱지’의 핵심은 수익과 직결되는 광고의 게재 여부다.구글의 ‘노란 딱지’ 정책의 경우 억지로 콘텐츠를 막거나 차단하기 위해서 생긴 것이 아님을 주지해야 한다.
# 윤상직 자유한국당 의원이 24일 유튜브가 콘텐츠 약관 위반 시 붙이는 '노란 딱지'와 관련해 구글을 공정거래위원회에 고발했다.'노란 딱지' 발부와 관련해 정치적 편향성 의혹을 제기한 윤 의원은 "유튜브 내의 사업자와 관련된 사항이므로 공정거래법상 불공정거래 행위, 시장지배적 지위의 남용 등에 충분히 해당한다"라고 고발 이유를 설명했다.
# 문장 정확도는 9.09%         number:84
# 형태소 정확도는 12.90%         number:84
# 문장 최종 정확도는38.79%         number:84
# 형태소 최종 정확도는43.25%         number:84
# 카카오가 포털서비스 다음의 연예뉴스 댓글 서비스를 폐지하기로 해 포털업계 1위 네이버로 관심이 쏠리고 있다.27일 정보기술(IT) 업계에 따르면 카카오는 지난 25일 오후 1시부터 카카오톡 내 샵 검색의 '실시간 이슈 검색어' 서비스를 중단했다.
# 카카오가 포털서비스 다음의 연예뉴스 댓글 서비스를 폐지하기로 해 포털업계 1위 네이버로 관심이 쏠리고 있다.네이버 역시 '악성 댓글'이나 '실시간 검색어 조작 논란'에서 자유롭지 않은 만큼 자정에 나서야 한다는 요구가 높아지는 형국이다.
# 문장 정확도는 55.02%         number:85
# 형태소 정확도는 58.62%         number:85
# 문장 최종 정확도는38.98%         number:85
# 형태소 최종 정확도는43.43%         number:85
# LG전자는 광고에서 한발 더 나아가, 지난달 20일에는 "삼성전자 QLED TV 광고가 사실과 다른 허위·과장된 내용을 담고 있다"며 공정위에 신고했다.삼성전자는 최초 무대응 전략으로 나섰지만, 최근 들어선 맞불을 놓고 있다.
# LG전자가 삼성전자 QLED TV를 향한 두번째 '저격 광고'를 내놨다.지난 9월초 내놓은 첫 광고를 삼성전자가 공정거래위원회에 제소했지만 아랑곳하지 않는 행보다.
# 문장 정확도는 29.49%         number:86
# 형태소 정확도는 30.00%         number:86
# 문장 최종 정확도는38.87%         number:86
# 형태소 최종 정확도는43.27%         number:86
# 25일 출시된 아이폰11 시리즈의 첫날 개통량이 전작인 아이폰XS·XR 시리즈보다 30%가량 높게 나타났다.전날 통신 3사 번호이동 건수는 2만7천여건으로 전작(2만8천753건)을 다소 밑돌았다.
# 25일 출시된 아이폰11 시리즈의 첫날 개통량이 전작인 아이폰XS·XR 시리즈보다 30%가량 높게 나타났다.26일 이동통신업계에 따르면 전날 시작된 아이폰11 시리즈의 개통량은 13만∼14만대로 추산된다.
# 문장 정확도는 62.78%         number:87
# 형태소 정확도는 55.56%         number:87
# 문장 최종 정확도는39.15%         number:87
# 형태소 최종 정확도는43.41%         number:87
# 매일 출퇴근을 하는 정기통근자(월 44회 이용)의 경우 현재 1만3200원까지 적립할 수 있었으나 이번 마일리지 확대로 최대 1만9800원까지 적립할 수 있게 됐다.국토부는 올해 6월부터 진행 중인 광역알뜰교통카드 시범사업 대상지역도 현재 부산·인천 등 11개 지역에서 대구, 광주, 서울지역(종로구, 서초구, 강남구)으로 추가 확대할 계획이다.
# 광역알뜰교통카드를 활용한 보행·자전거 마일리지 적립 혜택이 확대된다.국토교통부 대도시권광역교통위원회는 이달부터 광역알뜰교통카드 이용자들의 마일리지 혜택을 1회당 300원에서 350~450원으로 확대한다고 5일 밝혔다.
# 문장 정확도는 14.01%         number:88
# 형태소 정확도는 20.59%         number:88
# 문장 최종 정확도는38.86%         number:88
# 형태소 최종 정확도는43.15%         number:88
# 26일 이동통신업계에 따르면 출시 첫날 아이폰11 시리즈 개통량은 13만~14만대로, 전작에 비해 30%가량 높은 것으로 나타났다.전날(25일) 국내에 공식 출시된 아이폰11 시리즈가 첫 테이프를 성공적으로 끊었다.
# 전날 국내에 공식 출시된 아이폰11 시리즈가 첫 테이프를 성공적으로 끊었다.26일 이동통신업계에 따르면 출시 첫날 아이폰11 시리즈 개통량은 13만~14만대로, 전작에 비해 30%가량 높은 것으로 나타났다.
# 문장 정확도는 62.13%         number:89
# 형태소 정확도는 100.00%         number:89
# 문장 최종 정확도는39.12%         number:89
# 형태소 최종 정확도는43.79%         number:89
# 이후 네이버는 전국 지자체를 대상으로 공모를 실시해 지난달 30일 세종(2곳), 경북 구미시, 경북 김천시, 대구, 대전, 부산, 충북 음성군, 경기 평택시(2곳) 등 10곳을 제2 데이터센터 후보 부지로 선정했다.제2 데이터센터의 면적은 ‘각’보다 2배 가까이 큰 10만㎡(3만250평), 지상층 연면적은 5배 가까이 큰 25만㎡(7만5,625평)이 될 예정이다.
# 네이버는 제2 데이터센터 우선 협상 대상 부지로 세종특별자치시를 선정했다고 25일 밝혔다.네이버는 당초 경기도 용인시 기흥구에 제2 데이터센터를 건립하려고 했지만 주민 반대로 지난 6월 철회했다.
# 문장 정확도는 24.28%         number:90
# 형태소 정확도는 31.88%         number:90
# 문장 최종 정확도는38.96%         number:90
# 형태소 최종 정확도는43.66%         number:90
# ‘노(No) 재팬’ 운동과 환율 상승, 경기 악화 등이 겹쳐 실적이 크게 나빠진 영향으로 저비용항공사(LCC) 이스타항공이 매물로 나왔다는 내용이다.이번주 한경닷컴에서 가장 많이 본 기사는 10월 18일자 <이스타항공 매물로 나왔다…‘이륙’ 12년 만에 ‘No 재팬’ 유탄>이었다.
# 이번주 페이스북에서 가장 많이 공유된 기사는 10월 21일자 <"맛집은 골목에" "동남아 갈 땐 달러 신권을"…여행 '꿀팁' 대방출>이었다.지난 20일 막을 내린 국내 유일의 도심 여행문화축제 '여행페스타 2019'를 소개한 기사다.
# 문장 정확도는 23.00%         number:91
# 형태소 정확도는 14.55%         number:91
# 문장 최종 정확도는38.78%         number:91
# 형태소 최종 정확도는43.34%         number:91
# 갤럭시 폴드가 안으로 접는 '인폴딩'인 반면, 메이트X는 밖으로 접는 '아웃폴딩' 폴더블 스마트폰이다.메이트X는 접었을 때 위쪽 디스플레이가 16.76㎝(6.6인치), 뒤쪽 디스플레이가 16.15㎝(6.36인치)다.
# 삼성전자가 폴더블 스마트폰 '갤럭시 폴드'를 중국에 출시하기로 하면서 화웨이의 '메이트X'와 맞붙는다.삼성전자는 4일 중국판 트위터 '웨이보'를 통해 오는 8일 갤럭시 폴드를 중국에 출시한다고 밝혔다.
# 문장 정확도는 18.97%         number:92
# 형태소 정확도는 27.91%         number:92
# 문장 최종 정확도는38.57%         number:92
# 형태소 최종 정확도는43.17%         number:92
# 25일 KT, SK텔링크, LG유플러스에 따르면 내달 30일까지 삼성전자의 신형폰을 구매하는 소비자를 위해 중고폰 특별보상 프로그램을 시행한다.자급제 모델 기준 아이폰11은 99만~120만원, 아이폰11 프로는 139만~187만원, 아이폰11 프로 맥스는 155만~203만원이다.
# 삼성전자가 애플의 신형 아이폰11 시리즈 출시에 대항하기 위해 이동통신3사와 갤럭시노트10, 갤럭시S10 등의 중고폰 특별보상 프로그램에 돌입한다.25일 KT, SK텔링크, LG유플러스에 따르면 내달 30일까지 삼성전자의 신형폰을 구매하는 소비자를 위해 중고폰 특별보상 프로그램을 시행한다.
# 문장 정확도는 50.31%         number:93
# 형태소 정확도는 54.84%         number:93
# 문장 최종 정확도는38.70%         number:93
# 형태소 최종 정확도는43.30%         number:93
# 이런 문제로 화웨이는 지난 9월 중국에서 판매하기 시작한 플래그십 스마트폰인 메이트 30도 유럽 등 해외 시장에서 판매하지 못하고 있다.화웨이는 작년보다 두 달 더 빨리 연간 2억대 판매 목표를 달성했다.
# 중국 스마트폰 제조사 화웨이가 내달 15일부터 첫 폴더블폰인 메이트X를 중국 시장에서 판매하지만 당분간 해외 시장에서는 판매하지 않기로 했다.24일 경제지 차이신에 따르면 허강 화웨이 스마트폰 부문 총재는 중국 시장 수요를 충족하기에도 부족해 현재로서는 메이트X의 해외 출시 계획이 없다고 밝혔다.
# 문장 정확도는 23.57%         number:94
# 형태소 정확도는 29.03%         number:94
# 문장 최종 정확도는38.53%         number:94
# 형태소 최종 정확도는43.15%         number:94
# LG전자는 미국에서 판매 중인 대부분의 하이센스 TV 제품이 LG전자가 보유한 특허를 침해했다며 특허침해금지 및 손해배상청구소송을 냈다."사용자 인터페이스 개선을 위한 기술 등 특허 4건 침해"
# LG전자가 4일 미국 캘리포니아지방법원에 '하이센스'를 상대로 TV 관련 특허침해금지소송을 제기했다.LG전자는 미국에서 판매 중인 대부분의 하이센스 TV 제품이 LG전자가 보유한 특허를 침해했다며 특허침해금지 및 손해배상청구소송을 냈다.
# 문장 정확도는 25.83%         number:95
# 형태소 정확도는 68.97%         number:95
# 문장 최종 정확도는38.40%         number:95
# 형태소 최종 정확도는43.42%         number:95
# 개천절에 찾아온 10월 태풍 '미탁'의 영향으로 지난달 전국에 내린 비의 양이 관측 이후 가장 많았던 것으로 나타났습니다.첫 서리는 지난달 27일 서울과 수원, 북춘천에서 관측됐는데, 서울의 경우 지난해보다 15일 늦었고 평년보다 하루 늦었다고 기상청은 밝혔습니다.
# 개천절에 찾아온 10월 태풍 '미탁'의 영향으로 지난달 전국에 내린 비의 양이 관측 이후 가장 많았던 것으로 나타났습니다.기상청은 지난달 1일부터 3일 사이에 '미탁'이 우리나라를 지나며 10월 전국 평균 강수량이 169㎜로 평년보다 3~5배 정도 많았다고 분석했습니다.
# 문장 정확도는 60.20%         number:96
# 형태소 정확도는 60.38%         number:96
# 문장 최종 정확도는38.63%         number:96
# 형태소 최종 정확도는43.59%         number:96
# "처음에는 플레이키보드에 바른말 키패드 사업모델을 접목해보려고 했어요. 그런데 10대들은 귀엽고 깜찍한 캐릭터나 연예인을 더 좋아하더라구요. 움직이는 캐릭터나 연예인을 키보드에 녹여보면 어떨까 생각했죠."플레이키보드 이용자 대다수는 10대 여성. 안 대표는 사용자들이 어떤 서비스를 좋아할지부터 연구했다.
# 모바일 키보드를 캐릭터나 연예인으로 꾸밀 수 있는 앱 '플레이키보드'를 서비스하는 스타트업 비트바이트 안서형 대표의 포부다.플레이키보드는 10대 엄지족 사이에서 입소문을 제대로 탄 앱이다.
# 문장 정확도는 18.91%         number:97
# 형태소 정확도는 35.71%         number:97
# 문장 최종 정확도는38.42%         number:97
# 형태소 최종 정확도는43.51%         number:97
# LG전자가 지난 1일 북미 시장에 출시한 'LG G8X 씽큐(국내명 LG V50S)와 'LG 듀얼 스크린'에 대한 외신의 호평이 이어지고 있다.포브스는 “G8의 뛰어난 멀티태스킹 능력은 미니 노트북처럼 사용할 수 있을 정도로 뛰어나다”며 “실용적이고 합리적인 가격에 내구성까지 갖춘 제품”이라고 극찬했다.
# LG전자가 지난 1일 북미 시장에 출시한 'LG G8X 씽큐와 'LG 듀얼 스크린'에 대한 외신의 호평이 이어지고 있다.포브스는 "G8의 뛰어난 멀티태스킹 능력은 미니 노트북처럼 사용할 수 있을 정도로 뛰어나다"며 "실용적이고 합리적인 가격에 내구성까지 갖춘 제품"이라고 극찬했다.
# 문장 정확도는 93.58%         number:98
# 형태소 정확도는 98.18%         number:98
# 문장 최종 정확도는38.99%         number:98
# 형태소 최종 정확도는44.07%         number:98
# 또 고양선 새절역∼고양시청 구간은 광역교통개선 분담금으로 추진하고, 고양선을 일산 식사지구까지 추가 연장하는 방안은 추후 검토 과제로 정했다.현재 추진 중인 GTX-A는 오는 2023년까지 계획대로 개통하기로 했다.
# 인천2호선의 연장 노선이 기존 경의중앙선 일산역에서 탄현역까지로 늘어나는 등 1기신도시 일산의 교통문제를 해결하기 위한 방안이 본격 추진된다.31일 국토교통부 대도시권광역교통위원회의 '비전 2030'에 따르면 인천2호선 연장안이 기존 일산역에서 탄현역까지로 추가 조정됐다.
# 문장 정확도는 15.44%         number:99
# 형태소 정확도는 25.40%         number:99
# 문장 최종 정확도는38.75%         number:99
# 형태소 최종 정확도는43.88%         number:99
# 신세계인터내셔날은 미디어 커머스 채널 '먼데이박스'를 신규 론칭했다.영상 전문 스타트업 전문가들이 제작한 웹드라마, 웹예능, 콩트 등을 비롯해 아마추어가 제작한 영상, 일반 소비자들의 솔직한 제품 리뷰도 선보인다.
# 의류 및 패션 분야에서 '미디어 커머스' 온라인 채널 확보경쟁이 치열하다.온라인 쇼핑 규모는 최초로 110조원을 넘으며 2017년 온라인 쇼핑 규모 대비 약 22.6% 늘어났다.
# 문장 정확도는 19.27%         number:100
# 형태소 정확도는 12.24%         number:100
# 문장 최종 정확도는38.55%         number:100
# 형태소 최종 정확도는43.57%         number:100
# “광역급행철도(GTX) 수혜범위를 확대하기 위해 수도권 서부권 등에 신규 급행노선을 추가로 검토해 내년 하반기까지 확정·발표하겠습니다.김현미 장관은 “2030년까지 대도시권 철도망을 현재의 두 배 수준인 280㎞까지 확대하고 수도권 급행철도의 수혜인구는 77%까지 늘려 주요 거점 간의 통행시간을 30분대로 획기적으로 줄이겠다”고 말했다.
# "광역급행철도 수혜범위를 확대하기 위해 수도권 서부권 등에 신규 급행노선을 추가로 검토해 내년 하반기까지 확정·발표하겠습니다.수도권 서부권을 관통하는 광역급행철도 신규 노선을 내년 하반기 확정·발표한다.
# 문장 정확도는 54.30%         number:101
# 형태소 정확도는 57.14%         number:101
# 문장 최종 정확도는38.71%         number:101
# 형태소 최종 정확도는43.70%         number:101
# 콩크르정은 β-아드레날린수용체를 차단하는 베타차단제로 고혈압·협심증 치료와 좌심실 수축기능이 저하된 안전형 만성 심부전 치료 적응증을 가지고 있다.한국머크 바이오파마는 대웅제약과 자사 심혈관 질환 치료제 브랜드인 콩코르의 국내 판매 계약을 체결했다고 5일 밝혔다.
# 한국머크 바이오파마는 대웅제약과 자사 심혈관 질환 치료제 브랜드인 콩코르의 국내 판매 계약을 체결했다고 5일 밝혔다.이번 계약으로 대웅제약은 2020년부터 해당 제품의 의료진 대상 프로모션 및 세일즈 인력 운영 등의 영업활동을 전담하게 된다.
# 문장 정확도는 46.10%         number:102
# 형태소 정확도는 49.32%         number:102
# 문장 최종 정확도는38.78%         number:102
# 형태소 최종 정확도는43.76%         number:102
# ‘8-플라워 골든 넥타 오일’은 전 세계를 걸쳐 혼합된 8가지 꽃(진귀한 임모르텔, 일랑 일랑, 패츌리, 네롤리, 로즈, 라벤더, 쟈스민, 아이리스)들의 추출물이 함유되어 있다.프랑스 스파 브랜드 달팡(DARPHIN)이 신제품 ‘8-플라워 골든 넥타 오일’을 출시했다고 밝혔다.
# 프랑스 스파 브랜드 달팡이 신제품 '8-플라워 골든 넥타 오일'을 출시했다고 밝혔다.'8-플라워 골든 넥타 오일'은 전 세계를 걸쳐 혼합된 8가지 꽃들의 추출물이 함유되어 있다.
# 문장 정확도는 26.77%         number:103
# 형태소 정확도는 81.48%         number:103
# 문장 최종 정확도는38.67%         number:103
# 형태소 최종 정확도는44.12%         number:103
# 캐시슬라이드는 5일 안다르와 함께 "올 겨울 필수템, 피치레깅스 오늘만 ㅇㅁㅇㅊㅇ"란 초성퀴즈를 냈다.검색창에 '안다르 피치레깅스 대란'을 검색하면 힌트를 얻을 수 있다.
# 캐시슬라이드가 '안다르 피치레깅스 대란' 초성퀴즈를 출제했다.캐시슬라이드는 5일 안다르와 함께 "올 겨울 필수템, 피치레깅스 오늘만 ㅇㅁㅇㅊㅇ"란 초성퀴즈를 냈다.
# 문장 정확도는 61.29%         number:104
# 형태소 정확도는 74.29%         number:104
# 문장 최종 정확도는38.88%         number:104
# 형태소 최종 정확도는44.41%         number:104
# 5일 토스 행운 퀴즈로 '하나멤버스100만원' 관련 퀴즈가 출제되어 화제를 모으고 있다.출제자 측은 포털 사이트에 '시몬스 난연 매트리스'를 검색하면 힌트를 찾을 수 있다고 전했다.
# 토스 행운 퀴즈로 '하나멤버스100만원' 관련 문제가 출제됐다.5일 토스 행운 퀴즈로 '하나멤버스100만원' 관련 퀴즈가 출제되어 화제를 모으고 있다.
# 문장 정확도는 49.73%         number:105
# 형태소 정확도는 51.28%         number:105
# 문장 최종 정확도는38.99%         number:105
# 형태소 최종 정확도는44.48%         number:105
# 티웨이항공은 4일부터 전용 간편 결제 서비스인 '티웨이 페이'를 실시한다고 밝혔다.항공권 구매 시 여행자 보험까지 간편하게 가입할 수 있는 원클릭 여행자 보험 서비스도 운영하고 있다.
# 티웨이항공은 4일부터 전용 간편 결제 서비스인 '티웨이 페이'를 실시한다고 밝혔다.티웨이 페이는 전용 간편 결제 시스템으로 자주 쓰는 결제 카드를 사전에 등록해두면 결제 시마다 추가로 정보를 입력할 필요 없이 편리하게 사용할 수 있다.
# 문장 정확도는 50.64%         number:106
# 형태소 정확도는 40.82%         number:106
# 문장 최종 정확도는39.10%         number:106
# 형태소 최종 정확도는44.44%         number:106
# 출제된 퀴즈는 "홈랩에서 출시한 어린이집 낮잠용 이불의 풀네임은? ㄱㅈㅂㄷㅋㅈㅅㅌ"이며, 초성 부분을 맞추는 문제다.'박나래 기절토퍼 반값' 퀴즈는 리브메이트 보고쌓기, 엘포인트의 모아락, 현대포인트의 H.락, KT의 클립 잠금화면, CJ ONE의 원더락, 해피스크린, 허니스크린 등에서 참여 가능하다.
# 박나래 기절토퍼 반값' 관련 퀴즈가 출제돼 화제다.5일 버즈빌 계열 리워드 앱에서는 '박나래 기절토퍼 반값' 관련 퀴즈가 출제됐다.
# 문장 정확도는 19.83%         number:107
# 형태소 정확도는 25.00%         number:107
# 문장 최종 정확도는38.92%         number:107
# 형태소 최종 정확도는44.26%         number:107
# 오리온은 기존 판형 웨하스의 가격을 인하해 가성비를 높인 ‘오리온 웨하스’를 출시한다고 5일 밝혔다.오리온 관계자는 “소비자 만족도를 높이기 위해 그램당 가격을 인하한 실속형 웨하스를 선보이게 됐다”며 “앞으로도 가격 대비 만족도가 높은 제품들을 지속적으로 제공할 예정”이라고 말했다.
# 오리온은 기존 판형 웨하스의 가격을 인하해 가성비를 높인 '오리온 웨하스'를 출시한다고 5일 밝혔다.오리온 웨하스는 가성비 트렌드에 발맞춰 소비자들이 부담 없이 구매할 수 있도록 60g 규격을 편의점가 기준 900원에 선보인다.
# 문장 정확도는 50.35%         number:108
# 형태소 정확도는 52.63%         number:108
# 문장 최종 정확도는39.02%         number:108
# 형태소 최종 정확도는44.34%         number:108
# 몽벨의 보이기 위한 화려함 보다는 품질 우선의 제품을 만드는 브랜드 정신에 커버낫의 유니크한 제품을 녹여 아웃도어와 캐주얼의 벽을 넘나드는 새로운 제품을 만들어냈다.커버낫과 몽벨의 협업으로 선보이는 제품은 프리미엄 구스다운인 헝가리 구스다운을 사용한 숏 패딩, 보아 자켓, 보아 베스트, 플리스 크루넥, 캡, 럭색 총 6가지 이다.
# ...
# 25일 출시된 아이폰11 시리즈의 첫날 개통량이 전작인 아이폰XS·XR 시리즈보다 30%가량 높게 나타났다.26일 이동통신업계에 따르면 전날 시작된 아이폰11 시리즈의 개통량은 13만∼14만대로 추산된다.
# 문장 정확도는 62.78%         number:154
# 형태소 정확도는 55.56%         number:154
# 문장 최종 정확도는39.83%         number:154
# 형태소 최종 정확도는44.92%         number:154
# 서적 유통업체 예스24(대표 김석환)는 자체 블록체인 플랫폼 'sey체인' 메인넷을 론칭했다고 5일 밝혔다.예스24는 메인넷 개발과 함께 sey체인을 기반으로 한 암호화폐 'sey'코인을 출시함에 따라 플랫폼 참여자들과 이익을 공유하기 위한 각종 활용방안을 모색한다.
# 서적 유통업체 예스24는 자체 블록체인 플랫폼 'sey체인' 메인넷을 론칭했다고 5일 밝혔다.sey체인은 지난 2018년 8월 이더리움 ERC-20 기반으로 가상화폐 sey토큰을 론칭한 예스24가 독자적인 블록체인 생태계 구축을 목표로 개발했으며 파트너사들과 함께 운영할 수 있는 컨소시엄형 메인넷을 지향한다.
# 문장 정확도는 49.69%         number:155
# 형태소 정확도는 45.45%         number:155
# 문장 최종 정확도는39.90%         number:155
# 형태소 최종 정확도는44.93%         number:155
# 26일 이동통신업계에 따르면 출시 첫날 아이폰11 시리즈 개통량은 13만~14만대로, 전작에 비해 30%가량 높은 것으로 나타났다.전날(25일) 국내에 공식 출시된 아이폰11 시리즈가 첫 테이프를 성공적으로 끊었다.
# 전날 국내에 공식 출시된 아이폰11 시리즈가 첫 테이프를 성공적으로 끊었다.26일 이동통신업계에 따르면 출시 첫날 아이폰11 시리즈 개통량은 13만~14만대로, 전작에 비해 30%가량 높은 것으로 나타났다.
# 문장 정확도는 62.13%         number:156
# 형태소 정확도는 100.00%         number:156
# 문장 최종 정확도는40.04%         number:156
# 형태소 최종 정확도는45.28%         number:156
# 이후 네이버는 전국 지자체를 대상으로 공모를 실시해 지난달 30일 세종(2곳), 경북 구미시, 경북 김천시, 대구, 대전, 부산, 충북 음성군, 경기 평택시(2곳) 등 10곳을 제2 데이터센터 후보 부지로 선정했다.제2 데이터센터의 면적은 ‘각’보다 2배 가까이 큰 10만㎡(3만250평), 지상층 연면적은 5배 가까이 큰 25만㎡(7만5,625평)이 될 예정이다.
# 네이버는 제2 데이터센터 우선 협상 대상 부지로 세종특별자치시를 선정했다고 25일 밝혔다.네이버는 당초 경기도 용인시 기흥구에 제2 데이터센터를 건립하려고 했지만 주민 반대로 지난 6월 철회했다.
# 문장 정확도는 24.28%         number:157
# 형태소 정확도는 31.88%         number:157
# 문장 최종 정확도는39.94%         number:157
# 형태소 최종 정확도는45.20%         number:157
# ‘노(No) 재팬’ 운동과 환율 상승, 경기 악화 등이 겹쳐 실적이 크게 나빠진 영향으로 저비용항공사(LCC) 이스타항공이 매물로 나왔다는 내용이다.이번주 한경닷컴에서 가장 많이 본 기사는 10월 18일자 <이스타항공 매물로 나왔다…‘이륙’ 12년 만에 ‘No 재팬’ 유탄>이었다.
# 이번주 페이스북에서 가장 많이 공유된 기사는 10월 21일자 <"맛집은 골목에" "동남아 갈 땐 달러 신권을"…여행 '꿀팁' 대방출>이었다.지난 20일 막을 내린 국내 유일의 도심 여행문화축제 '여행페스타 2019'를 소개한 기사다.
# 문장 정확도는 23.00%         number:158
# 형태소 정확도는 14.55%         number:158
# 문장 최종 정확도는39.83%         number:158
# 형태소 최종 정확도는45.00%         number:158
# 갤럭시 폴드가 안으로 접는 '인폴딩'인 반면, 메이트X는 밖으로 접는 '아웃폴딩' 폴더블 스마트폰이다.메이트X는 접었을 때 위쪽 디스플레이가 16.76㎝(6.6인치), 뒤쪽 디스플레이가 16.15㎝(6.36인치)다.
# 삼성전자가 폴더블 스마트폰 '갤럭시 폴드'를 중국에 출시하기로 하면서 화웨이의 '메이트X'와 맞붙는다.삼성전자는 4일 중국판 트위터 '웨이보'를 통해 오는 8일 갤럭시 폴드를 중국에 출시한다고 밝혔다.
# 문장 정확도는 18.97%         number:159
# 형태소 정확도는 27.91%         number:159
# 문장 최종 정확도는39.70%         number:159
# 형태소 최종 정확도는44.89%         number:159
# 25일 KT, SK텔링크, LG유플러스에 따르면 내달 30일까지 삼성전자의 신형폰을 구매하는 소비자를 위해 중고폰 특별보상 프로그램을 시행한다.자급제 모델 기준 아이폰11은 99만~120만원, 아이폰11 프로는 139만~187만원, 아이폰11 프로 맥스는 155만~203만원이다.
# 삼성전자가 애플의 신형 아이폰11 시리즈 출시에 대항하기 위해 이동통신3사와 갤럭시노트10, 갤럭시S10 등의 중고폰 특별보상 프로그램에 돌입한다.25일 KT, SK텔링크, LG유플러스에 따르면 내달 30일까지 삼성전자의 신형폰을 구매하는 소비자를 위해 중고폰 특별보상 프로그램을 시행한다.
# 문장 정확도는 50.31%         number:160
# 형태소 정확도는 54.84%         number:160
# 문장 최종 정확도는39.77%         number:160
# 형태소 최종 정확도는44.96%         number:160
# 이런 문제로 화웨이는 지난 9월 중국에서 판매하기 시작한 플래그십 스마트폰인 메이트 30도 유럽 등 해외 시장에서 판매하지 못하고 있다.화웨이는 작년보다 두 달 더 빨리 연간 2억대 판매 목표를 달성했다.
# 중국 스마트폰 제조사 화웨이가 내달 15일부터 첫 폴더블폰인 메이트X를 중국 시장에서 판매하지만 당분간 해외 시장에서는 판매하지 않기로 했다.24일 경제지 차이신에 따르면 허강 화웨이 스마트폰 부문 총재는 중국 시장 수요를 충족하기에도 부족해 현재로서는 메이트X의 해외 출시 계획이 없다고 밝혔다.
# 문장 정확도는 23.57%         number:161
# 형태소 정확도는 29.03%         number:161
# 문장 최종 정확도는39.67%         number:161
# 형태소 최종 정확도는44.86%         number:161
# 경찰에 따르면 서울지방경찰청 사이버안전과는 이날 오전 서울 마포구 상암동 CJ ENM 사무실에 수사관들을 보내 관련 자료를 추가로 확보하고 있다.앞서 이날 오전 10시 30분부터 시작된 프듀X 프로그램 담당 안준영 PD와 연예기획사 관계자 등 4명에 대한 구속 전 피의자 심문(영장실질심사)은 2시간여 만인 오후 1시께 종료됐다.
# '프로듀스X 101' 등 엠넷의 오디션 프로그램 생방송 투표 조작 의혹을 수사하는 경찰이 5일 CJ ENM을 압수수색하고 있다.경찰에 따르면 서울지방경찰청 사이버안전과는 이날 오전 서울 마포구 상암동 CJ ENM 사무실에 수사관들을 보내 관련 자료를 추가로 확보하고 있다.
# 문장 정확도는 48.21%         number:162
# 형태소 정확도는 53.52%         number:162
# 문장 최종 정확도는39.72%         number:162
# 형태소 최종 정확도는44.91%         number:162
# 박 차관은 이번 실태조사로 "고교서열이 확인됐다"면서 추가조사와 특정감사를 통해 고교서열이 대학의 '고교등급제' 탓에 발생했는지 확인하겠다고 밝혔다.박백범 교육부 차관은 5일 서울대 등 13개 대학 학생부종합전형(학종) 실태조사 결과를 발표하면서 "학종은 배점 기준 등이 사전에 공개되지 않아 '깜깜이 전형'이 되고 있다"고 말했다.
# 박백범 교육부 차관은 5일 서울대 등 13개 대학 학생부종합전형 실태조사 결과를 발표하면서 "학종은 배점 기준 등이 사전에 공개되지 않아 '깜깜이 전형'이 되고 있다"고 말했다.박 차관은 이번 실태조사로 "고교서열이 확인됐다"면서 추가조사와 특정감사를 통해 고교서열이 대학의 '고교등급제' 탓에 발생했는지 확인하겠다고 밝혔다.
# 문장 정확도는 45.11%         number:163
# 형태소 정확도는 99.01%         number:163
# 문장 최종 정확도는39.75%         number:163
# 형태소 최종 정확도는45.24%         number:163
# 5일 업계에 따르면 올해 10월 말 부산 동구 범일교차로 인근 요지에 새로 문을 열 예정이던 부산의 14번째 유니클로 매장이 올해 12월로 개장을 잠정 연기했다.개장 연기에 가장 큰 영향을 준 것은 인근 재래시장 상인 반발과 일본제품 불매운동으로 꼽힌다.
# 일본 수출규제에 따른 불매운동 대상이 된 유니클로가 부산지역 신규 매장 개장을 두고 전전긍긍하고 있다.5일 업계에 따르면 올해 10월 말 부산 동구 범일교차로 인근 요지에 새로 문을 열 예정이던 부산의 14번째 유니클로 매장이 올해 12월로 개장을 잠정 연기했다.
# 문장 정확도는 62.28%         number:164
# 형태소 정확도는 69.84%         number:164
# 문장 최종 정확도는39.89%         number:164
# 형태소 최종 정확도는45.39%         number:164
# 고등학교들이 학생부종합전형(학종)을 위해 대학에 제출하는 '고교 프로파일'(공통고교정보)이 어학성적·소논문 등 학교생활기록부에 기재가 금지된 '스펙'을 제출하는 간접 창구로 활용된 것으로 드러났다.이런 원클릭 시스템을 가진 5개 대학의 지원자 1명당 평균 서류 평가 시간을 보니, 가장 시간이 짧은 대학은 평균 8.66분에 불과했다.
# 고등학교들이 학생부종합전형을 위해 대학에 제출하는 '고교 프로파일'이 어학성적·소논문 등 학교생활기록부에 기재가 금지된 '스펙'을 제출하는 간접 창구로 활용된 것으로 드러났다.5일 교육부에 따르면, 전국 고등학교 2천216곳 가운데 37.9%인 840곳이 한국대학교육협의회에 고교 프로파일을 제출하면서 대교협이 요구하는 필수정보 외에 추가 자료를 입력했다.
# 문장 정확도는 55.06%         number:165
# 형태소 정확도는 59.09%         number:165
# 문장 최종 정확도는39.98%         number:165
# 형태소 최종 정확도는45.48%         number:165
# 교보문고와 대산문화재단은 5일 "한국 독자와 세계 작가의 접점을 확장하기 위해 '세계 작가와의 대화'를 시작한다"며 "첫 작가로 옌롄커를 초청한다"고 밝혔다.옌롄커는 이달 12일 오후 7시30분 서울 광화문 교보빌딩 23층 교보컨벤션홀에서 '침묵과 한숨 - 내가 경험한 중국과 문학'을 주제로 강연을 펼친다.
# 중국에서 '가장 폭발력 있는 작가', '가장 문제적인 작가' 등으로 불리는 옌롄커가 한국을 방문해 강연을 펼친다.교보문고와 대산문화재단은 5일 "한국 독자와 세계 작가의 접점을 확장하기 위해 '세계 작가와의 대화'를 시작한다"며 "첫 작가로 옌롄커를 초청한다"고 밝혔다.
# 문장 정확도는 54.49%         number:166
# 형태소 정확도는 66.67%         number:166
# 문장 최종 정확도는40.07%         number:166
# 형태소 최종 정확도는45.60%         number:166
# 이어 "KBS의 재난주관방송사 관련 예산인 20억원을 전액 삭감해야 한다"며 "방송통신위원회가 사실관계를 확인하고 추가 영상이 있는지 확인한 뒤 의혹을 자체 감사해서 보고해달라"고 요구했다.국회 과학기술정보방송통신위원회의 5일 전체회의에서는 KBS가 독도 헬기 사고 관련 영상을 보유한 사실을 숨기고 경찰의 공유 요청을 거절했다는 의혹이 도마 위에 올랐다.
# 국회 과학기술정보방송통신위원회의 5일 전체회의에서는 KBS가 독도 헬기 사고 관련 영상을 보유한 사실을 숨기고 경찰의 공유 요청을 거절했다는 의혹이 도마 위에 올랐다.특히 자유한국당을 비롯한 야당 의원들은 이번 사태를 '방송 참사'라고 규정하며 KBS의 재난주관방송사 관련 예산 삭감을 요구했다.
# 문장 정확도는 51.10%         number:167
# 형태소 정확도는 71.43%         number:167
# 문장 최종 정확도는40.14%         number:167
# 형태소 최종 정확도는45.76%         number:167
# 결국 당시 국토교통부를 중심으로 한 '플랫폼 택시' 관련 사회적 협의 진행상황을 전했을 뿐, 기소 방침을 미리 전달받거나 기소 여부에 대한 청와대의 의견을 검찰에 전달한 것은 아니라는 것이 이 관계자의 설명이다.실제로 김 실장은 지난달 30일 YTN '노종면의 더뉴스'에 출연해 검찰의 '타다' 기소에 대해 "저도 당혹감을 느꼈다"고 말했다.
# 검찰이 승차공유 서비스 '타다'에 대한 기소 방침을 청와대에 사전에 보고했다는 주장이 제기된 가운데, 청와대 측은 5일 "법무부와 청와대 정책실이 지난 7월에 타다 문제와 관련한 얘기를 나눈 것은 사실"이라는 설명을 내놨다.그러나 검찰의 '기소 방침'을 보고받거나 하지는 않았으며, 법무부와도 업무협의 과정에서 정상적으로 의견을 주고받았을 뿐이라고 청와대는 설명했다.
# 문장 정확도는 15.15%         number:168
# 형태소 정확도는 31.33%         number:168
# 문장 최종 정확도는39.99%         number:168
# 형태소 최종 정확도는45.67%         number:168
# '몸통시신 사건' 장대호 무기징역…"내 아들 살려내" 유족 오열의정부지법 고양지원 제1형사부(전국진 부장판사)는 이날 오전 10시 20분께 501호 법정에서 선고 공판을 열고 살인 및 사체손괴, 사체은닉 혐의로 구속기소된 장대호에게 무기징역을 선고했다.
# 이른바 '한강 몸통시신 사건'의 장대호에게 1심 법원이 5일 무기징역을 선고했다.의정부지법 고양지원 제1형사부는 이날 오전 10시 20분께 501호 법정에서 선고 공판을 열고 살인 및 사체손괴, 사체은닉 혐의로 구속기소된 장대호에게 무기징역을 선고했다.
# 문장 정확도는 80.85%         number:169
# 형태소 정확도는 81.69%         number:169
# 문장 최종 정확도는40.23%         number:169
# 형태소 최종 정확도는45.89%         number:169
# 피지로 신도 집단이주시켜 폭행한 목사, 항소심서 징역 7년재판부는 같은 혐의로 기소된 교회 관계자 4명에게는 징역 4월∼4년을 선고했다.
# 교회 신도들을 남태평양 피지로 이주시킨 뒤 이른바 '타작마당'이라는 이름의 종교의식을 앞세워 폭행한 목사가 항소심에서 1심보다 더 무거운 실형을 선고받았다.수원지법 형사항소8부는 5일 공동상해, 특수폭행, 중감금, 사기, 아동복지법 위반 등의 혐의로 기소된 목사 A 씨에게 징역 6년을 선고한 원심을 파기하고 징역 7년을 선고했다.
# 문장 정확도는 35.25%         number:170
# 형태소 정확도는 42.86%         number:170
# 문장 최종 정확도는40.20%         number:170
# 형태소 최종 정확도는45.87%         number:170
# LG전자는 미국에서 판매 중인 대부분의 하이센스 TV 제품이 LG전자가 보유한 특허를 침해했다며 특허침해금지 및 손해배상청구소송을 냈다."사용자 인터페이스 개선을 위한 기술 등 특허 4건 침해"
# LG전자가 4일 미국 캘리포니아지방법원에 '하이센스'를 상대로 TV 관련 특허침해금지소송을 제기했다.LG전자는 미국에서 판매 중인 대부분의 하이센스 TV 제품이 LG전자가 보유한 특허를 침해했다며 특허침해금지 및 손해배상청구소송을 냈다.
# 문장 정확도는 25.83%         number:171
# 형태소 정확도는 68.97%         number:171
# 문장 최종 정확도는40.12%         number:171
# 형태소 최종 정확도는46.00%         number:171
# 온라인 구매 증가 등에 힘입어 3분기 카드 승인액이 작년 같은 기간보다 소폭 늘어난 것으로 나타났다.올 7∼8월 화장품 판매액은 5조6천481억원으로 작년 동기 대비 17.2% 증가했고, 면세점 판매액은 4조1천994억원으로 31.8% 늘었다.
# 온라인 구매 증가 등에 힘입어 3분기 카드 승인액이 작년 같은 기간보다 소폭 늘어난 것으로 나타났다.5일 여신금융협회에 따르면 올 3분기 신용카드와 체크카드를 합한 전체 카드 승인액은 216조6천억원, 승인 건수는 56억4천만건이다.
# 문장 정확도는 54.14%         number:172
# 형태소 정확도는 57.78%         number:172
# 문장 최종 정확도는40.20%         number:172
# 형태소 최종 정확도는46.07%         number:172
# 개천절에 찾아온 10월 태풍 '미탁'의 영향으로 지난달 전국에 내린 비의 양이 관측 이후 가장 많았던 것으로 나타났습니다.첫 서리는 지난달 27일 서울과 수원, 북춘천에서 관측됐는데, 서울의 경우 지난해보다 15일 늦었고 평년보다 하루 늦었다고 기상청은 밝혔습니다.
# 개천절에 찾아온 10월 태풍 '미탁'의 영향으로 지난달 전국에 내린 비의 양이 관측 이후 가장 많았던 것으로 나타났습니다.기상청은 지난달 1일부터 3일 사이에 '미탁'이 우리나라를 지나며 10월 전국 평균 강수량이 169㎜로 평년보다 3~5배 정도 많았다고 분석했습니다.
# 문장 정확도는 60.20%         number:173
# 형태소 정확도는 60.38%         number:173
# 문장 최종 정확도는40.31%         number:173
# 형태소 최종 정확도는46.15%         number:173
# "처음에는 플레이키보드에 바른말 키패드 사업모델을 접목해보려고 했어요. 그런데 10대들은 귀엽고 깜찍한 캐릭터나 연예인을 더 좋아하더라구요. 움직이는 캐릭터나 연예인을 키보드에 녹여보면 어떨까 생각했죠."플레이키보드 이용자 대다수는 10대 여성. 안 대표는 사용자들이 어떤 서비스를 좋아할지부터 연구했다.
# 모바일 키보드를 캐릭터나 연예인으로 꾸밀 수 있는 앱 '플레이키보드'를 서비스하는 스타트업 비트바이트 안서형 대표의 포부다.플레이키보드는 10대 엄지족 사이에서 입소문을 제대로 탄 앱이다.
# 문장 정확도는 18.91%         number:174
# 형태소 정확도는 35.71%         number:174
# 문장 최종 정확도는40.19%         number:174
# 형태소 최종 정확도는46.09%         number:174
# LG전자가 지난 1일 북미 시장에 출시한 'LG G8X 씽큐(국내명 LG V50S)와 'LG 듀얼 스크린'에 대한 외신의 호평이 이어지고 있다.포브스는 “G8의 뛰어난 멀티태스킹 능력은 미니 노트북처럼 사용할 수 있을 정도로 뛰어나다”며 “실용적이고 합리적인 가격에 내구성까지 갖춘 제품”이라고 극찬했다.
# LG전자가 지난 1일 북미 시장에 출시한 'LG G8X 씽큐와 'LG 듀얼 스크린'에 대한 외신의 호평이 이어지고 있다.포브스는 "G8의 뛰어난 멀티태스킹 능력은 미니 노트북처럼 사용할 수 있을 정도로 뛰어나다"며 "실용적이고 합리적인 가격에 내구성까지 갖춘 제품"이라고 극찬했다.
# 문장 정확도는 93.58%         number:175
# 형태소 정확도는 98.18%         number:175
# 문장 최종 정확도는40.49%         number:175
# 형태소 최종 정확도는46.39%         number:175
# 한편, 황 대표는 장내 열기가 고조되며 일부 참석자가 문재인 대통령을 향해 'XXX'라며 거친 발언을 하자 "지금 상중이니 그런 말씀은 하지 말라"고 제지하기도 했다.황 대표는 "우리가 똘똘 뭉쳐 싸워야 할 적이 옆에 선 우리 동지이냐. 나와 경선하는 우리 동지가 내 적이냐"며 "우리는 선한 경쟁자다.
# 자유한국당 황교안 대표는 2일 "싸우다 보면 이길 수도, 실수할 수도 있다.이길 때만 박수치고 실수한다고 뒤에서 총질할 것이냐"고 말했다.황 대표는 이날 오후 경남 창원 마산합포구청 대강당에서 열린 '고위공직자범죄수사처법 저지 및 국회의원 정수 축소 촉구 좌파독재 실정 보고대회'에 참석, 강연을 통해 "내부 총질은 하지 말아야 하지 않겠나"라며 이같이 밝혔다.황 대표는 "우리가 똘똘 뭉쳐 싸워야 할 적이 옆에 선 우리 동지이냐.나와 경선하는 우리 동지가 내 적이냐"며 "우리는 선한 경쟁자다.우리 상대는 문재인 정권"이라고 강조했다.
# 문장 정확도는 10.23%         number:176
# 형태소 정확도는 42.72%         number:176
# 문장 최종 정확도는40.32%         number:176
# 형태소 최종 정확도는46.37%         number:176
# 온라인 서점 예스24는 책을 사랑하는 독자들이 직접 선택하는 ‘제17회 올해의 책·올해의 커버’ 투표를 11월 4일부터 12월 5일까지 진행한다.출판사 편집자, 디자이너 등의 추천을 받은 64권의 책 표지 중 독자들이 2종부터 최대 5종까지 선택하면, 득표 순으로 올해의 커버 10종이 선정된다.
# 온라인 서점 예스24는 책을 사랑하는 독자들이 직접 선택하는 '제17회 올해의 책·올해의 커버' 투표를 11월 4일부터 12월 5일까지 진행한다.소설, 시·에세이, 인문·교양, 경제경영, 자기계발, 유아동·청소년, 가정·취미·실용, 만화·예술 등 8개 분야 총 232권의 후보작 중 독자들이 4개 이상의 분야에서 선택한 4권에서 최대 10권까지의 작품 중 가장 많은 표를 받은 상위 24권이 '올해의 책'으로 선정된다.
# 문장 정확도는 52.63%         number:177
# 형태소 정확도는 52.75%         number:177
# 문장 최종 정확도는40.39%         number:177
# 형태소 최종 정확도는46.41%         number:177
# 한편, 황 대표는 장내 열기가 고조되며 일부 참석자가 문재인 대통령을 향해 'XXX'라며 거친 발언을 하자 "지금 상중이니 그런 말씀은 하지 말라"고 제지하기도 했다.황 대표는 "우리가 똘똘 뭉쳐 싸워야 할 적이 옆에 선 우리 동지이냐. 나와 경선하는 우리 동지가 내 적이냐"며 "우리는 선한 경쟁자다.
# 자유한국당 황교안 대표는 2일 "싸우다 보면 이길 수도, 실수할 수도 있다.이길 때만 박수치고 실수한다고 뒤에서 총질할 것이냐"고 말했다.황 대표는 이날 오후 경남 창원 마산합포구청 대강당에서 열린 '고위공직자범죄수사처법 저지 및 국회의원 정수 축소 촉구 좌파독재 실정 보고대회'에 참석, 강연을 통해 "내부 총질은 하지 말아야 하지 않겠나"라며 이같이 밝혔다.황 대표는 "우리가 똘똘 뭉쳐 싸워야 할 적이 옆에 선 우리 동지이냐.나와 경선하는 우리 동지가 내 적이냐"며 "우리는 선한 경쟁자다.우리 상대는 문재인 정권"이라고 강조했다.
# 문장 정확도는 10.23%         number:178
# 형태소 정확도는 42.72%         number:178
# 문장 최종 정확도는40.22%         number:178
# 형태소 최종 정확도는46.39%         number:178
# 릭 오스터로 구글 하드웨어 부문장은 이날 “핏빗의 전문가들과 긴밀하게 협력하고, 인공지능(AI), 소프트웨어, 하드웨어 등을 결합할 경우 웨어러블 분야 혁신을 추동하는 데 도움이 될 것”이라고 강조했다.구글이 주당 7.35달러에 핏빗을 인수하기로 했다고 CNBC를 비롯한 주요 외신들이 1일(현지시간) 보도했다.
# 구글 모회사인 알파벳이 핏빗을 인수했다.구글은 핏빗 인수로 스마트워치 운영체제인 웨어OS 경쟁력 확보에 큰 힘이 될 것으로 기대하고 있다.릭 오스터로 구글 하드웨어 부문장은 이날 "핏빗의 전문가들과 긴밀하게 협력하고, 인공지능, 소프트웨어, 하드웨어 등을 결합할 경우 웨어러블 분야 혁신을 추동하는 데 도움이 될 것"이라고 강조했다.
# 문장 정확도는 59.44%         number:179
# 형태소 정확도는 75.95%         number:179
# 문장 최종 정확도는40.33%         number:179
# 형태소 최종 정확도는46.55%         number:179
# 이날 그는 이달부터 서비스를 시작한 스트리밍 서비스 '애플TV+(플러스)'에 대해 "서비스와 하드웨어(제품)가 결합된 첫 번째 묶음상품"이라면서, 이를 좋은 전략으로 보는지 쿡 CEO에게 물었다.미국 경제매체 CNBC는 애플이 아이폰에 클라우드, 애플TV+ 등 서비스를 묶는 상품을 정기구독 형태로 판매할 수 있을 것으로 예상했다.
# 스마트폰 시장이 성숙기에 접어들며 아이폰 판매가 부진에 빠진 가운데, 애플이 아이폰의 본격 정기구독 서비스 가능성을 열어뒀다.앞서 애플은 지난 2015년 월 일정액을 내면 1년마다 새 제품을 받고 애플보험 서비스를 받을 수 있게 한 '아이폰 업그레이드 프로그램'을 도입한 적이 있다.한편 지난 분기 애플은 아이폰 매출이 1년 전보다 9.2% 줄었고, 서비스 매출은 18% 늘어 분기 기준 역대최대치를 기록했다.
# 문장 정확도는 7.25%         number:180
# 형태소 정확도는 29.63%         number:180
# 문장 최종 정확도는40.15%         number:180
# 형태소 최종 정확도는46.46%         number:180
# 1일(현지시간) 정보기술(IT) 전문매체 GSM아레나에 따르면 샤오미는 오는 14일 미노트10 발표를 예고한 가운데 최근 이 제품의 카메라 사양을 소셜네트워크서비스(SNS)에 선공개했다.따라서 3200만 화소 전면 카메라를 비롯해 두 개의 카메라에 OIS(손떨림방지) 기능이 적용되고 30W 고속충전이 되는 5260밀리암페어아워(mAh) 배터리를 장착할 것으로 예상된다.
# 샤오미가 후면 카메라 렌즈만 5개인 펜타카메라를 탑재한 새 스마트폰을 선보인다.1일 정보기술 전문매체 GSM아레나에 따르면 샤오미는 오는 14일 미노트10 발표를 예고한 가운데 최근 이 제품의 카메라 사양을 소셜네트워크서비스에 선공개했다.미노트10은 1억800만 화소 후면 카메라, 500만 화소 망원렌즈, 1200만 화소 인물사진용 렌즈, 2000만 화소 초광각렌즈, 200만 화소 접사촬영용 렌즈 등을 듀얼LED 플래시와 함께 장착하는 등 카메라에 크게 신경 썼다.
# 문장 정확도는 44.35%         number:181
# 형태소 정확도는 40.86%         number:181
# 문장 최종 정확도는40.17%         number:181
# 형태소 최종 정확도는46.43%         number:181
# 그러나 동물보호단체 '페타'(PETA)는 "잔혹하고 정당화될 수 없는 실험"이라며 해당 연구기관에 동물 실험을 중단할 것을 촉구했습니다.현지 시간으로 지난달 31일, 영국 데일리메일 등 외신들은 중국 교통의학연구소가 이 실험에 3개월도 안 된 새끼 돼지 15마리를 투입했다고 보도했습니다.
# 중국의 한 연구진이 새끼 돼지로 자동차 충돌 실험을 했다는 사실이 밝혀져 논란이 일고 있습니다.현지 시간으로 지난달 31일, 영국 데일리메일 등 외신들은 중국 교통의학연구소가 이 실험에 3개월도 안 된 새끼 돼지 15마리를 투입했다고 보도했습니다.
# 문장 정확도는 66.22%         number:182
# 형태소 정확도는 67.65%         number:182
# 문장 최종 정확도는40.31%         number:182
# 형태소 최종 정확도는46.54%         number:182
# 한국의 여야 의원들로 구성된 한일의원연맹(회장 강창일)과 일본 의원들의 모임 일한의원연맹(회장 누카가 후쿠시로<額賀福志郞>)은 이날 도쿄 일본 중의원회관에서 제42차 합동총회를 열었다.한국 의원들은 2년 전 합동총회 때에는 아베 총리를 예방하기도 했지만, 이번 한국 의원들의 방일에 맞춰서는 아베 총리 예방 자리가 마련되지 못한 것으로 알려졌다.
# 한국과 일본의 국회의원들이 1일 일본 도쿄에서 모여 악화 일로를 걷고 있는 한일 갈등의 해법을 모색했지만, 좀처럼 접점을 찾지 못한 채 평행선을 달렸다.아베 총리는 특히 직전 일본에서 개최된 2년 전의 총회와 달리 이번 총회에서는 축사를 보내지 않아 한국을 대놓고 홀대했다.그는 지난 2017년 12월 일본에서 개최된 합동총회에서는 관방 부장관이 대독한 메시지를 통해 "양국의 곤란한 문제가 한일관계 전체에 악영향을 미치지 않도록 적절하게 관리해 미래지향적인 관계를 발전시켜야 한다"며 우호적인 메시지를 보냈었다.
# 문장 정확도는 7.50%         number:183
# 형태소 정확도는 23.30%         number:183
# 문장 최종 정확도는40.13%         number:183
# 형태소 최종 정확도는46.42%         number:183
# 이달 공식 판매에 들어갈 6세대 부분변경 모델인 신형 그랜저는 20~30를 타깃으로 삼았다고 여길 정도로 젊은 감각을 추구했다.1998년부터 2005년까지 판매된 3세대 그랜저는 하드톱 스타일로 세련된 디자인으로 국내외에서 호평받았다.
# 10년전인 2009년 방영된 현대차 그랜저 CF에 나온 내용이다.처음에는 사장차로 인지도를 쌓다가 4·5세대에는 아빠차로 거듭나더니 6세대 들어서는 오빠차로 거듭났다.이달 공식 판매에 들어갈 6세대 부분변경 모델인 신형 그랜저는 20~30를 타깃으로 삼았다고 여길 정도로 젊은 감각을 추구했다.
# 문장 정확도는 48.14%         number:184
# 형태소 정확도는 59.26%         number:184
# 문장 최종 정확도는40.18%         number:184
# 형태소 최종 정확도는46.49%         number:184
# 또 80cm 크기 일렉트로맨 TV(정상가 17만 9,000원)를 9만9000원, 조생햇귤(국내산 3kg) 9,500원 등에 판매하고 있다.신세계그룹이 미국 블랙프라이데이와 중국 광군제를 넘어서는 규모라고 밝힌 대규모 할인행사이벤트 ‘대한민국 쓱데이’ 행사가 2일 진행되고 있다
# 신세계그룹이 '쓱데이' 행사가 진행 중인 2일 서울의 한 이마트 매장에 시민들이 줄지어 입장을 기다리고 있다.신세계그룹이 '쓱데이' 행사가 진행 중인 2일 서울의 한 이마트 매장에 시민들이 입장을 기다리고 있다.
# 문장 정확도는 20.59%         number:185
# 형태소 정확도는 26.92%         number:185
# 문장 최종 정확도는40.07%         number:185
# 형태소 최종 정확도는46.38%         number:185
# 부산의 대표 가을 축제로 올해 15회째를 맞는 부산불꽃축제는 이날 오후부터 열린 사전행사 ‘불꽃버스킹’을 시작으로 광안리 해수욕장 백사장 곳곳에서 매직쇼, 불쇼, 마임, 한국무용 등의 공연이 동시에 펼쳐지고 있다.한편 부산일보는 페이스북과 유튜브 등 공식 SNS를 통해 화려한 불꽃쇼를 라이브방송으로 전할 예정이다.
# 제15회 부산불꽃축제가 열리는 부산 광안리해수욕장 일대가 인파로 붐비고 있다.2일 오후 부산 수영구 광안리 해수욕장 일대에서 '제15회 부산불꽃축제'가 열리고 있다.부산의 대표 가을 축제로 올해 15회째를 맞는 부산불꽃축제는 이날 오후부터 열린 사전행사 '불꽃버스킹'을 시작으로 광안리 해수욕장 백사장 곳곳에서 매직쇼, 불쇼, 마임, 한국무용 등의 공연이 동시에 펼쳐지고 있다.
# 문장 정확도는 60.47%         number:186
# 형태소 정확도는 67.39%         number:186
# 문장 최종 정확도는40.18%         number:186
# 형태소 최종 정확도는46.49%         number:186
# 올해로 한국나이 84세인 김영달 씨는 코어 근육을 키우는 플랭크(Plank) 운동으로 건강을 지키고 있다.유튜브를 보고 좋다는 운동은 다 따라서 했다.
# 올해로 한국나이 84세인 김영달 씨는 코어 근육을 키우는 플랭크 운동으로 건강을 지키고 있다.노인들에게도 근육 운동의 효과는 크다.1990년 미국의사협회 저널에 '90세 어르신들의 고강도 근육훈련'가 발표된 이후 노인들도 근육운동을 하면 효과가 좋다는 연구 결과가 이어지고 있다.
# 문장 정확도는 50.00%         number:187
# 형태소 정확도는 52.17%         number:187
# 문장 최종 정확도는40.23%         number:187
# 형태소 최종 정확도는46.52%         number:187
