# %%
from random import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
data = []

for cnt in range(365):
    i = randint(1,5)
    data.append(i)
print(data)
# Out:
# [3, 4, 4, 2, 4, 1, 5, 3, 1, 5, 1, 2, 2, 2, 1, 4, 4, 3, 5, 1, 1, 1, 4, 5, 3, 5, 2, 1, 1, 1, 4, 1, 3, 2, 1, 1, 4, 2, 3, 5, 4, 1, 3, 1, 4, 2, 1, 4, 5, 1, 1, 5, 5, 4, 3, 5, 4, 5, 4, 4, 3, 1, 5, 3, 2, 1, 4, 1, 5, 4, 1, 3, 5, 2, 3, 1, 5, 3, 2, 2, 4, 4, 3, 1, 5, 5, 4, 5, 2, 5, 1, 2, 1, 1, 1, 1, 3, 4, 1, 3, 2, 2, 1, 1, 5, 5, 1, 5, 1, 2, 3, 4, 4, 3, 5, 2, 1, 5, 2, 5, 5, 4, 1, 3, 3, 2, 3, 4, 4, 5, 2, 2, 1, 2, 3, 5, 4, 3, 5, 2, 4, 3, 1, 1, 4, 1, 1, 1, 3, 2, 1, 2, 5, 2, 5, 1, 2, 4, 1, 1, 4, 1, 4, 3, 4, 4, 3, 5, 4, 2, 5, 2, 1, 3, 5, 4, 3, 4, 3, 2, 4, 2, 1, 3, 1, 2, 2, 5, 1, 2, 4, 1, 2, 4, 4, 1, 1, 1, 3, 5, 2, 1, 4, 3, 5, 4, 5, 5, 1, 1, 3, 3, 4, 2, 1, 2, 3, 4, 1, 5, 3, 4, 3, 3, 4, 5, 5, 2, 2, 4, 1, 1, 4, 1, 5, 2, 3, 4, 5, 5, 1, 4, 3, 5, 1, 1, 2, 1, 3, 5, 1, 5, 1, 1, 2, 3, 5, 3, 2, 2, 3, 3, 2, 1, 4, 1, 1, 2, 3, 2, 5, 1, 1, 1, 3, 3, 4, 2, 2, 4, 4, 5, 1, 2, 1, 4, 5, 3, 2, 1, 4, 3, 1, 5, 2, 4, 5, 2, 3, 4, 2, 2, 4, 3, 1, 5, 5, 3, 3, 5, 1, 4, 2, 2, 4, 5, 4, 2, 5, 4, 2, 1, 4, 1, 4, 2, 5, 4, 1, 5, 4, 2, 3
# ...

# %%
count_days = 1
bio_phy = math.sin(math.tau * count_days / 23)
bio_emo = math.sin(math.tau * count_days / 28) 
bio_int = math.sin(math.tau * count_days / 33) 
bio_phy
bio_emo
bio_int
# Out:
# 0.1892512443604102

# %%
print(bio_phy, bio_emo, bio_int)
# Out:
# 0.2697967711570243 0.2225209339563144 0.1892512443604102

# %%
bio_emo = (2 * (math.sin(math.tau * count_days / 28))) + 3

# %%
print(bio_emo)
# Out:
# 3.4450418679126287

# %%
bio = []
for cnt in range(1, 365):
    bio_emo = (2 * (math.sin(math.tau * cnt / 28))) + 3
    bio.append(bio_emo)
print(bio)
# Out:
# [3.4450418679126287, 3.867767478235116, 4.246979603717467, 4.56366296493606, 4.801937735804838, 4.949855824363647, 5.0, 4.949855824363647, 4.801937735804838, 4.56366296493606, 4.246979603717468, 3.8677674782351166, 3.4450418679126282, 3.0000000000000004, 2.554958132087372, 2.132232521764884, 1.7530203962825324, 1.4363370350639406, 1.198062264195162, 1.0501441756363528, 1.0, 1.0501441756363523, 1.1980622641951615, 1.4363370350639402, 1.7530203962825326, 2.1322325217648848, 2.554958132087371, 2.9999999999999996, 3.4450418679126282, 3.8677674782351144, 4.246979603717467, 4.563662964936059, 4.801937735804838, 4.949855824363647, 5.0, 4.949855824363647, 4.801937735804838, 4.56366296493606, 4.246979603717468, 3.867767478235117, 3.4450418679126296, 3.000000000000001, 2.5549581320873718, 2.1322325217648874, 1.7530203962825335, 1.4363370350639408, 1.1980622641951622, 1.050144175636353, 1.0, 1.0501441756363525, 1.1980622641951613, 1.436337035063942, 1.7530203962825321, 2.132232521764883, 2.5549
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(1, 30, 1)
y = (np.sin(math.tau * x/28) * 2) + 3

# %%
plt.plot(x,y)
plt.show()

# %%
x1 = np.arange(1, 31, 1)
y1 = data[:30]

# %%
plt.plot(x1,y1)
plt.show()

# %%
# Out:
# [3,
#  4,
#  4,
#  2,
#  4,
#  1,
#  5,
#  3,
#  1,
#  5,
#  1,
#  2,
#  2,
#  2,
#  1,
#  4,
#  4,
#  3,
#  5,
#  1,
#  1,
#  1,
#  4,
#  5,
#  3,
#  5,
#  2,
#  1,
#  1,
#  1]

# %%
import torch

# %%
data_tensor = torch.tensor(data)

# %%
bio_tensor = torch.tensor(bio)

# %%
bio_tensor
# Out:
# tensor([3.4450, 3.8678, 4.2470, 4.5637, 4.8019, 4.9499, 5.0000, 4.9499, 4.8019,
#         4.5637, 4.2470, 3.8678, 3.4450, 3.0000, 2.5550, 2.1322, 1.7530, 1.4363,
#         1.1981, 1.0501, 1.0000, 1.0501, 1.1981, 1.4363, 1.7530, 2.1322, 2.5550,
#         3.0000, 3.4450, 3.8678, 4.2470, 4.5637, 4.8019, 4.9499, 5.0000, 4.9499,
#         4.8019, 4.5637, 4.2470, 3.8678, 3.4450, 3.0000, 2.5550, 2.1322, 1.7530,
#         1.4363, 1.1981, 1.0501, 1.0000, 1.0501, 1.1981, 1.4363, 1.7530, 2.1322,
#         2.5550, 3.0000, 3.4450, 3.8678, 4.2470, 4.5637, 4.8019, 4.9499, 5.0000,
#         4.9499, 4.8019, 4.5637, 4.2470, 3.8678, 3.4450, 3.0000, 2.5550, 2.1322,
#         1.7530, 1.4363, 1.1981, 1.0501, 1.0000, 1.0501, 1.1981, 1.4363, 1.7530,
#         2.1322, 2.5550, 3.0000, 3.4450, 3.8678, 4.2470, 4.5637, 4.8019, 4.9499,
#         5.0000, 4.9499, 4.8019, 4.5637, 4.2470, 3.8678, 3.4450, 3.0000, 2.5550,
#         2.1322, 1.7530, 1.4363, 1.1981, 1.0501, 1.0000, 1.0501, 1.1981, 1.4363,
# ...

# %%
import matplotlib.pyplot as plt

# %%
import math

# %%
x = np.random.rand(30, 1)
x = x + 4
print(x)
# Out:
# [[4.07222805]
#  [4.21138714]
#  [4.27785677]
#  [4.9103161 ]
#  [4.60316247]
#  [4.53288896]
#  [4.35260309]
#  [4.32210968]
#  [4.8389416 ]
#  [4.57597282]
#  [4.25941659]
#  [4.43865806]
#  [4.39306903]
#  [4.2825532 ]
#  [4.55990207]
#  [4.17806893]
#  [4.36967378]
#  [4.21705217]
#  [4.36730927]
#  [4.52275371]
#  [4.95938827]
#  [4.4878782 ]
#  [4.13742938]
#  [4.86703145]
#  [4.34132658]
#  [4.52905973]
#  [4.84015264]
#  [4.37005073]
#  [4.38995759]
#  [4.08654854]]
