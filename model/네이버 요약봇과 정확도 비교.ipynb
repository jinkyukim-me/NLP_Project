# %%
import difflib
import numpy as np
import krwordrank
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter
from konlpy.tag import Okt
from PIL import Image
from pykospacing import spacing
import krwordrank
from krwordrank.sentence import summarize_with_sentences
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\jungs\Anaconda3\envs\py36\lib\site-packages\tensorflow\python\util\deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead

# %% [markdown]
# 데이터 전처리(엔터를 기준으로 한 문장으로 인식)

# %%
okt = Okt()
noun = []
sent = []
for i in range(1,68):
    data_path = 'E:\\news\\news\\뉴스\\뉴스원본_'+str(i)+'.txt'
    def get_texts(data_path):
        file = open(data_path, 'r',encoding='UTF-8')
        data =file.readlines()
        data_list = []
        for sentence in data:
            list_sentence1 = sentence.replace('\n','').replace('""','').split('\n')
            for list_sentence2 in list_sentence1:
                list_sentence = list_sentence2.replace('다.','다.  .').split('  .')
                for lines in list_sentence:
                    line = lines.strip()
                    data_list.append(line)
        texts = list(set(data_list))
        if '' in texts:
            texts.remove('')
        return texts 
    texts = get_texts(data_path)
    penalty = lambda x:0 if (25 <= len(x) <= 100) else 1
    keywords, sents = summarize_with_sentences(
        texts,
        penalty=penalty,
        stopwords={},
        diversity=0.5,
        num_keywords=5,
        num_keysents=2,
        scaling=lambda x:1,
        verbose=False,
        min_count = 1)
    a = ""
    for s in sents:
        a += s
    sent.append(a)
    b = okt.nouns(a)
#     c = []
#     for bb in range(0,2):
#         c.extend(b)
    noun.append(b)

# %%
sent_before = []
noun_before = []
for j in range(1,68):
    data_path1 = 'E:\\news\\news\\요약\\뉴스_'+str(j)+'.txt'
    def get_texts1(data_path):
        file = open(data_path, 'r',encoding='UTF-8')
        data =file.read()
        return data
    data = get_texts1(data_path1)
    a = ""
    a = data.replace("\n",'')
    sent_before.append(a)
    b = okt.nouns(a)
    noun_before.append(b)

# %%
print(sent_before)
# Out:
# ["삼성전자가 갤럭시 폴드에 이어 '클램셸' 형태의 새로운 폴더블폰을 공개하며 2세대 폼팩터 전쟁의 문을 열었다.내년 전세계 320만대 규모로 성장한 폴더블폰 시장에서 앞으로 여러 제조사들이 앞다투어 새로운 폼팩터를 출시할 것으로 보인다.", '경찰이 2일 화성연쇄살인 사건의 피의자 이모씨가 추가 자백한 초등생 김모양의 시신 발굴작업을 진행중인 가운데 현재까지 35% 작업을 마무리했다고 밝혔다.이날 경찰은 150여개의 구역 중 50% 발굴을 목표로 경기남부청 과학수사대와 기동대 등 36명을 투입해 오전 9시부터 5인 1조 4개 조가 각 구획별로 분석작업을 벌였다.', "삼성전자가 갤럭시 폴드에 이어 '클램셸' 형태의 새로운 폴더블폰을 공개하며 2세대 폼팩터 전쟁의 문을 열었다.내년 전세계 320만대 규모로 성장한 폴더블폰 시장에서 앞으로 여러 제조사들이 앞다투어 새로운 폼팩터를 출시할 것으로 보인다.", '지난 달 28일 검찰이 타다를 불법으로 판단하면서, 고용노동부가 타다를 파견법 위반으로 판단할 가능성이 높아졌다.하지만 여객자동차운수사업법 개정안이 국회에서 통과하기 전까지 노동부는 결론을 내리지 않을 것으로 보인다.', 'LG G8X 씽큐가 북미 시장 출시 초반부터 듀얼 스크린의 멀티태스킹 경험과 합리적인 가격이 호평을 받았다.LG전자는 지난 1일 북미 시장에 출시한 LG G8X 씽큐와 듀얼 스크린에 대한 외신 호평이 이어지고 있다고 밝혔다.', "온라인동영상서비스 웨이브가 2020 도쿄올림픽 야구 본선 진출권이 달린 '2019 WBSC 프리미어 12' 경기를 온라인 독점 생중계한다.콘텐츠웨이브는 '프리미어12' 공식 스폰서로 참여해 생중계 권한을 확보, 1일부터 대한민국 국가대표팀 전 경기를 고화질로 무료 생중계한다.", '게임 축제 블리즈컨2019에서 신작 디아블로4와 오버워치2, 월드오브워크래프트 새 확장팩 등이 깜짝 공개됐다.블리자드엔터테인먼트는 1일 오전 10시 미국 캘리포니아 애너하임 컨벤션 센터에서 블리즈컨2019 개막을 알렸다.', "웨어러블 시장의 최강자로 자리매김한 '핏빗'이 세계 최대 검색엔진 업체 구글의 모회사 '알파벳'에 인수된다고 미 언론들이 1일 보도했다.한국계 미국인 제임스 박이 공동창업한 핏빗은 하루 걸음 수나 달린 거리, 소모된 칼로리양, 심장 박동수, 수면 시간과 수면의 질 등을 계측하는 스마트워치 등을 생산한다.", '지난달 영국에서 냉동 컨테이너안에 숨진 채 발견된 39명이 모두 베트남 출신으로 추정된다는 현지 경찰의 발표에 베트남이 큰 충격에 빠졌습니다.쩐 응옥 안 영국 주재 베트남 대사는 "영국경찰의 공식 통보를 받고 충격을 받았으며 매우 슬프다"고 말했습니다.', '사람이 말하거나 구동 중인 동영상의 음성을 인공지능이 실시간으로 인식해 타이핑해주는 구글 드라이브의 음성입력 서비스가 큰 인기를 끌고 있습니다.30분짜리 강연 영상을 틀어놓고 잠시 다른 일을 본 후 30분 후에 자리에 오면 이미 타이핑이 끝나 있는 문서를 확인할 수 있는 형태인데요.', "'수크라테놀'과 관련한 토스 행운퀴즈가 등장했다.간편 송금 서비스 토스는 1일 'OOOOO은 수크랄페이트와 덱스판테놀의 복합체로 손상 받은 피부의 진정과 보호에 도움을 준다.OOOOO에 들어갈 닥터오킴스의 독자적 성분은?'이라는 행운퀴즈를 출제했다.", "간편송금 서비스 토스가 1일 '아시아나항공 우수회원'과 관련 행운퀴즈를 출제했다.마일리지가 반영되어 우수회원 자격을 보다 쉽게 획득하실 수 있다.", '삼성전자 스마트폰 사업 실적이 되살아났다.갤럭시노트10과 중저가폰인 갤럭시A 시리즈 판매 호조로 3분기 깜짝 실적을 냈다.', 'LG전자 스마트폰 사업이 18분기 연속 적자를 기록했으나 베트남 공장 이전을 통한 생산지 효율화와 원가개선으로 영업손실의 폭을 줄였다.LG전자는 30일 3분기 실적발표를 통해 매출액 15조7007억원, 영업이익 7814억원을 기록했다고 밝혔다.', "삼성전자가 2020년엔 폴더블폰 생산량을 늘리겠다고 밝혔다.갤럭시 폴드의 흥행 이후 위아래로 여닫는 '클램셸' 형태 폴더블폰까지 공개한 삼성전자가 폴더블폰 시장 주도권을 이어갈 수 있을지 주목된다.", "'온디맨드' 업체가 늘어나며 단기고용직인 '긱 이코노미' 종사자가 급증하고 있지만 정규직이 아닌 탓에 관련업계가 관리문제로 몸살을 앓고 있다.검증되지 않은 이들이 긱 이코노미 시장에 유입되면서 성희롱과 욕설·바가지 금액 책정 등 피해사례가 늘어나 업체마다 이미지 타격이 적지 않지만 인건비 부담으로 직접 고용이 어렵고 간접고용인 탓에 종사자 교육도 쉽지 않은 상황이다.", "검찰이 승합차와 운전자 모두를 빌려주는 모빌리티 플랫폼 '타다' 운행이 불법이라고 판단하고 임원들을 불구속 기소하자, 벤처인들이 강력하게 반발하고 있다.검찰은 어제 여객자동차운수사업법 위반 혐의로 박재욱 VCNC 대표와 이재웅 쏘카 대표를 각각 불구속 기소했다.", "애플이 '노이즈 캔슬링' 기능이 탑재된 새로운 디자인의 '에어팟 프로'를 공개한 가운데 한국 소비자를 해외 소비자와 차별하고 있다는 지적이 나온다.28일 애플은 공식 자료를 통해 '에어팟 프로'를 30일부터 공식 스토어에서 판매한다고 밝혔다.", "아이폰 11 시리즈로 글로벌 흥행을 이어가고 있는 애플이 새로운 프리미엄 무선 이어폰 '에어팟 프로'를 내놨다.애플은 28일 노이즈 캔슬링과 인이어 디자인 등을 갖춘 에어팟 프로를 공개했다.", "국내 연구진이 포함된 국제 공동연구팀이 '호모사피엔스'가 아프리카 칼라하리 지역에 처음 나타났으며, 첫 번째 인류 대이동의 원인은 기후변화였다는 사실을 밝혀냈다.호주의 가반의학연구소와 뉴사우스웨일스대, 한국의 기초과학연구원 기후물리연구단, 남아프리카공화국 로즈대, 나미비아 빈트후크중앙병원 등 10개 기관 연구진으로 구성된 국제공동연구팀은 현생인류가 20만년 전 아프리카 칼라하리 지역에서 처음 나타났고 13만년 전 기후변화 때문에 인류 대이동이 있었다는 연구 결과를 세계적인 과학저널 '네이처' 10월 29일자에 발표했다.", 'SK텔레콤은 카카오와 3000억원 규모의 지분을 교환하고 전략적 파트너십을 체결한다고 28일 밝혔다.SK텔레콤은 3000억원 규모의 자기주식을 카카오에 매각하고, 카카오는 신주를 발행해 SK텔레콤에 배정하는 방식으로 지분을 맞교환한다.', '지난 주말새 비트코인 가격이 20% 이상 폭등하며 1000만원선을 회복한 가운데, 향후 암호화폐 시장 전망에 대한 업계의 의견이 갈리고 있다.중국 정부의 블록체인 육성정책 덕에 "내년 초 비트코인 가격이 5만달러까지 폭등할 것"이라는 시각과 "오히려 각국 정부의 코인시장 관리가 더 엄격해질 것"이라는 반대의견이 팽팽하게 맞선다.', "카카오가 포털서비스 다음의 연예뉴스 댓글 서비스를 폐지하기로 해 포털업계 1위 네이버로 관심이 쏠리고 있다.네이버 역시 '악성 댓글'이나 '실시간 검색어 조작 논란'에서 자유롭지 않은 만큼 자정에 나서야 한다는 요구가 높아지는 형국이다.", '유시민 노무현재단 이사장은 2일 조국 전 법무부 장관 가족에 대한 검찰 수사에 대해 "잔인무도하다"고 밝혔다.유 이사장은 이날 노무현재단 전북지역위원회가 창립 8주년을 기념해 전주교육대에서 연 시민학교 대담에서 "검찰이 조국 전 장관의 80대 노모를 소환 조사하고 딸을 기소하겠다고 으름장을 놓는다.조국 일가족의 혐의점에 비해 무지무지하게 잔인하다"며 이같이 말했다.', '25일 출시된 아이폰11 시리즈의 첫날 개통량이 전작인 아이폰XS·XR 시리즈보다 30%가량 높게 나타났다.26일 이동통신업계에 따르면 전날 시작된 아이폰11 시리즈의 개통량은 13만∼14만대로 추산된다.', '전날 국내에 공식 출시된 아이폰11 시리즈가 첫 테이프를 성공적으로 끊었다.26일 이동통신업계에 따르면 출시 첫날 아이폰11 시리즈 개통량은 13만~14만대로, 전작에 비해 30%가량 높은 것으로 나타났다.', '네이버는 제2 데이터센터 우선 협상 대상 부지로 세종특별자치시를 선정했다고 25일 밝혔다.네이버는 당초 경기도 용인시 기흥구에 제2 데이터센터를 건립하려고 했지만 주민 반대로 지난 6월 철회했다.', "삼성전자가 폴더블 스마트폰 '갤럭시 폴드'를 중국에 출시하기로 하면서 화웨이의 ' ...

# %%
print(sent)
# Out:
# ['삼성전자(005930)가 갤럭시 폴드에 이어 ‘클램셸’ 형태의 새로운 폴더블폰을 공개하며 2세대 폼팩터 전쟁의 문을 열었다.이에 더해 삼성전자는 지난달 29일(현지시간) 미국 캘리포니아주 새너제이에서 열린 삼성 개발자 콘퍼런스(SDC) 2019에서 위아래로 여닫는 2세대 폴더블폰을 공개했다.', '그러나 오전 11시 화성연쇄살인사건 전담 수사본부장인 반기수 경기남부지방경찰청 2부장이 현장지휘를 이어가면서 다시 6인 1조 6개조로 확대해 작업을 진행중이다.이날 경찰은 150여개의 구역 중 50% 발굴을 목표로 경기남부청 과학수사대와 기동대 등 36명을 투입해 오전 9시부터 5인 1조 4개 조가 각 구획별로 분석작업을 벌였다.', '삼성전자가 갤럭시 폴드에 이어 ‘클램셸’ 형태의 새로운 폴더블폰을 공개하며 2세대 폼팩터 전쟁의 문을 열었다.이에 더해 삼성전자는 지난달 29일(현지시간) 미국 캘리포니아주 새너제이에서 열린 삼성 개발자 콘퍼런스(SDC) 2019에서 위아래로 여닫는 2세대 폴더블폰을 공개했다.', '지난 달 28일 검찰이 타다를 불법으로 판단하면서, 고용노동부가 타다를 파견법(파견근로자 보호 등에 관한 법률) 위반으로 판단할 가능성이 높아졌다.타다, 파견법 위반 가능성 높아져…노동부는 개정안 통과 전까지 결론 안낼 듯', '미국 IT 매체 더 버지(The Verge)는 “LG G8X 씽큐와 듀얼 스크린의 멀티태스킹 성능은 지금까지 사용해 본 모바일 제품 중 최고”라고 호평했다.美 외신 "LG 듀얼스크린, 멀티태스킹 성능 최강"', "콘텐츠웨이브는 '프리미어12' 공식 스폰서로 참여해 생중계 권한을 확보, 1일부터 대한민국 국가대표팀 전 경기를 고화질(풀HD)로 무료 생중계한다.대한민국 대표팀의 올림픽 출전권까지 걸린 중요한 대회다.", '게임 축제 블리즈컨2019에서 신작 디아블로4와 오버워치2, 월드오브워크래프트 새 확장팩 등이 깜짝 공개됐다.신작 및 기존 서비스작 업데이트 버전 체험 가능', '한국계 미국인 제임스 박이 공동창업한 핏빗은 하루 걸음 수나 달린 거리, 소모된 칼로리양, 심장 박동수, 수면 시간과 수면의 질 등을 계측하는 스마트워치 등을 생산한다.핏빗은 1일(현지시간) 보도자료를 통해 "구글이 현금으로 주당 7.35달러에 핏빗을 인수하는 방안에 합의했다"고 밝혔다.', '지난달 영국에서 냉동 컨테이너안에 숨진 채 발견된 39명이 모두 베트남 출신으로 추정된다는 현지 경찰의 발표에 베트남이 큰 충격에 빠졌습니다.레 티 투 항 베트남 외교부 대변인도 오늘 새벽 긴급 성명을 내고 "심각한 비극"이라며 "희생자 가족에게 위로의 말을 전한다"고 밝혔습니다.', '사람이 말하거나 구동 중인 동영상의 음성을 인공지능(AI)이 실시간으로 인식해 타이핑해주는 구글 드라이브의 음성입력 서비스가 큰 인기를 끌고 있습니다.30분짜리 강연도 한 번에…구글 드라이브 음성입력 이용 방법', 'OOOOO에 들어갈 닥터오킴스의 독자적 성분은?’이라는 행운퀴즈를 출제했다.간편 송금 서비스 토스는 1일 ‘OOOOO은 수크랄페이트와 덱스판테놀의 복합체로 손상 받은 피부의 진정과 보호에 도움을 준다.', '\'아시아나항공 우수회원\' 토스 행운퀴즈 정답은?이어진 두번째 토스퀴즈는 "항공 탑승 및 아시아나 제휴 카드 이용 실적에 따라 골드, 다이아몬드, 다이아몬드 플러스, □□□□ 회원으로 승급된다.', '삼성전자의 이런 전략이 실적에 반영되기 시작했다는 분석이 나온다.갤럭시노트10과 중저가폰인 갤럭시A 시리즈 판매 호조로 3분기 깜짝 실적을 냈다.', 'LG전자는 30일 3분기 실적발표를 통해 매출액 15조7007억원, 영업이익 7814억원을 기록했다고 밝혔다.MC사업본부는 스마트폰 공장을 경기도 평택에서 베트남 하이퐁으로 이전함으로써 비용 개선에 성공한 것으로 분석된다.', '갤럭시 폴드의 흥행 이후 위아래로 여닫는 ‘클램셸’ 형태 폴더블폰까지 공개한 삼성전자가 폴더블폰 시장 주도권을 이어갈 수 있을지 주목된다.고 사장은 중가형 스마트폰 갤럭시 A 시리즈에 대해선 “(수익성이) 목표한 것까지는 아직 안됐다”라며 “더 혁신이 필요하다”고 강조했다.', "'온디맨드(O2O)' 업체가 늘어나며 단기고용직인 '긱 이코노미(단기근로)' 종사자가 급증하고 있지만 정규직이 아닌 탓에 관련업계가 관리문제로 몸살을 앓고 있다.채팅방 성희롱 논란에 이어 기사 욕설 논란까지 휩싸인 타다의 경우, 직접 고용이 아닌 알선업체를 통해 기사를 간접 고용하고 있어 직접 교육이 불가능하다고 주장한다.", '①법률상 문언적 근거가 있어 불법이라 보기 어렵고 ②타다에 대한 이용자 선택권을 침해했으며 ③4차 산업혁명 전환기에 낡은 규제로 신산업을 형사 기소하는 일은 잘못이라는 것이다.검찰은 어제(28일) 여객자동차운수사업법 위반 혐의로 박재욱 VCNC 대표와 이재웅 쏘카 대표를 각각 불구속 기소했다.', '‘에어팟 프로’의 ‘노이즈 캔슬링’ 기능을 이용하면 사용자는 주변 소음에 방해받지 않고 통화, 음악 감상에 집중할 수 있다.28일(이하 현지시간) 애플은 공식 자료를 통해 ‘에어팟 프로’를 30일부터 공식 스토어에서 판매한다고 밝혔다.', '애플은 28일(현지시간) 노이즈 캔슬링과 인이어(귀 삽입형) 디자인 등을 갖춘 에어팟 프로를 공개했다.“아이폰11 흥행 잇는다”...애플, 32만원대 ‘에어팟 프로’ 공개', '국내 연구진이 포함된 국제 공동연구팀이 ‘호모사피엔스’(현생인류)가 아프리카 칼라하리 지역에 처음 나타났으며, 첫 번째 인류 대이동의 원인은 기후변화였다는 사실을 밝혀냈다.연구팀은 또 해양 퇴적물 같은 고(古)기후 및 지질학적 데이터와 슈퍼컴퓨터를 이용한 기후 모델을 분석한 결과 약 13만년 전 지구 자전축의 움직임이 변해 남반구의 일사량이 변하고 강수량이 이전과 달라지면서 현생인류가 발상지에서 벗어나 이주를 시작했다고 분석했다.', 'SK텔레콤은 3000억원 규모의 자기주식을 카카오에 매각하고, 카카오는 신주를 발행해 SK텔레콤에 배정하는 방식으로 지분을 맞교환한다.SKT-카카오, 통신·커머스·디지털 콘텐츠·미래ICT 등 협력', '지난 주말새 비트코인 가격이 20% 이상 폭등하며 1000만원선을 회복한 가운데, 향후 암호화폐 시장 전망에 대한 업계의 의견이 갈리고 있다.시진핑 주석의 블록체인 육성 의지 천명에도 비트코인 비관론자들은 "중국의 블록체인 산업 육성과 비트코인은 별개로 봐야 한다"고 지적한다.', "카카오가 포털서비스 다음의 연예뉴스 댓글 서비스를 폐지하기로 해 포털업계 1위 네이버로 관심이 쏠리고 있다.앞서 2015년 2월부터 '뉴스댓글 상처 없는 댓글세상 만들기' 캠페인을 시작, 선플을 유도하고 있다.", '유시민 노무현재단 이사장은 2일 조국 전 법무부 장관 가족에 대한 검찰 수사에 대해 "잔인무도하다"고 밝혔다.하고 싶은 것은 수단 방법을 가리지 않는다"며 "전두환 신군부 때를 보는 듯하다"고도 했다.', '이는 작년 11월 출시된 아이폰XS·XS맥스·아이폰XR 첫날 개통량(10만대 수준)과 비교하면 30% 이상 많은 수치다.26일 이동통신업계에 따르면 전날 시작된 아이폰11 시리즈의 개통량은 13만∼14만대로 추산된다.', '26일 이동통신업계에 따르면 출시 첫날 아이폰11 시리즈 개통량은 13만~14만대로, 전작에 비해 30%가량 높은 것으로 나타났다.통신사간 판매 경쟁 과열 정도를 가늠해볼 수 있는 번호이동 건수는 전작에 비해 오히려 줄었다.', '네이버는 당초 경기도 용인시 기흥구에 제2 데이터센터를 건립하려고 했지만 주민 반대로 지난 6월 철회했다.지난 7일부터 18일까지 10개 후보 부지의 실사를 진행한 결과 세종을 우선 협상 부지로 결정하게 됐다.', "삼성전자가 폴더블 스마트폰 '갤럭시 폴드'를 중국에 출시하기로 하면서 화웨이의 '메이트X'와 맞붙는다.메이트X 15일 출시…갤폴드, 내구성 검증에 가격도 50만원 저렴", '25일 KT, SK텔링크, LG유플러스에 따르면 내달 30일까지 삼성전자의 신형폰을 구매하는 소비자를 위해 중고폰 특별보상 프로그램을 시행한다.자급제 모델 기준 아이폰11은 99만~120만원, 아이폰11 프로는 139만~187만원, 아이폰11 프로 맥스는 155만~203만원이다.', 'LG전자는 미국 ...

# %%
n=1
a=0
a1=0
for  i in range(0,67):
    print(sent[i])
    print(sent_before[i])
    s = difflib.SequenceMatcher(lambda x: x == " ", sent[i], sent_before[i])
    result = round(s.ratio(), 4)
    s1 = difflib.SequenceMatcher(lambda x: x == " ", noun[i], noun_before[i])
    result1 = round(s1.ratio(), 4)
    print("문장 정확도는 {}%         ".format(result*100)+str(n))
    print("형태소 정확도는 {}%         ".format(result1*100)+str(n))
    a = a+result
    b = (a*100)/n
    print("문장 최종 정확도는"+"%0.2f"%b+"%         "+str(n))
    a1 = a1+result1
    b1 = (a1*100)/n
    print("형태소 최종 정확도는"+"%0.2f"%b1+"%         "+str(n))
    n = n+1
# Out:
# 삼성전자(005930)가 갤럭시 폴드에 이어 ‘클램셸’ 형태의 새로운 폴더블폰을 공개하며 2세대 폼팩터 전쟁의 문을 열었다.이에 더해 삼성전자는 지난달 29일(현지시간) 미국 캘리포니아주 새너제이에서 열린 삼성 개발자 콘퍼런스(SDC) 2019에서 위아래로 여닫는 2세대 폴더블폰을 공개했다.
# 삼성전자가 갤럭시 폴드에 이어 '클램셸' 형태의 새로운 폴더블폰을 공개하며 2세대 폼팩터 전쟁의 문을 열었다.내년 전세계 320만대 규모로 성장한 폴더블폰 시장에서 앞으로 여러 제조사들이 앞다투어 새로운 폼팩터를 출시할 것으로 보인다.
# 문장 정확도는 48.3%         1
# 형태소 정확도는 54.24%         1
# 문장 최종 정확도는48.30%         1
# 형태소 최종 정확도는54.24%         1
# 그러나 오전 11시 화성연쇄살인사건 전담 수사본부장인 반기수 경기남부지방경찰청 2부장이 현장지휘를 이어가면서 다시 6인 1조 6개조로 확대해 작업을 진행중이다.이날 경찰은 150여개의 구역 중 50% 발굴을 목표로 경기남부청 과학수사대와 기동대 등 36명을 투입해 오전 9시부터 5인 1조 4개 조가 각 구획별로 분석작업을 벌였다.
# 경찰이 2일 화성연쇄살인 사건의 피의자 이모씨가 추가 자백한 초등생 김모양의 시신 발굴작업을 진행중인 가운데 현재까지 35% 작업을 마무리했다고 밝혔다.이날 경찰은 150여개의 구역 중 50% 발굴을 목표로 경기남부청 과학수사대와 기동대 등 36명을 투입해 오전 9시부터 5인 1조 4개 조가 각 구획별로 분석작업을 벌였다.
# 문장 정확도는 63.93%         2
# 형태소 정확도는 67.42%         2
# 문장 최종 정확도는56.12%         2
# 형태소 최종 정확도는60.83%         2
# 삼성전자가 갤럭시 폴드에 이어 ‘클램셸’ 형태의 새로운 폴더블폰을 공개하며 2세대 폼팩터 전쟁의 문을 열었다.이에 더해 삼성전자는 지난달 29일(현지시간) 미국 캘리포니아주 새너제이에서 열린 삼성 개발자 콘퍼런스(SDC) 2019에서 위아래로 여닫는 2세대 폴더블폰을 공개했다.
# 삼성전자가 갤럭시 폴드에 이어 '클램셸' 형태의 새로운 폴더블폰을 공개하며 2세대 폼팩터 전쟁의 문을 열었다.내년 전세계 320만대 규모로 성장한 폴더블폰 시장에서 앞으로 여러 제조사들이 앞다투어 새로운 폼팩터를 출시할 것으로 보인다.
# 문장 정확도는 49.65%         3
# 형태소 정확도는 55.169999999999995%         3
# 문장 최종 정확도는53.96%         3
# 형태소 최종 정확도는58.94%         3
# 지난 달 28일 검찰이 타다를 불법으로 판단하면서, 고용노동부가 타다를 파견법(파견근로자 보호 등에 관한 법률) 위반으로 판단할 가능성이 높아졌다.타다, 파견법 위반 가능성 높아져…노동부는 개정안 통과 전까지 결론 안낼 듯
# 지난 달 28일 검찰이 타다를 불법으로 판단하면서, 고용노동부가 타다를 파견법 위반으로 판단할 가능성이 높아졌다.하지만 여객자동차운수사업법 개정안이 국회에서 통과하기 전까지 노동부는 결론을 내리지 않을 것으로 보인다.
# 문장 정확도는 58.78%         4
# 형태소 정확도는 62.74999999999999%         4
# 문장 최종 정확도는55.16%         4
# 형태소 최종 정확도는59.89%         4
# 미국 IT 매체 더 버지(The Verge)는 “LG G8X 씽큐와 듀얼 스크린의 멀티태스킹 성능은 지금까지 사용해 본 모바일 제품 중 최고”라고 호평했다.美 외신 "LG 듀얼스크린, 멀티태스킹 성능 최강"
# LG G8X 씽큐가 북미 시장 출시 초반부터 듀얼 스크린의 멀티태스킹 경험과 합리적인 가격이 호평을 받았다.LG전자는 지난 1일 북미 시장에 출시한 LG G8X 씽큐와 듀얼 스크린에 대한 외신 호평이 이어지고 있다고 밝혔다.
# 문장 정확도는 30.830000000000002%         5
# 형태소 정확도는 17.78%         5
# 문장 최종 정확도는50.30%         5
# 형태소 최종 정확도는51.47%         5
# 콘텐츠웨이브는 '프리미어12' 공식 스폰서로 참여해 생중계 권한을 확보, 1일부터 대한민국 국가대표팀 전 경기를 고화질(풀HD)로 무료 생중계한다.대한민국 대표팀의 올림픽 출전권까지 걸린 중요한 대회다.
# 온라인동영상서비스 웨이브가 2020 도쿄올림픽 야구 본선 진출권이 달린 '2019 WBSC 프리미어 12' 경기를 온라인 독점 생중계한다.콘텐츠웨이브는 '프리미어12' 공식 스폰서로 참여해 생중계 권한을 확보, 1일부터 대한민국 국가대표팀 전 경기를 고화질로 무료 생중계한다.
# 문장 정확도는 57.68%         6
# 형태소 정확도는 61.53999999999999%         6
# 문장 최종 정확도는51.53%         6
# 형태소 최종 정확도는53.15%         6
# 게임 축제 블리즈컨2019에서 신작 디아블로4와 오버워치2, 월드오브워크래프트 새 확장팩 등이 깜짝 공개됐다.신작 및 기존 서비스작 업데이트 버전 체험 가능
# 게임 축제 블리즈컨2019에서 신작 디아블로4와 오버워치2, 월드오브워크래프트 새 확장팩 등이 깜짝 공개됐다.블리자드엔터테인먼트는 1일 오전 10시 미국 캘리포니아 애너하임 컨벤션 센터에서 블리즈컨2019 개막을 알렸다.
# 문장 정확도는 59.050000000000004%         7
# 형태소 정확도는 61.22%         7
# 문장 최종 정확도는52.60%         7
# 형태소 최종 정확도는54.30%         7
# 한국계 미국인 제임스 박이 공동창업한 핏빗은 하루 걸음 수나 달린 거리, 소모된 칼로리양, 심장 박동수, 수면 시간과 수면의 질 등을 계측하는 스마트워치 등을 생산한다.핏빗은 1일(현지시간) 보도자료를 통해 "구글이 현금으로 주당 7.35달러에 핏빗을 인수하는 방안에 합의했다"고 밝혔다.
# 웨어러블 시장의 최강자로 자리매김한 '핏빗'이 세계 최대 검색엔진 업체 구글의 모회사 '알파벳'에 인수된다고 미 언론들이 1일 보도했다.한국계 미국인 제임스 박이 공동창업한 핏빗은 하루 걸음 수나 달린 거리, 소모된 칼로리양, 심장 박동수, 수면 시간과 수면의 질 등을 계측하는 스마트워치 등을 생산한다.
# 문장 정확도는 56.8%         8
# 형태소 정확도는 59.74%         8
# 문장 최종 정확도는53.13%         8
# 형태소 최종 정확도는54.98%         8
# 지난달 영국에서 냉동 컨테이너안에 숨진 채 발견된 39명이 모두 베트남 출신으로 추정된다는 현지 경찰의 발표에 베트남이 큰 충격에 빠졌습니다.레 티 투 항 베트남 외교부 대변인도 오늘 새벽 긴급 성명을 내고 "심각한 비극"이라며 "희생자 가족에게 위로의 말을 전한다"고 밝혔습니다.
# 지난달 영국에서 냉동 컨테이너안에 숨진 채 발견된 39명이 모두 베트남 출신으로 추정된다는 현지 경찰의 발표에 베트남이 큰 충격에 빠졌습니다.쩐 응옥 안 영국 주재 베트남 대사는 "영국경찰의 공식 통보를 받고 충격을 받았으며 매우 슬프다"고 말했습니다.
# 문장 정확도는 65.10000000000001%         9
# 형태소 정확도는 55.879999999999995%         9
# 문장 최종 정확도는54.46%         9
# 형태소 최종 정확도는55.08%         9
# 사람이 말하거나 구동 중인 동영상의 음성을 인공지능(AI)이 실시간으로 인식해 타이핑해주는 구글 드라이브의 음성입력 서비스가 큰 인기를 끌고 있습니다.30분짜리 강연도 한 번에…구글 드라이브 음성입력 이용 방법
# 사람이 말하거나 구동 중인 동영상의 음성을 인공지능이 실시간으로 인식해 타이핑해주는 구글 드라이브의 음성입력 서비스가 큰 인기를 끌고 있습니다.30분짜리 강연 영상을 틀어놓고 잠시 다른 일을 본 후 30분 후에 자리에 오면 이미 타이핑이 끝나 있는 문서를 확인할 수 있는 형태인데요.
# 문장 정확도는 66.18%         10
# 형태소 정확도는 63.160000000000004%         10
# 문장 최종 정확도는55.63%         10
# 형태소 최종 정확도는55.89%         10
# OOOOO에 들어갈 닥터오킴스의 독자적 성분은?’이라는 행운퀴즈를 출제했다.간편 송금 서비스 토스는 1일 ‘OOOOO은 수크랄페이트와 덱스판테놀의 복합체로 손상 받은 피부의 진정과 보호에 도움을 준다.
# '수크라테놀'과 관련한 토스 행운퀴즈가 등장했다.간편 송금 서비스 토스는 1일 'OOOOO은 수크랄페이트와 덱스판테놀의 복합체로 손상 받은 피부의 진정과 보호에 도움을 준다.OOOOO에 들어갈 닥터오킴스의 독자적 성분은?'이라는 행운퀴즈를 출제했다.
# 문장 정확도는 62.150000000000006%         11
# 형태소 정확도는 65.45%         11
# 문장 최종 정확도는56.22%         11
# 형태소 최종 정확도는56.76%         11
# '아시아나항공 우수회원' 토스 행운퀴즈 정답은?이어진 두번째 토스퀴즈는 "항공 탑승 및 아시아나 제휴 카드 이용 실적에 따라 골드, 다이아몬드, 다이아몬드 플러스, □□□□ 회원으로 승급된다.
# 간편송금 서비스 토스가 1일 '아시아나항공 우수회원'과 관련 행운퀴즈를 출제했다.마일리지가 반영되어 우수회원 자격을 보다 쉽게 획득하실 수 있다.
# 문장 정확도는 24.47%         12
# 형태소 정확도는 30.43%         12
# 문장 최종 정확도는53.58%         12
# 형태소 최종 정확도는54.56%         12
# 삼성전자의 이런 전략이 실적에 반영되기 시작했다는 분석이 나온다.갤럭시노트10과 중저가폰인 갤럭시A 시리즈 판매 호조로 3분기 깜짝 실적을 냈다.
# 삼성전자 스마트폰 사업 실적이 되살아났다.갤럭시노트10과 중저가폰인 갤럭시A 시리즈 판매 호조로 3분기 깜짝 실적을 냈다.
# 문장 정확도는 73.83%         13
# 형태소 정확도는 78.79%         13
# 문장 최종 정확도는55.13%         13
# 형태소 최종 정확도는56.43%         13
# LG전자는 30일 3분기 실적발표를 통해 매출액 15조7007억원, 영업이익 7814억원을 기록했다고 밝혔다.MC사업본부는 스마트폰 공장을 경기도 평택에서 베트남 하이퐁으로 이전함으로써 비용 개선에 성공한 것으로 분석된다.
# LG전자 스마트폰 사업이 18분기 연속 적자를 기록했으나 베트남 공장 이전을 통한 생산지 효율화와 원가개선으로 영업손실의 폭을 줄였다.LG전자는 30일 3분기 실적발표를 통해 매출액 15조7007억원, 영업이익 7814억원을 기록했다고 밝혔다.
# 문장 정확도는 46.92%         14
# 형태소 정확도는 37.5%         14
# 문장 최종 정확도는54.55%         14
# 형태소 최종 정확도는55.08%         14
# 갤럭시 폴드의 흥행 이후 위아래로 여닫는 ‘클램셸’ 형태 폴더블폰까지 공개한 삼성전자가 폴더블폰 시장 주도권을 이어갈 수 있을지 주목된다.고 사장은 중가형 스마트폰 갤럭시 A 시리즈에 대해선 “(수익성이) 목표한 것까지는 아직 안됐다”라며 “더 혁신이 필요하다”고 강조했다.
# 삼성전자가 2020년엔 폴더블폰 생산량을 늘리겠다고 밝혔다.갤럭시 폴드의 흥행 이후 위아래로 여닫는 '클램셸' 형태 폴더블폰까지 공개한 삼성전자가 폴더블폰 시장 주도권을 이어갈 수 있을지 주목된다.
# 문장 정확도는 57.03%         15
# 형태소 정확도는 64.52%         15
# 문장 최종 정확도는54.71%         15
# 형태소 최종 정확도는55.71%         15
# '온디맨드(O2O)' 업체가 늘어나며 단기고용직인 '긱 이코노미(단기근로)' 종사자가 급증하고 있지만 정규직이 아닌 탓에 관련업계가 관리문제로 몸살을 앓고 있다.채팅방 성희롱 논란에 이어 기사 욕설 논란까지 휩싸인 타다의 경우, 직접 고용이 아닌 알선업체를 통해 기사를 간접 고용하고 있어 직접 교육이 불가능하다고 주장한다.
# '온디맨드' 업체가 늘어나며 단기고용직인 '긱 이코노미' 종사자가 급증하고 있지만 정규직이 아닌 탓에 관련업계가 관리문제로 몸살을 앓고 있다.검증되지 않은 이들이 긱 이코노미 시장에 유입되면서 성희롱과 욕설·바가지 금액 책정 등 피해사례가 늘어나 업체마다 이미지 타격이 적지 않지만 인건비 부담으로 직접 고용이 어렵고 간접고용인 탓에 종사자 교육도 쉽지 않은 상황이다.
# 문장 정확도는 53.23%         16
# 형태소 정확도는 57.14%         16
# 문장 최종 정확도는54.62%         16
# 형태소 최종 정확도는55.80%         16
# ①법률상 문언적 근거가 있어 불법이라 보기 어렵고 ②타다에 대한 이용자 선택권을 침해했으며 ③4차 산업혁명 전환기에 낡은 규제로 신산업을 형사 기소하는 일은 잘못이라는 것이다.검찰은 어제(28일) 여객자동차운수사업법 위반 혐의로 박재욱 VCNC 대표와 이재웅 쏘카 대표를 각각 불구속 기소했다.
# 검찰이 승합차와 운전자 모두를 빌려주는 모빌리티 플랫폼 '타다' 운행이 불법이라고 판단하고 임원들을 불구속 기소하자, 벤처인들이 강력하게 반발하고 있다.검찰은 어제 여객자동차운수사업법 위반 혐의로 박재욱 VCNC 대표와 이재웅 쏘카 대표를 각각 불구속 기소했다.
# 문장 정확도는 49.68%         17
# 형태소 정확도는 56.720000000000006%         17
# 문장 최종 정확도는54.33%         17
# 형태소 최종 정확도는55.85%         17
# ‘에어팟 프로’의 ‘노이즈 캔슬링’ 기능을 이용하면 사용자는 주변 소음에 방해받지 않고 통화, 음악 감상에 집중할 수 있다.28일(이하 현지시간) 애플은 공식 자료를 통해 ‘에어팟 프로’를 30일부터 공식 스토어에서 판매한다고 밝혔다.
# 애플이 '노이즈 캔슬링' 기능이 탑재된 새로운 디자인의 '에어팟 프로'를 공개한 가운데 한국 소비자를 해외 소비자와 차별하고 있다는 지적이 나온다.28일 애플은 공식 자료를 통해 '에어팟 프로'를 30일부터 공식 스토어에서 판매한다고 밝혔다.
# 문장 정확도는 45.11%         18
# 형태소 정확도는 48.28%         18
# 문장 최종 정확도는53.82%         18
# 형태소 최종 정확도는55.43%         18
# 애플은 28일(현지시간) 노이즈 캔슬링과 인이어(귀 삽입형) 디자인 등을 갖춘 에어팟 프로를 공개했다.“아이폰11 흥행 잇는다”...애플, 32만원대 ‘에어팟 프로’ 공개
# 아이폰 11 시리즈로 글로벌 흥행을 이어가고 있는 애플이 새로운 프리미엄 무선 이어폰 '에어팟 프로'를 내놨다.애플은 28일 노이즈 캔슬링과 인이어 디자인 등을 갖춘 에어팟 프로를 공개했다.
# 문장 정확도는 43.78%         19
# 형태소 정확도는 45.0%         19
# 문장 최종 정확도는53.29%         19
# 형태소 최종 정확도는54.88%         19
# 국내 연구진이 포함된 국제 공동연구팀이 ‘호모사피엔스’(현생인류)가 아프리카 칼라하리 지역에 처음 나타났으며, 첫 번째 인류 대이동의 원인은 기후변화였다는 사실을 밝혀냈다.연구팀은 또 해양 퇴적물 같은 고(古)기후 및 지질학적 데이터와 슈퍼컴퓨터를 이용한 기후 모델을 분석한 결과 약 13만년 전 지구 자전축의 움직임이 변해 남반구의 일사량이 변하고 강수량이 이전과 달라지면서 현생인류가 발상지에서 벗어나 이주를 시작했다고 분석했다.
# 국내 연구진이 포함된 국제 공동연구팀이 '호모사피엔스'가 아프리카 칼라하리 지역에 처음 나타났으며, 첫 번째 인류 대이동의 원인은 기후변화였다는 사실을 밝혀냈다.호주의 가반의학연구소와 뉴사우스웨일스대, 한국의 기초과학연구원 기후물리연구단, 남아프리카공화국 로즈대, 나미비아 빈트후크중앙병원 등 10개 기관 연구진으로 구성된 국제공동연구팀은 현생인류가 20만년 전 아프리카 칼라하리 지역에서 처음 나타났고 13만년 전 기후변화 때문에 인류 대이동이 있었다는 연구 결과를 세계적인 과학저널 '네이처' 10월 29일자에 발표했다.
# 문장 정확도는 40.37%         20
# 형태소 정확도는 36.7%         20
# 문장 최종 정확도는52.64%         20
# 형태소 최종 정확도는53.97%         20
# SK텔레콤은 3000억원 규모의 자기주식을 카카오에 매각하고, 카카오는 신주를 발행해 SK텔레콤에 배정하는 방식으로 지분을 맞교환한다.SKT-카카오, 통신·커머스·디지털 콘텐츠·미래ICT 등 협력
# SK텔레콤은 카카오와 3000억원 규모의 지분을 교환하고 전략적 파트너십을 체결한다고 28일 밝혔다.SK텔레콤은 3000억원 규모의 자기주식을 카카오에 매각하고, 카카오는 신주를 발행해 SK텔레콤에 배정하는 방식으로 지분을 맞교환한다.
# 문장 정확도는 62.5%         21
# 형태소 정확도는 63.63999999999999%         21
# 문장 최종 정확도는53.11%         21
# 형태소 최종 정확도는54.43%         21
# 지난 주말새 비트코인 가격이 20% 이상 폭등하며 1000만원선을 회복한 가운데, 향후 암호화폐 시장 전망에 대한 업계의 의견이 갈리고 있다.시진핑 주석의 블록체인 육성 의지 천명에도 비트코인 비관론자들은 "중국의 블록체인 산업 육성과 비트코인은 별개로 봐야 한다"고 지적한다.
# 지난 주말새 비트코인 가격이 20% 이상 폭등하며 1000만원선을 회복한 가운데, 향후 암호화폐 시장 전망에 대한 업계의 의견이 갈리고 있다.중국 정부의 블록체인 육성정책 덕에 "내년 초 비트코인 가격이 5만달러까지 폭등할 것"이라는 시각과 "오히려 각국 정부의 코인시장 관리가 더 엄격해질 것"이라는 반대의견이 팽팽하게 맞선다.
# 문장 정확도는 61.36000000000001%         22
# 형태소 정확도는 54.55%         22
# 문장 최종 정확도는53.49%         22
# 형태소 최종 정확도는54.44%         22
# 카카오가 포털서비스 다음의 연예뉴스 댓글 서비스를 폐지하기로 해 포털업계 1위 네이버로 관심이 쏠리고 있다.앞서 2015년 2월부터 '뉴스댓글 상처 없는 댓글세상 만들기' 캠페인을 시작, 선플을 유도하고 있다.
# 카카오가 포털서비스 다음의 연예뉴스 댓글 서비스를 폐지하기로 해 포털업계 1위 네이버로 관심이 쏠리고 있다.네이버 역시 '악성 댓글'이나 '실시간 검색어 조작 논란'에서 자유롭지 않은 만큼 자정에 나서야 한다는 요구가 높아지는 형국이다.
# 문장 정확도는 54.620000000000005%         23
# 형태소 정확도는 59.260000000000005%         23
# 문장 최종 정확도는53.54%         23
# 형태소 최종 정확도는54.65%         23
# 유시민 노무현재단 이사장은 2일 조국 전 법무부 장관 가족에 대한 검찰 수사에 대해 "잔인무도하다"고 밝혔다.하고 싶은 것은 수단 방법을 가리지 않는다"며 "전두환 신군부 때를 보는 듯하다"고도 했다.
# 유시민 노무현재단 이사장은 2일 조국 전 법무부 장관 가족에 대한 검찰 수사에 대해 "잔인무도하다"고 밝혔다.유 이사장은 이날 노무현재단 전북지역위원회가 창립 8주년을 기념해 전주교육대에서 연 시민학교 대담에서 "검찰이 조국 전 장관의 80대 노모를 소환 조사하고 딸을 기소하겠다고 으름장을 놓는다.조국 일가족의 혐의점에 비해 무지무지하게 잔인하다"며 이같이 말했다.
# 문장 정확도는 47.32%         24
# 형태소 정확도는 42.42%         24
# 문장 최종 정확도는53.28%         24
# 형태소 최종 정확도는54.14%         24
# 이는 작년 11월 출시된 아이폰XS·XS맥스·아이폰XR 첫날 개통량(10만대 수준)과 비교하면 30% 이상 많은 수치다.26일 이동통신업계에 따르면 전날 시작된 아이폰11 시리즈의 개통량은 13만∼14만대로 추산된다.
# 25일 출시된 아이폰11 시리즈의 첫날 개통량이 전작인 아이폰XS·XR 시리즈보다 30%가량 높게 나타났다.26일 이동통신업계에 따르면 전날 시작된 아이폰11 시리즈의 개통량은 13만∼14만대로 추산된다.
# 문장 정확도는 62.980000000000004%         25
# 형태소 정확도는 57.89%         25
# 문장 최종 정확도는53.67%         25
# 형태소 최종 정확도는54.29%         25
# 26일 이동통신업계에 따르면 출시 첫날 아이폰11 시리즈 개통량은 13만~14만대로, 전작에 비해 30%가량 높은 것으로 나타났다.통신사간 판매 경쟁 과열 정도를 가늠해볼 수 있는 번호이동 건수는 전작에 비해 오히려 줄었다.
# 전날 국내에 공식 출시된 아이폰11 시리즈가 첫 테이프를 성공적으로 끊었다.26일 이동통신업계에 따르면 출시 첫날 아이폰11 시리즈 개통량은 13만~14만대로, 전작에 비해 30%가량 높은 것으로 나타났다.
# 문장 정확도는 60.83%         26
# 형태소 정확도는 48.78%         26
# 문장 최종 정확도는53.94%         26
# 형태소 최종 정확도는54.08%         26
# 네이버는 당초 경기도 용인시 기흥구에 제2 데이터센터를 건립하려고 했지만 주민 반대로 지난 6월 철회했다.지난 7일부터 18일까지 10개 후보 부지의 실사를 진행한 결과 세종을 우선 협상 부지로 결정하게 됐다.
# 네이버는 제2 데이터센터 우선 협상 대상 부지로 세종특별자치시를 선정했다고 25일 밝혔다.네이버는 당초 경기도 용인시 기흥구에 제2 데이터센터를 건립하려고 했지만 주민 반대로 지난 6월 철회했다.
# 문장 정확도는 52.21%         27
# 형태소 정확도는 53.059999999999995%         27
# 문장 최종 정확도는53.88%         27
# 형태소 최종 정확도는54.04%         27
# 삼성전자가 폴더블 스마트폰 '갤럭시 폴드'를 중국에 출시하기로 하면서 화웨이의 '메이트X'와 맞붙는다.메이트X 15일 출시…갤폴드, 내구성 검증에 가격도 50만원 저렴
# 삼성전자가 폴더블 스마트폰 '갤럭시 폴드'를 중국에 출시하기로 하면서 화웨이의 '메이트X'와 맞붙는다.삼성전자는 4일 중국판 트위터 '웨이보'를 통해 오는 8일 갤럭시 폴드를 중국에 출시한다고 밝혔다.
# 문장 정확도는 60.49%         28
# 형태소 정확도는 60.0%         28
# 문장 최종 정확도는54.11%         28
# 형태소 최종 정확도는54.25%         28
# 25일 KT, SK텔링크, LG유플러스에 따르면 내달 30일까지 삼성전자의 신형폰을 구매하는 소비자를 위해 중고폰 특별보상 프로그램을 시행한다.자급제 모델 기준 아이폰11은 99만~120만원, 아이폰11 프로는 139만~187만원, 아이폰11 프로 맥스는 155만~203만원이다.
# 삼성전자가 애플의 신형 아이폰11 시리즈 출시에 대항하기 위해 이동통신3사와 갤럭시노트10, 갤럭시S10 등의 중고폰 특별보상 프로그램에 돌입한다.25일 KT, SK텔링크, LG유플러스에 따르면 내달 30일까지 삼성전자의 신형폰을 구매하는 소비자를 위해 중고폰 특별보상 프로그램을 시행한다.
# 문장 정확도는 50.31%         29
# 형태소 정확도는 51.61%         29
# 문장 최종 정확도는53.98%         29
# 형태소 최종 정확도는54.16%         29
# LG전자는 미국에서 판매 중인 대부분의 하이센스 TV 제품이 LG전자가 보유한 특허를 침해했다며 특허침해금지 및 손해배상청구소송을 냈다."사용자 인터페이스 개선을 위한 기술 등 특허 4건 침해"
# LG전자가 4일 미국 캘리포니아지방법원에 '하이센스'를 상대로 TV 관련 특허침해금지소송을 제기했다.LG전자는 미국에서 판매 중인 대부분의 하이센스 TV 제품이 LG전자가 보유한 특허를 침해했다며 특허침해금지 및 손해배상청구소송을 냈다.
# 문장 정확도는 25.83%         30
# 형태소 정확도는 62.07%         30
# 문장 최종 정확도는53.04%         30
# 형태소 최종 정확도는54.42%         30
# 개천절에 찾아온 10월 태풍 '미탁'의 영향으로 지난달 전국에 내린 비의 양이 관측 이후 가장 많았던 것으로 나타났습니다.울진지역에는 10월 2일 하루에 332.9mm의 비가 내렸고 10월 3일에는 한 시간에 104.5mm의 매우 강한 비가 퍼부었습니다.
# 개천절에 찾아온 10월 태풍 '미탁'의 영향으로 지난달 전국에 내린 비의 양이 관측 이후 가장 많았던 것으로 나타났습니다.기상청은 지난달 1일부터 3일 사이에 '미탁'이 우리나라를 지나며 10월 전국 평균 강수량이 169㎜로 평년보다 3~5배 정도 많았다고 분석했습니다.
# 문장 정확도는 56.66%         31
# 형태소 정확도는 52.0%         31
# 문장 최종 정확도는53.16%         31
# 형태소 최종 정확도는54.35%         31
# LG전자가 지난 1일 북미 시장에 출시한 'LG G8X 씽큐(국내명 LG V50S)와 'LG 듀얼 스크린'에 대한 외신의 호평이 이어지고 있다.G8X는 전면에 3200만 고화소 카메라를 달았다.
# LG전자가 지난 1일 북미 시장에 출시한 'LG G8X 씽큐와 'LG 듀얼 스크린'에 대한 외신의 호평이 이어지고 있다.포브스는 "G8의 뛰어난 멀티태스킹 능력은 미니 노트북처럼 사용할 수 있을 정도로 뛰어나다"며 "실용적이고 합리적인 가격에 내구성까지 갖춘 제품"이라고 극찬했다.
# 문장 정확도는 55.85%         32
# 형태소 정확도는 52.38%         32
# 문장 최종 정확도는53.24%         32
# 형태소 최종 정확도는54.28%         32
# 그러나 법원 관계자는 이번 탈주가 계획된 것으로 보인다고 전했다.태국에서 죄수 세 명이 재판을 받기 위해 도착한 법원에서 경찰을 총으로 쏘고 차를 타고 달아나는 사건이 발생했다고 일간 방콕포스트가 5일 보도했다.
# 태국에서 죄수 세 명이 재판을 받기 위해 도착한 법원에서 경찰을 총으로 쏘고 차를 타고 달아나는 사건이 발생했다고 일간 방콕포스트가 5일 보도했다.신문에 따르면 사건은 전날 파타야 지방법원에서 발생했다.
# 문장 정확도는 71.0%         33
# 형태소 정확도는 73.47%         33
# 문장 최종 정확도는53.78%         33
# 형태소 최종 정확도는54.87%         33
# 하지만 수색팀은 3일 아침 “크레타섬과 폴레간드로스섬 중간 지점에서” 그녀를 찾아냈다.화제의 주인공은 항해 경험이 많았던 쿠실라 스타인(45). 터키 남부에서 그리스 아테네로 건너가는 요트 ‘라이벌 34’ 호를 몰던 영국인 남성의 일손을 거들겠다며 동승했다.
# 뉴질랜드 여성이 혼자서 고무보트에 실려 그리스에서 가장 큰 크레타섬 근처 에게해 바다를 이틀 가까이 표류하다 무사히 구조됐다.터키 남부에서 그리스 아테네로 건너가는 요트 '라이벌 34' 호를 몰던 영국인 남성의 일손을 거들겠다며 동승했다.
# 문장 정확도는 50.54%         34
# 형태소 정확도는 48.28%         34
# 문장 최종 정확도는53.69%         34
# 형태소 최종 정확도는54.67%         34
# 미국과 중국의 패권 경쟁이 거센 가운데 시진핑(習近平) 중국 국가주석이 RCEP(역내포괄적경제동반자협정) 타결과 국제수입박람회를 통해 '스트롱맨'으로 우뚝 섰다.더구나 시진핑 주석은 5일 개막한 제2회 국제수입박람회를 통해 제2 경제 대국이자 13억 인구의 막강한 구매력을 전 세계에 과시하고 나섰다.
# 미국과 중국의 패권 경쟁이 거센 가운데 시진핑 중국 국가주석이 RCEP 타결과 국제수입박람회를 통해 '스트롱맨'으로 우뚝 섰다.도널드 트럼프 미국 대통령과 함께 글로벌 지도자를 다투는 시진핑 주석은 중국 주도의 세계 최대 규모의 '메가 FTA'와 국제수입박람회에서 세계 최대 구매력을 과시함으로써 미국 경제 패권에 가장 위협적인 인물로 급부상했기 때문이다.
# 문장 정확도는 53.949999999999996%         35
# 형태소 정확도는 52.27%         35
# 문장 최종 정확도는53.69%         35
# 형태소 최종 정확도는54.60%         35
# 중국에서 '가장 폭발력 있는 작가', '가장 문제적인 작가' 등으로 불리는 옌롄커(염련과·閻連科)가 한국을 방문해 강연을 펼친다.옌롄커는 이달 12일 오후 7시30분 서울 광화문 교보빌딩 23층 교보컨벤션홀에서 '침묵과 한숨 - 내가 경험한 중국과 문학'을 주제로 강연을 펼친다.
# 중국에서 '가장 폭발력 있는 작가', '가장 문제적인 작가' 등으로 불리는 옌롄커가 한국을 방문해 강연을 펼친다.교보문고와 대산문화재단은 5일 "한국 독자와 세계 작가의 접점을 확장하기 위해 '세계 작가와의 대화'를 시작한다"며 "첫 작가로 옌롄커를 초청한다"고 밝혔다.
# 문장 정확도는 44.95%         36
# 형태소 정확도는 39.39%         36
# 문장 최종 정확도는53.45%         36
# 형태소 최종 정확도는54.18%         36
# 토픽스(TOPIX) 지수도 전 거래일 종가 대비 20.98포인트 상승해 1,687.48로 올랐다.전날 미국 뉴욕증시의 3대지수가 역대 최고치를 기록하며 호조를 보인 영향으로 5일 일본 도쿄증시의 니케이지수도 올해 최고치를 경신했다.
# 전날 미국 뉴욕증시의 3대지수가 역대 최고치를 기록하며 호조를 보인 영향으로 5일 일본 도쿄증시의 니케이지수도 올해 최고치를 경신했다.이날 일본 도쿄 증시는 미국 주식 시장 호조의 영향으로 사자 주문이 이어져 오전 9시15분 기준 니케이지수가 전 거래일 종가보다 347.81포인트 상승한 23,198.58로 올해 최고가를 기록했다.
# 문장 정확도는 47.77%         37
# 형태소 정확도는 48.480000000000004%         37
# 문장 최종 정확도는53.30%         37
# 형태소 최종 정확도는54.03%         37
# 개인 간 대출 거래를 제도권으로 끌어들이는 일명 'P2P법'이 국회 본회의를 통과되면서 관련 스타트업 대표가 박용만 대한상공회의소 회장에게 감사인사를 전했다.김 대표는 "업계 전체에 영웅이 되어주신 박용만 회장님 제가 꼭 한번 업어드릴게요"라며 감사를 표했다.
# 개인 간 대출 거래를 제도권으로 끌어들이는 일명 'P2P법'이 국회 본회의를 통과되면서 관련 스타트업 대표가 박용만 대한상공회의소 회장에게 감사인사를 전했다.2일 대한상의에 따르면 김성준 렌딧 대표는 지난달 31일 박용만 대한상의 회장의 페이스북 담벼락에 "드디어 큰 사건이 하나 터졌다.많은 분들께서 도와주신 덕분"이라며 "열심히 해서 꼭 좋은 모습 보여드리겠다"는 글을 남겼다.
# 문장 정확도는 59.78%         38
# 형태소 정확도는 67.61%         38
# 문장 최종 정확도는53.47%         38
# 형태소 최종 정확도는54.38%         38
# 코트라는 6일부터 이틀간 필리핀 마닐라에서 '한·아세안 프로젝트 플라자'를 개최한다고 5일 밝혔다.플랜트산업협회와 공동 주최한 이번 행사는 인프라 협력 포럼, 수출 상담회, 네트워킹 등으로 구성됐으며, 건설·수처리·에너지 분야의 해외 발주처 및 바이어 업체 100개사와 국내 기업 40개사가 참가한다.
# 코트라는 6일부터 이틀간 필리핀 마닐라에서 '한·아세안 프로젝트 플라자'를 개최한다고 5일 밝혔다.플랜트산업협회와 공동 주최한 이번 행사는 인프라 협력 포럼, 수출 상담회, 네트워킹 등으로 구성됐으며, 건설·수처리·에너지 분야의 해외 발주처 및 바이어 업체 100개사와 국내 기업 40개사가 참가한다.
# 문장 정확도는 100.0%         39
# 형태소 정확도는 100.0%         39
# 문장 최종 정확도는54.66%         39
# 형태소 최종 정확도는55.55%         39
# 이언주 국회의원(무소속, 경기 광명을)은 2일 "북핵을 폐기하고 우리한테 필요한 도움이라면 과거사고 나발이고 무조건 (미국·일본에) 손잡고 도움을 청해야 한다"고 주장했다.연설대에 오른 황영호 위원장은 문재인 대통령을 향해 "조국이라는 희대의 사기꾼·악마같은 놈을 법무부장관으로 임명했다"면서 "미친X 아니냐"고 강한 어조로 비판하기도 했다.
# 이언주 국회의원은 2일 "북핵을 폐기하고 우리한테 필요한 도움이라면 과거사고 나발이고 무조건 손잡고 도움을 청해야 한다"고 주장했다.이 의원은 이날 충북 청주시 상당공원 인근에서 열린 '문재인 정권 규탄 집회'에 참석해 현 정부의 외교정책을 비판하며 이 같이 말했다.
# 문장 정확도는 51.18000000000001%         40
# 형태소 정확도는 45.33%         40
# 문장 최종 정확도는54.58%         40
# 형태소 최종 정확도는55.30%         40
# 홍콩의 민주화 요구 시위가 장기화되는 가운데 시진핑(習近平) 중국 국가주석이 캐리 람 홍콩 행정장관과 전격적으로 만났다.하지만 시 주석이 람 장관에게 “홍콩의 풍파가 이미 5개월째 지속하고 있다”고 말한 점으로 미뤄 사태를 방치한데 대한 ‘문책성 회동’이 아니냐는 분석도 나온다.
# 홍콩의 민주화 요구 시위가 장기화되는 가운데 시진핑 중국 국가주석이 캐리 람 홍콩 행정장관과 전격적으로 만났다.이는 시 주석이 캐리람 장관에 대해 재신임을 천명하고 힘을 실어주는 것으로 향후 홍콩 정부가 시위를 더욱 강경하게 진압할 것이란 관측이 나온다.
# 문장 정확도는 57.05%         41
# 형태소 정확도는 57.97%         41
# 문장 최종 정확도는54.64%         41
# 형태소 최종 정확도는55.36%         41
# 미국 '위성 위치 확인 시스템(GPS)'에 대응해 '베이더우(北斗)' 시스템을 개발 중인 중국이 이를 위한 인공위성 발사에 또다시 성공했다.이번에 발사된 위성과 로켓은 중국항천과기집단 산하 중국공간기술연구원과 중국운반로켓기술연구원에서 각각 제작했다.
# 미국 '위성 위치 확인 시스템'에 대응해 '베이더우' 시스템을 개발 중인 중국이 이를 위한 인공위성 발사에 또다시 성공했다.중국은 5일 오전 1시 43분 쓰촨성 시창위성발사센터에서 창정-3호 이 운반 로켓으로 베이더우 3호 시스템 위성 1기를 추가로 궤도에 올리는 데 성공했다고 신화통신이 전했다.
# 문장 정확도는 51.800000000000004%         42
# 형태소 정확도는 51.519999999999996%         42
# 문장 최종 정확도는54.57%         42
# 형태소 최종 정확도는55.27%         42
# 최근 사망한 이슬람국가(IS)의 수괴 아부 바크르 알바그다디의 친누나가 터키 당국에 생포된 것으로 전해졌다.이날 아와드가 잡힌 시리아 북서부는 지난 2016년 터키가 IS 세력과 쿠르드군을 몰아내려고 '유프라테스 방패' 작전을 벌여 장악한 지역이다.
# 최근 사망한 이슬람국가의 수괴 아부 바크르 알바그다디의 친누나가 터키 당국에 생포된 것으로 전해졌다.AP, 로이터 통신 등에 따르면 터키의 한 고위 당국자는 4일 저녁 시리아 북서부의 알레포 주 앗자즈에서 알바그다디의 친누나인 라스미야 아와드를 붙잡았다고 밝혔다.
# 문장 정확도는 46.150000000000006%         43
# 형태소 정확도는 53.12%         43
# 문장 최종 정확도는54.37%         43
# 형태소 최종 정확도는55.22%         43
# 핼러윈 파티장에서 총격 사건이 발생해 4명이 숨지는 등 미국의 대표적 축제일인 '핼러윈 데이'가 핏빛으로 물들었다.파티장에서 총성이 잇달아 들리자 참석자들은 비명을 지르고 혼비백산해 파티장을 뛰쳐나왔다.
# 핼러윈 파티장에서 총격 사건이 발생해 4명이 숨지는 등 미국의 대표적 축제일인 '핼러윈 데이'가 핏빛으로 물들었다.캘리포니아주 샌프란시스코 베이 지역 인근 부촌의 한 주택에서 지난달 31일 밤 10시 45분쯤 총격 사건이 발생했다.
# 문장 정확도는 59.5%         44
# 형태소 정확도는 59.57%         44
# 문장 최종 정확도는54.49%         44
# 형태소 최종 정확도는55.32%         44
# 오후 6시53분께 칠레 중부 이야펠 인근에서 규모 6.0의 강진이 발생했다.또한 이번 강진으로 인해 태평양 연안 일대에 쓰나미(지진해일)가 일어나지는 않을 것이라고 전망했다.
# 4일 오후 6시53분께 칠레 중부 이야펠 인근에서 규모 6.0의 강진이 발생했다.이번 지진은 수도 산티아고에서 대규모 반정부 시위가 진행되던 와중에 일어났지만, 인명 피해는 없는 것으로 알려졌다.
# 문장 정확도는 49.51%         45
# 형태소 정확도는 53.66%         45
# 문장 최종 정확도는54.38%         45
# 형태소 최종 정확도는55.28%         45
# 현대차는 5일, 전국 영업점에서 전날부터 사전계약에 들어갔던 더 뉴 그랜저의 첫날 계약 대수가 1만 7,294대로 나타났다고 밝혔다.더 뉴 그랜저는 6세대 그랜저의 부분변경(페이스리프트) 모델임에도 신차급 변화를 줬다는 평가를 받는다.
# 현대자동차의 '더 뉴 그랜저'가 사전계약 첫날에만 1만 7,294대의 계약 기록을 세우며 역대 최다 신기록을 세웠다.현대차는 5일, 전국 영업점에서 전날부터 사전계약에 들어갔던 더 뉴 그랜저의 첫날 계약 대수가 1만 7,294대로 나타났다고 밝혔다.
# 문장 정확도는 54.81%         46
# 형태소 정확도는 49.059999999999995%         46
# 문장 최종 정확도는54.39%         46
# 형태소 최종 정확도는55.15%         46
# 의류 및 패션 분야에서 '미디어 커머스' 온라인 채널 확보경쟁이 치열하다.영상 전문 스타트업 전문가들이 제작한 웹드라마, 웹예능, 콩트 등을 비롯해 아마추어가 제작한 영상, 일반 소비자들의 솔직한 제품 리뷰도 선보인다.
# 의류 및 패션 분야에서 '미디어 커머스' 온라인 채널 확보경쟁이 치열하다.온라인 쇼핑 규모는 최초로 110조원을 넘으며 2017년 온라인 쇼핑 규모 대비 약 22.6% 늘어났다.
# 문장 정확도는 43.44%         47
# 형태소 정확도는 41.67%         47
# 문장 최종 정확도는54.15%         47
# 형태소 최종 정확도는54.86%         47
# 소속사인 스타쉽엔터테인먼트는 대마 흡연 의혹까지 불거지자 이날 "더 계약을 유지할 수 없다고 판단했다"며 원호와 계약을 해지했다.1일 경찰에 따르면 서울지방경찰청 광역수사대는 원호의 대마 흡연 의혹과 관련해 내사 중이다.
# 대마 흡연 의혹이 불거진 보이 그룹 '몬스타엑스' 전 멤버 원호에 대해 경찰이 사실관계를 들여다보고 있다.1일 경찰에 따르면 서울지방경찰청 광역수사대는 원호의 대마 흡연 의혹과 관련해 내사 중이다.
# 문장 정확도는 50.63999999999999%         48
# 형태소 정확도는 61.82%         48
# 문장 최종 정확도는54.08%         48
# 형태소 최종 정확도는55.01%         48
# 위화, 모옌과 더불어 중국의 3대 거장으로 평가받는 문제적 작가 옌롄커가 한국독자들과 만남을 갖는다.옌롄커는 1978년 인민해방군으로 입대해 28년간 직업군인으로 복무한 이력을 갖고 있다.
# 위화, 모옌과 더불어 중국의 3대 거장으로 평가받는 문제적 작가 옌롄커가 한국독자들과 만남을 갖는다.교보문고와 대산문화재단은 '세계작가와의 대화' 프로그램을 신설, 첫 작가로 현재 중국에서 가장 폭발력 있는 작가이자 노벨문학상 후보로 오르내리는 옌롄커를 초청, 독자들과의 만남을 진행한다.
# 문장 정확도는 46.62%         49
# 형태소 정확도는 45.28%         49
# 문장 최종 정확도는53.93%         49
# 형태소 최종 정확도는54.81%         49
# 현재 기획재정부에서 국제행사심사위원회 전문위원회 민간위원과 자체규제심의위원회 민간위원으로 활동중이며, 자유한국당 법률자문위원으로도 활동하고 있다.권세호 삼영회계법인 대표는 5일 "이 세상에서 가장 쉬운 회계학 책을 써야겠다는 마음으로 지난달 '권세호의 별에서 온 회계학'을 펴냈다"며 이같이 말했다.
# "한국공인회계사, 미국공인회계사로 한국, 미국, 중국, 싱가포르 등에서 일하며 배우며 느끼고 고민한 생각과 경험을 담았습니다.권세호 삼영회계법인 대표는 5일 "이 세상에서 가장 쉬운 회계학 책을 써야겠다는 마음으로 지난달 '권세호의 별에서 온 회계학'을 펴냈다"며 이같이 말했다.
# 문장 정확도는 58.199999999999996%         50
# 형태소 정확도는 52.05%         50
# 문장 최종 정확도는54.01%         50
# 형태소 최종 정확도는54.75%         50
# 서적 유통업체 예스24(대표 김석환)는 자체 블록체인 플랫폼 'sey체인' 메인넷을 론칭했다고 5일 밝혔다.독자들은 디지털 콘텐츠 플랫폼 '시프트북스'에서 마음에 드는 작품을 응원하는 활동을 통해 sey코인을 받고 작가들 또한 독자 응원 순위에 따른 보상으로 sey코인을 받는다.
# 서적 유통업체 예스24는 자체 블록체인 플랫폼 'sey체인' 메인넷을 론칭했다고 5일 밝혔다.sey체인은 지난 2018년 8월 이더리움 ERC-20 기반으로 가상화폐 sey토큰을 론칭한 예스24가 독자적인 블록체인 생태계 구축을 목표로 개발했으며 파트너사들과 함께 운영할 수 있는 컨소시엄형 메인넷을 지향한다.
# 문장 정확도는 41.339999999999996%         51
# 형태소 정확도는 33.85%         51
# 문장 최종 정확도는53.77%         51
# 형태소 최종 정확도는54.34%         51
# 중국에서 '가장 폭발력 있는 작가', '가장 문제적인 작가' 등으로 불리는 옌롄커(염련과·閻連科)가 한국을 방문해 강연을 펼친다.옌롄커는 이달 12일 오후 7시30분 서울 광화문 교보빌딩 23층 교보컨벤션홀에서 '침묵과 한숨 - 내가 경험한 중국과 문학'을 주제로 강연을 펼친다.
# 중국에서 '가장 폭발력 있는 작가', '가장 문제적인 작가' 등으로 불리는 옌롄커가 한국을 방문해 강연을 펼친다.교보문고와 대산문화재단은 5일 "한국 독자와 세계 작가의 접점을 확장하기 위해 '세계 작가와의 대화'를 시작한다"며 "첫 작가로 옌롄커를 초청한다"고 밝혔다.
# 문장 정확도는 44.95%         52
# 형태소 정확도는 39.39%         52
# 문장 최종 정확도는53.60%         52
# 형태소 최종 정확도는54.06%         52
# 문화재청 궁능유적본부 덕수궁관리소는 오는 8일 낮 12시15분부터 오후 1시까지 서울 덕수궁 돌담길에서 '덕수궁 돌담길 음악회'를 개최한다고 5일 밝혔다.덕수궁을 찾은 관람객 누구나 무료로 감상할 수 있으며 자세한 사항은 덕수궁관리소 누리집에서 확인할 수 있다.
# 문화재청 궁능유적본부 덕수궁관리소는 오는 8일 낮 12시15분부터 오후 1시까지 서울 덕수궁 돌담길에서 '덕수궁 돌담길 음악회'를 개최한다고 5일 밝혔다.문화재청은 지난해 12월 막혀 있던 덕수궁 돌담길 70m 구간의 궁 안쪽에 보행로를 만들어 연결했다.
# 문장 정확도는 64.58%         53
# 형태소 정확도는 65.57%         53
# 문장 최종 정확도는53.80%         53
# 형태소 최종 정확도는54.27%         53
# 대기업 면세점 두 곳이 한꺼번에 사업을 접으면서 관심은 이달 예정된 시내면세점 흥행에 쏠리고 있다.이처럼 시내면세점 흥행이 저조한 이유는 실적이 '황금알을 낳는 거위'에서 '독이 든 성배'로 추락했기 때문이다.
# 두산그룹이 4년만에 면세사업을 포기하면서 이달 예정된 서울 시내면세점 입찰 흥행에도 비상이 걸린 상황이다.두산에 이어 올 상반기 한화도 면세사업 철수를 선언하면서 '대기업도 못견디는 시장'이라는 이미지가 더 강해졌기 때문이다.
# 문장 정확도는 33.739999999999995%         54
# 형태소 정확도는 27.450000000000003%         54
# 문장 최종 정확도는53.43%         54
# 형태소 최종 정확도는53.78%         54
# 대한민국 임시정부 수립 100주년을 기념해 제작된 뮤지컬 '도산 안창호'가 오는 16~17일 양일 간 나루아트센터 대극장에서 공연된다.흥사단은 우리가 잘 알지 못했던 도산의 정신과 업적, 나라의 중요성과 독립운동가의 헌신을 뮤지컬을 통해 알리고자 이 작품을 제작했다.
# 대한민국 임시정부 수립 100주년을 기념해 제작된 뮤지컬 '도산 안창호'가 오는 16~17일 양일 간 나루아트센터 대극장에서 공연된다.흥사단은 우리가 잘 알지 못했던 도산의 정신과 업적, 나라의 중요성과 독립운동가의 헌신을 뮤지컬을 통해 알리고자 이 작품을 제작했다.
# 문장 정확도는 100.0%         55
# 형태소 정확도는 100.0%         55
# 문장 최종 정확도는54.28%         55
# 형태소 최종 정확도는54.62%         55
# 지난해 무대에 처음 오른 이 무용은 2019 한국문화예술위원회 공연예술 창작산실 올해의 레퍼토리에 선정된 작품이다.환각제 등이 우리 신체를 자극하게 됐을 때 몸은 과연 어떻게 변하게 될까.
# 환각제 등이 우리 신체를 자극하게 됐을 때 몸은 과연 어떻게 변하게 될까.오는 8~9일 이틀간 서울 대학로예술극장 대극장에서 공연되는 'OPIUM'은 환각제로 사용되는 양귀비에서 착안, 감각이 극대화했을 때 나타나는 신체 변형과 변신을 탐구한 현대무용이다.
# 문장 정확도는 33.06%         56
# 형태소 정확도는 30.19%         56
# 문장 최종 정확도는53.90%         56
# 형태소 최종 정확도는54.18%         56
# 매일 출퇴근을 하는 정기통근자(월 44회 이용)의 경우 현재 1만3200원까지 적립할 수 있었으나 이번 마일리지 확대로 최대 1만9800원까지 적립할 수 있게 됐다.국토교통부 대도시권광역교통위원회(대광위)는 이달부터 광역알뜰교통카드 이용자들의 마일리지 혜택을 1회당 300원에서 350~450원으로 확대한다고 5일 밝혔다.
# 광역알뜰교통카드를 활용한 보행·자전거 마일리지 적립 혜택이 확대된다.국토교통부 대도시권광역교통위원회는 이달부터 광역알뜰교통카드 이용자들의 마일리지 혜택을 1회당 300원에서 350~450원으로 확대한다고 5일 밝혔다.
# 문장 정확도는 63.12%         57
# 형태소 정확도는 57.14%         57
# 문장 최종 정확도는54.06%         57
# 형태소 최종 정확도는54.23%         57
# 김현미 국토교통부 장관은 31일 오전 국회에서 열린 ‘대도시권 광역교통 비전 2030’ 발표를 위한 당정 협의에서 이같이 말했다.수도권 서부권을 관통하는 광역급행철도(GTX) 신규 노선(가칭 GTX D)을 내년 하반기 확정·발표한다.
# "광역급행철도 수혜범위를 확대하기 위해 수도권 서부권 등에 신규 급행노선을 추가로 검토해 내년 하반기까지 확정·발표하겠습니다.수도권 서부권을 관통하는 광역급행철도 신규 노선을 내년 하반기 확정·발표한다.
# 문장 정확도는 23.87%         58
# 형태소 정확도는 44.440000000000005%         58
# 문장 최종 정확도는53.54%         58
# 형태소 최종 정확도는54.06%         58
# 프랑스 스파 브랜드 달팡(DARPHIN)이 신제품 ‘8-플라워 골든 넥타 오일’을 출시했다고 밝혔다.‘8-플라워 골든 넥타 오일’은 전 세계를 걸쳐 혼합된 8가지 꽃(진귀한 임모르텔, 일랑 일랑, 패츌리, 네롤리, 로즈, 라벤더, 쟈스민, 아이리스)들의 추출물이 함유되어 있다.
# 프랑스 스파 브랜드 달팡이 신제품 '8-플라워 골든 넥타 오일'을 출시했다고 밝혔다.'8-플라워 골든 넥타 오일'은 전 세계를 걸쳐 혼합된 8가지 꽃들의 추출물이 함유되어 있다.
# 문장 정확도는 74.8%         59
# 형태소 정확도는 81.47999999999999%         59
# 문장 최종 정확도는53.90%         59
# 형태소 최종 정확도는54.53%         59
# 캐시슬라이드가 '안다르 피치레깅스 대란' 초성퀴즈를 출제했다.한편, 해당 퀴즈는 캐시슬라이드 앱에서 참여할 수 있으며 문제가 바뀔 경우 정답 또한 달라진다.
# 캐시슬라이드가 '안다르 피치레깅스 대란' 초성퀴즈를 출제했다.캐시슬라이드는 5일 안다르와 함께 "올 겨울 필수템, 피치레깅스 오늘만 ㅇㅁㅇㅊㅇ"란 초성퀴즈를 냈다.
# 문장 정확도는 48.309999999999995%         60
# 형태소 정확도는 50.0%         60
# 문장 최종 정확도는53.81%         60
# 형태소 최종 정확도는54.45%         60
# FCMM이 1일부터 오는 3일까지 'FCMM 데이' 이벤트를 진행한다.'FCMM데이'는 일년에 딱 한 번 진행되는 파격 할인 행사로 구스패딩부터, 인기품목인 플리스 자켓, 4계절 필수템인 후드, 팬츠까지 신상을 포함한 전상품을 최대 90% 할인된 가격에 판매한다.
# FCMM이 1일부터 오는 3일까지 'FCMM 데이' 이벤트를 진행한다.'FCMM데이'는 일년에 딱 한 번 진행되는 파격 할인 행사로 구스패딩부터, 인기품목인 플리스 자켓, 4계절 필수템인 후드, 팬츠까지 신상을 포함한 전상품을 최대 90% 할인된 가격에 판매한다.
# 문장 정확도는 100.0%         61
# 형태소 정확도는 100.0%         61
# 문장 최종 정확도는54.57%         61
# 형태소 최종 정확도는55.20%         61
# 5일 토스 행운 퀴즈로 '하나멤버스100만원' 관련 퀴즈가 출제되어 화제를 모으고 있다.출제자 측은 포털 사이트에 '시몬스 난연 매트리스'를 검색하면 힌트를 찾을 수 있다고 전했다.
# 토스 행운 퀴즈로 '하나멤버스100만원' 관련 문제가 출제됐다.5일 토스 행운 퀴즈로 '하나멤버스100만원' 관련 퀴즈가 출제되어 화제를 모으고 있다.
# 문장 정확도는 49.730000000000004%         62
# 형태소 정확도는 46.150000000000006%         62
# 문장 최종 정확도는54.49%         62
# 형태소 최종 정확도는55.05%         62
# 티웨이항공은 4일부터 전용 간편 결제 서비스인 '티웨이 페이'를 실시한다고 밝혔다.또한 티웨이항공은 오는 24일까지 티웨이 페이 런칭 기념 이벤트를 진행한다.
# 티웨이항공은 4일부터 전용 간편 결제 서비스인 '티웨이 페이'를 실시한다고 밝혔다.티웨이 페이는 전용 간편 결제 시스템으로 자주 쓰는 결제 카드를 사전에 등록해두면 결제 시마다 추가로 정보를 입력할 필요 없이 편리하게 사용할 수 있다.
# 문장 정확도는 50.23%         63
# 형태소 정확도는 48.89%         63
# 문장 최종 정확도는54.42%         63
# 형태소 최종 정확도는54.96%         63
# 출제된 퀴즈는 "홈랩에서 출시한 어린이집 낮잠용 이불의 풀네임은? ㄱㅈㅂㄷㅋㅈㅅㅌ"이며, 초성 부분을 맞추는 문제다.'박나래 기절토퍼 반값' 관련 퀴즈가 출제돼 화제다.
# 박나래 기절토퍼 반값' 관련 퀴즈가 출제돼 화제다.5일 버즈빌 계열 리워드 앱에서는 '박나래 기절토퍼 반값' 관련 퀴즈가 출제됐다.
# 문장 정확도는 35.93%         64
# 형태소 정확도는 40.0%         64
# 문장 최종 정확도는54.13%         64
# 형태소 최종 정확도는54.72%         64
# 오리온은 기존 판형 웨하스의 가격을 인하해 가성비를 높인 ‘오리온 웨하스’를 출시한다고 5일 밝혔다.더불어 작은 크기로 취식 편의성이 높은 ‘오리온 미니 웨하스’와 네겹 제품인 ‘오리온 웨하스-미니’등 웨하스 라인업을 강화했다.
# 오리온은 기존 판형 웨하스의 가격을 인하해 가성비를 높인 '오리온 웨하스'를 출시한다고 5일 밝혔다.오리온 웨하스는 가성비 트렌드에 발맞춰 소비자들이 부담 없이 구매할 수 있도록 60g 규격을 편의점가 기준 900원에 선보인다.
# 문장 정확도는 50.39%         65
# 형태소 정확도는 54.900000000000006%         65
# 문장 최종 정확도는54.07%         65
# 형태소 최종 정확도는54.72%         65
# 몽벨의 보이기 위한 화려함 보다는 품질 우선의 제품을 만드는 브랜드 정신에 커버낫의 유니크한 제품을 녹여 아웃도어와 캐주얼의 벽을 넘나드는 새로운 제품을 만들어냈다.커버낫과 몽벨의 협업으로 선보이는 제품은 프리미엄 구스다운인 헝가리 구스다운을 사용한 숏 패딩, 보아 자켓, 보아 베스트, 플리스 크루넥, 캡, 럭색 총 6가지 이다.
# 국내 스트릿 브랜드 커버낫과 44년 전통 아웃도어 브랜드 몽벨이 콜라보레이션을 선보였다.몽벨의 보이기 위한 화려함 보다는 품질 우선의 제품을 만드는 브랜드 정신에 커버낫의 유니크한 제품을 녹여 아웃도어와 캐주얼의 벽을 넘나드는 새로운 제품을 만들어냈다.
# 문장 정확도는 56.44%         66
# 형태소 정확도는 47.760000000000005%         66
# 문장 최종 정확도는54.11%         66
# 형태소 최종 정확도는54.62%         66
# 임 전무는 이정재와의 데이트 장면이 포착될 때마다 패션 아이템이 덩달아 화제가 됐다.지난 1일 한 매체는 이정재와 임 전무 커플이 인천국제공항을 통해 출국하는 모습을 전했다.
# 임세령 대상 전무가 연인 사이인 배우 이정재와 동반 출국하는 현장이 포착되면서, 그의 패션에 또다시 관심이 쏠리고 있다.지난 1일 한 매체는 이정재와 임 전무 커플이 인천국제공항을 통해 출국하는 모습을 전했다.
# 문장 정확도는 64.49000000000001%         67
# 형태소 정확도는 65.31%         67
# 문장 최종 정확도는54.26%         67
# 형태소 최종 정확도는54.78%         67
