# %%
import difflib
import numpy as np
import krwordrank
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter
from konlpy.tag import Okt
from PIL import Image
from pykospacing import spacing
import krwordrank
from krwordrank.sentence import summarize_with_sentences
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\jungs\Anaconda3\envs\py36\lib\site-packages\tensorflow\python\util\deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead

# %% [markdown]
# 데이터 전처리(엔터를 기준으로 한 문장으로 인식)

# %%
okt = Okt()
noun = []
sent = []
for i in range(1,54):
    data_path = 'E:\\news\\news\\뉴스\\뉴스__'+str(i)+'.txt'
    def get_texts(data_path):
        file = open(data_path, 'r',encoding='UTF-8')
        data =file.readlines()
        data_list = []
        for sentence in data:
            list_sentence1 = sentence.replace('\n','').split('\n')
            for list_sentence2 in list_sentence1:
                list_sentence = list_sentence2.replace('다.','다.  .').split('  .')
                for lines in list_sentence:
                    line = lines.strip()
                    data_list.append(line)
        texts = list(set(data_list))
        if '' in texts:
            texts.remove('')
        return texts
    texts = get_texts(data_path)
    penalty = lambda x:0 if (25 <= len(x) <= 100) else 1
    keywords, sents = summarize_with_sentences(
        texts,
        penalty=penalty,
        stopwords={},
        diversity=0.5,
        num_keywords=5,
        num_keysents=2,
        scaling=lambda x:1,
        verbose=False,
        min_count = 1)
    ex_a = ""
    for s in sents:
        ex_a += s
    sent.append(ex_a)
    ex_n = okt.nouns(ex_a)
    ex_n.sort()
    noun.append(ex_n)
# Out:
# C:\Users\jungs\Anaconda3\envs\py36\lib\site-packages\jpype\_core.py:210: UserWarning:
# -------------------------------------------------------------------------------
# Deprecated: convertStrings was not specified when starting the JVM. The default
# behavior in JPype will be False starting in JPype 0.8. The recommended setting
# for new code is convertStrings=False.  The legacy value of True was assumed for
# this session. If you are a user of an application that reported this warning,
# please file a ticket with the developer.
# -------------------------------------------------------------------------------
#
#   """)

# %%
sent_before = []
noun_before = []
for j in range(1,54):
    data_path1 = 'E:\\news\\news\\요약\\요약__'+str(j)+'.txt'
    def get_texts1(data_path):
        file = open(data_path, 'r',encoding='UTF-8')
        data =file.read()
        return data
    data = get_texts1(data_path1)
    ex_aa = ""
    ex_aa = data.replace("\n",'')
    sent_before.append(ex_aa)
    ex_bb = okt.nouns(ex_aa)
    ex_bb.sort()
    noun_before.append(ex_bb)

# %%
n=1
a=0
a1=0
for  i in range(0,53):
    print(sent[i])
    print(sent_before[i])
    s = difflib.SequenceMatcher(lambda x: x == " ", sent[i], sent_before[i])
    result = round(s.ratio(), 4)
    s1 = difflib.SequenceMatcher(lambda x: x == " ", noun[i], noun_before[i])
    result1 = round(s1.ratio(), 4)
    print("문장 정확도는 {:0.2f}%         number:".format(result*100)+str(n))
    print("형태소 정확도는 {:0.2f}%         number:".format(result1*100)+str(n))
    a = a+result
    b = (a*100)/n
    print("문장 최종 정확도는"+"%0.2f"%b+"%         number:"+str(n))
    a1 = a1+result1
    b1 = (a1*100)/n
    print("형태소 최종 정확도는"+"%0.2f"%b1+"%         number:"+str(n))
    n = n+1
# Out:
# 사람이 말하거나 구동 중인 동영상의 음성을 인공지능(AI)이 실시간으로 인식해 타이핑해주는 구글 드라이브의 음성입력 서비스가 큰 인기를 끌고 있습니다.30분짜리 강연도 한 번에…구글 드라이브 음성입력 이용 방법
# 사람이 말하거나 구동 중인 동영상의 음성을 인공지능이 실시간으로 인식해 타이핑해주는 구글 드라이브의 음성입력 서비스가 큰 인기를 끌고 있습니다.30분짜리 강연 영상을 틀어놓고 잠시 다른 일을 본 후 30분 후에 자리에 오면 이미 타이핑이 끝나 있는 문서를 확인할 수 있는 형태인데요.
# 문장 정확도는 66.18%         number:1
# 형태소 정확도는 63.16%         number:1
# 문장 최종 정확도는66.18%         number:1
# 형태소 최종 정확도는63.16%         number:1
# 국내 연구진이 포함된 국제 공동연구팀이 ‘호모사피엔스’(현생인류)가 아프리카 칼라하리 지역에 처음 나타났으며, 첫 번째 인류 대이동의 원인은 기후변화였다는 사실을 밝혀냈다.그 결과 최초 인류는 현재 나미비아와 짐바브웨 국경에 이르는 보츠나와 북부 지역인 칼라하라 지역에서 나타났으며, L0 혈통이 처음 출현한 시점은 지금까지 알려진 15만~17만 5000년 전이 아니라 20만년 전이라는 사실을 밝혀냈다.
# 국내 연구진이 포함된 국제 공동연구팀이 '호모사피엔스'가 아프리카 칼라하리 지역에 처음 나타났으며, 첫 번째 인류 대이동의 원인은 기후변화였다는 사실을 밝혀냈다.호주의 가반의학연구소와 뉴사우스웨일스대, 한국의 기초과학연구원 기후물리연구단, 남아프리카공화국 로즈대, 나미비아 빈트후크중앙병원 등 10개 기관 연구진으로 구성된 국제공동연구팀은 현생인류가 20만년 전 아프리카 칼라하리 지역에서 처음 나타났고 13만년 전 기후변화 때문에 인류 대이동이 있었다는 연구 결과를 세계적인 과학저널 '네이처' 10월 29일자에 발표했다.
# 문장 정확도는 41.62%         number:2
# 형태소 정확도는 50.00%         number:2
# 문장 최종 정확도는53.90%         number:2
# 형태소 최종 정확도는56.58%         number:2
# SK텔레콤은 3000억원 규모의 자기주식을 카카오에 매각하고, 카카오는 신주를 발행해 SK텔레콤에 배정하는 방식으로 지분을 맞교환한다.이와 함께 양사는 전략적 파트너십을 체결하고, 통신·커머스·디지털 콘텐츠·미래 ICT 등 4대 분야에서 양사 간 긴밀한 협력을 추진키로 했다.
# SK텔레콤은 카카오와 3000억원 규모의 지분을 교환하고 전략적 파트너십을 체결한다고 28일 밝혔다.SK텔레콤은 3000억원 규모의 자기주식을 카카오에 매각하고, 카카오는 신주를 발행해 SK텔레콤에 배정하는 방식으로 지분을 맞교환한다.
# 문장 정확도는 52.63%         number:3
# 형태소 정확도는 65.38%         number:3
# 문장 최종 정확도는53.48%         number:3
# 형태소 최종 정확도는59.51%         number:3
# 지난 주말새 비트코인 가격이 20% 이상 폭등하며 1000만원선을 회복한 가운데, 향후 암호화폐 시장 전망에 대한 업계의 의견이 갈리고 있다.블록체인 개발사 블록스트림의 아댐 백 대표 역시 "내년초 비트코인 가격은 5만달러(약 6000만원)을 쉽게 넘어설 수 있을 것"이라고 전망했다.
# 지난 주말새 비트코인 가격이 20% 이상 폭등하며 1000만원선을 회복한 가운데, 향후 암호화폐 시장 전망에 대한 업계의 의견이 갈리고 있다.중국 정부의 블록체인 육성정책 덕에 "내년 초 비트코인 가격이 5만달러까지 폭등할 것"이라는 시각과 "오히려 각국 정부의 코인시장 관리가 더 엄격해질 것"이라는 반대의견이 팽팽하게 맞선다.
# 문장 정확도는 63.56%         number:4
# 형태소 정확도는 63.16%         number:4
# 문장 최종 정확도는56.00%         number:4
# 형태소 최종 정확도는60.43%         number:4
# 카카오가 포털서비스 다음의 연예뉴스 댓글 서비스를 폐지하기로 해 포털업계 1위 네이버로 관심이 쏠리고 있다.네이버는 일단 자정 작용을 위한 방안을 고심 중이다.
# 카카오가 포털서비스 다음의 연예뉴스 댓글 서비스를 폐지하기로 해 포털업계 1위 네이버로 관심이 쏠리고 있다.네이버 역시 '악성 댓글'이나 '실시간 검색어 조작 논란'에서 자유롭지 않은 만큼 자정에 나서야 한다는 요구가 높아지는 형국이다.
# 문장 정확도는 63.35%         number:5
# 형태소 정확도는 66.67%         number:5
# 문장 최종 정확도는57.47%         number:5
# 형태소 최종 정확도는61.67%         number:5
# 유시민 노무현재단 이사장은 2일 조국 전 법무부 장관 가족에 대한 검찰 수사에 대해 "잔인무도하다"고 밝혔다.조국 일가족의 혐의점에 비해 무지무지하게 잔인하다"며 이같이 말했다.
# 유시민 노무현재단 이사장은 2일 조국 전 법무부 장관 가족에 대한 검찰 수사에 대해 "잔인무도하다"고 밝혔다.유 이사장은 이날 노무현재단 전북지역위원회가 창립 8주년을 기념해 전주교육대에서 연 시민학교 대담에서 "검찰이 조국 전 장관의 80대 노모를 소환 조사하고 딸을 기소하겠다고 으름장을 놓는다.조국 일가족의 혐의점에 비해 무지무지하게 잔인하다"며 이같이 말했다.
# 문장 정확도는 65.13%         number:6
# 형태소 정확도는 60.32%         number:6
# 문장 최종 정확도는58.75%         number:6
# 형태소 최종 정확도는61.45%         number:6
# 이는 작년 11월 출시된 아이폰XS·XS맥스·아이폰XR 첫날 개통량(10만대 수준)과 비교하면 30% 이상 많은 수치다.26일 이동통신업계에 따르면 전날 시작된 아이폰11 시리즈의 개통량은 13만∼14만대로 추산된다.
# 25일 출시된 아이폰11 시리즈의 첫날 개통량이 전작인 아이폰XS·XR 시리즈보다 30%가량 높게 나타났다.26일 이동통신업계에 따르면 전날 시작된 아이폰11 시리즈의 개통량은 13만∼14만대로 추산된다.
# 문장 정확도는 62.98%         number:7
# 형태소 정확도는 63.16%         number:7
# 문장 최종 정확도는59.35%         number:7
# 형태소 최종 정확도는61.69%         number:7
# 네이버는 제2 데이터센터 우선 협상 대상 부지로 세종특별자치시를 선정했다고 25일 밝혔다.지난 7일부터 18일까지 10개 후보 부지의 실사를 진행한 결과 세종을 우선 협상 부지로 결정하게 됐다.
# 네이버는 제2 데이터센터 우선 협상 대상 부지로 세종특별자치시를 선정했다고 25일 밝혔다.네이버는 당초 경기도 용인시 기흥구에 제2 데이터센터를 건립하려고 했지만 주민 반대로 지난 6월 철회했다.
# 문장 정확도는 50.69%         number:8
# 형태소 정확도는 51.06%         number:8
# 문장 최종 정확도는58.27%         number:8
# 형태소 최종 정확도는60.36%         number:8
# 25일 KT, SK텔링크, LG유플러스에 따르면 내달 30일까지 삼성전자의 신형폰을 구매하는 소비자를 위해 중고폰 특별보상 프로그램을 시행한다.자급제 모델 기준 아이폰11은 99만~120만원, 아이폰11 프로는 139만~187만원, 아이폰11 프로 맥스는 155만~203만원이다.
# 삼성전자가 애플의 신형 아이폰11 시리즈 출시에 대항하기 위해 이동통신3사와 갤럭시노트10, 갤럭시S10 등의 중고폰 특별보상 프로그램에 돌입한다.25일 KT, SK텔링크, LG유플러스에 따르면 내달 30일까지 삼성전자의 신형폰을 구매하는 소비자를 위해 중고폰 특별보상 프로그램을 시행한다.
# 문장 정확도는 50.31%         number:9
# 형태소 정확도는 54.84%         number:9
# 문장 최종 정확도는57.38%         number:9
# 형태소 최종 정확도는59.75%         number:9
# (지디넷코리아=권혜미 기자)LG전자가 4일(현지시간) 미국 캘리포니아지방법원에 ‘하이센스’를 상대로 TV 관련 특허침해금지소송을 제기했다."사용자 인터페이스 개선을 위한 기술 등 특허 4건 침해"
# LG전자가 4일 미국 캘리포니아지방법원에 '하이센스'를 상대로 TV 관련 특허침해금지소송을 제기했다.LG전자는 미국에서 판매 중인 대부분의 하이센스 TV 제품이 LG전자가 보유한 특허를 침해했다며 특허침해금지 및 손해배상청구소송을 냈다.
# 문장 정확도는 54.77%         number:10
# 형태소 정확도는 50.85%         number:10
# 문장 최종 정확도는57.12%         number:10
# 형태소 최종 정확도는58.86%         number:10
# 간편 송금 서비스 토스는 1일 ‘OOOOO은 수크랄페이트와 덱스판테놀의 복합체로 손상 받은 피부의 진정과 보호에 도움을 준다.OOOOO에 들어갈 닥터오킴스의 독자적 성분은?’이라는 행운퀴즈를 출제했다.
# '수크라테놀'과 관련한 토스 행운퀴즈가 등장했다.간편 송금 서비스 토스는 1일 'OOOOO은 수크랄페이트와 덱스판테놀의 복합체로 손상 받은 피부의 진정과 보호에 도움을 준다.OOOOO에 들어갈 닥터오킴스의 독자적 성분은?'이라는 행운퀴즈를 출제했다.
# 문장 정확도는 87.65%         number:11
# 형태소 정확도는 83.64%         number:11
# 문장 최종 정확도는59.90%         number:11
# 형태소 최종 정확도는61.11%         number:11
# 개천절에 찾아온 10월 태풍 '미탁'의 영향으로 지난달 전국에 내린 비의 양이 관측 이후 가장 많았던 것으로 나타났습니다.울진지역에는 10월 2일 하루에 332.9mm의 비가 내렸고 10월 3일에는 한 시간에 104.5mm의 매우 강한 비가 퍼부었습니다.
# 개천절에 찾아온 10월 태풍 '미탁'의 영향으로 지난달 전국에 내린 비의 양이 관측 이후 가장 많았던 것으로 나타났습니다.기상청은 지난달 1일부터 3일 사이에 '미탁'이 우리나라를 지나며 10월 전국 평균 강수량이 169㎜로 평년보다 3~5배 정도 많았다고 분석했습니다.
# 문장 정확도는 56.66%         number:12
# 형태소 정확도는 52.00%         number:12
# 문장 최종 정확도는59.63%         number:12
# 형태소 최종 정확도는60.35%         number:12
# LG전자가 지난 1일 북미 시장에 출시한 'LG G8X 씽큐(국내명 LG V50S)와 'LG 듀얼 스크린'에 대한 외신의 호평이 이어지고 있다.G8X는 전면에 3200만 고화소 카메라를 달았다.
# LG전자가 지난 1일 북미 시장에 출시한 'LG G8X 씽큐와 'LG 듀얼 스크린'에 대한 외신의 호평이 이어지고 있다.포브스는 "G8의 뛰어난 멀티태스킹 능력은 미니 노트북처럼 사용할 수 있을 정도로 뛰어나다"며 "실용적이고 합리적인 가격에 내구성까지 갖춘 제품"이라고 극찬했다.
# 문장 정확도는 55.85%         number:13
# 형태소 정확도는 52.38%         number:13
# 문장 최종 정확도는59.34%         number:13
# 형태소 최종 정확도는59.74%         number:13
# 미국과 중국의 패권 경쟁이 거센 가운데 시진핑(習近平) 중국 국가주석이 RCEP(역내포괄적경제동반자협정) 타결과 국제수입박람회를 통해 '스트롱맨'으로 우뚝 섰다.더구나 시진핑 주석은 5일 개막한 제2회 국제수입박람회를 통해 제2 경제 대국이자 13억 인구의 막강한 구매력을 전 세계에 과시하고 나섰다.
# 미국과 중국의 패권 경쟁이 거센 가운데 시진핑 중국 국가주석이 RCEP 타결과 국제수입박람회를 통해 '스트롱맨'으로 우뚝 섰다.도널드 트럼프 미국 대통령과 함께 글로벌 지도자를 다투는 시진핑 주석은 중국 주도의 세계 최대 규모의 '메가 FTA'와 국제수입박람회에서 세계 최대 구매력을 과시함으로써 미국 경제 패권에 가장 위협적인 인물로 급부상했기 때문이다.
# 문장 정확도는 53.95%         number:14
# 형태소 정확도는 59.09%         number:14
# 문장 최종 정확도는58.95%         number:14
# 형태소 최종 정확도는59.69%         number:14
# 중국에서 '가장 폭발력 있는 작가', '가장 문제적인 작가' 등으로 불리는 옌롄커(염련과·閻連科)가 한국을 방문해 강연을 펼친다.교보문고와 대산문화재단은 5일 "한국 독자와 세계 작가의 접점을 확장하기 위해 '세계 작가와의 대화'를 시작한다"며 "첫 작가로 옌롄커를 초청한다"고 밝혔다.
# 중국에서 '가장 폭발력 있는 작가', '가장 문제적인 작가' 등으로 불리는 옌롄커가 한국을 방문해 강연을 펼친다.교보문고와 대산문화재단은 5일 "한국 독자와 세계 작가의 접점을 확장하기 위해 '세계 작가와의 대화'를 시작한다"며 "첫 작가로 옌롄커를 초청한다"고 밝혔다.
# 문장 정확도는 97.11%         number:15
# 형태소 정확도는 98.55%         number:15
# 문장 최종 정확도는61.50%         number:15
# 형태소 최종 정확도는62.28%         number:15
# 토픽스(TOPIX) 지수도 전 거래일 종가 대비 20.98포인트 상승해 1,687.48로 올랐다.전날 미국 뉴욕증시의 3대지수가 역대 최고치를 기록하며 호조를 보인 영향으로 5일 일본 도쿄증시의 니케이지수도 올해 최고치를 경신했다.
# 전날 미국 뉴욕증시의 3대지수가 역대 최고치를 기록하며 호조를 보인 영향으로 5일 일본 도쿄증시의 니케이지수도 올해 최고치를 경신했다.이날 일본 도쿄 증시는 미국 주식 시장 호조의 영향으로 사자 주문이 이어져 오전 9시15분 기준 니케이지수가 전 거래일 종가보다 347.81포인트 상승한 23,198.58로 올해 최고가를 기록했다.
# 문장 정확도는 47.77%         number:16
# 형태소 정확도는 69.70%         number:16
# 문장 최종 정확도는60.64%         number:16
# 형태소 최종 정확도는62.75%         number:16
# 개인 간 대출 거래를 제도권으로 끌어들이는 일명 'P2P법'이 국회 본회의를 통과되면서 관련 스타트업 대표가 박용만 대한상공회의소 회장에게 감사인사를 전했다.김 대표는 "업계 전체에 영웅이 되어주신 박용만 회장님 제가 꼭 한번 업어드릴게요"라며 감사를 표했다.
# 개인 간 대출 거래를 제도권으로 끌어들이는 일명 'P2P법'이 국회 본회의를 통과되면서 관련 스타트업 대표가 박용만 대한상공회의소 회장에게 감사인사를 전했다.2일 대한상의에 따르면 김성준 렌딧 대표는 지난달 31일 박용만 대한상의 회장의 페이스북 담벼락에 "드디어 큰 사건이 하나 터졌다.많은 분들께서 도와주신 덕분"이라며 "열심히 해서 꼭 좋은 모습 보여드리겠다"는 글을 남겼다.
# 문장 정확도는 59.78%         number:17
# 형태소 정확도는 70.42%         number:17
# 문장 최종 정확도는60.59%         number:17
# 형태소 최종 정확도는63.20%         number:17
# 코트라는 6일부터 이틀간 필리핀 마닐라에서 '한·아세안 프로젝트 플라자'를 개최한다고 5일 밝혔다.플랜트산업협회와 공동 주최한 이번 행사는 인프라 협력 포럼, 수출 상담회, 네트워킹 등으로 구성됐으며, 건설·수처리·에너지 분야의 해외 발주처 및 바이어 업체 100개사와 국내 기업 40개사가 참가한다.
# 코트라는 6일부터 이틀간 필리핀 마닐라에서 '한·아세안 프로젝트 플라자'를 개최한다고 5일 밝혔다.플랜트산업협회와 공동 주최한 이번 행사는 인프라 협력 포럼, 수출 상담회, 네트워킹 등으로 구성됐으며, 건설·수처리·에너지 분야의 해외 발주처 및 바이어 업체 100개사와 국내 기업 40개사가 참가한다.
# 문장 정확도는 100.00%         number:18
# 형태소 정확도는 100.00%         number:18
# 문장 최종 정확도는62.78%         number:18
# 형태소 최종 정확도는65.24%         number:18
# 이언주 국회의원(무소속, 경기 광명을)은 2일 "북핵을 폐기하고 우리한테 필요한 도움이라면 과거사고 나발이고 무조건 (미국·일본에) 손잡고 도움을 청해야 한다"고 주장했다.연설대에 오른 황영호 위원장은 문재인 대통령을 향해 "조국이라는 희대의 사기꾼·악마같은 놈을 법무부장관으로 임명했다"면서 "미친X 아니냐"고 강한 어조로 비판하기도 했다.
# 이언주 국회의원은 2일 "북핵을 폐기하고 우리한테 필요한 도움이라면 과거사고 나발이고 무조건 손잡고 도움을 청해야 한다"고 주장했다.이 의원은 이날 충북 청주시 상당공원 인근에서 열린 '문재인 정권 규탄 집회'에 참석해 현 정부의 외교정책을 비판하며 이 같이 말했다.
# 문장 정확도는 51.18%         number:19
# 형태소 정확도는 45.33%         number:19
# 문장 최종 정확도는62.17%         number:19
# 형태소 최종 정확도는64.20%         number:19
# 어쨌든 중국 최고 지도부를 잇따라 만나는 람 장관은 향후 홍콩 시위 진압에 더욱 강경한 입장을 보일 것으로 예상된다.중국 관영 매체인 글로벌타임스도 한정 부총리와 람 장관의 회동에 대해 “람 장관에 대한 중앙정부의 강력한 지지를 보여주는 것”이라고 보도했다.
# 홍콩의 민주화 요구 시위가 장기화되는 가운데 시진핑 중국 국가주석이 캐리 람 홍콩 행정장관과 전격적으로 만났다.이는 시 주석이 캐리람 장관에 대해 재신임을 천명하고 힘을 실어주는 것으로 향후 홍콩 정부가 시위를 더욱 강경하게 진압할 것이란 관측이 나온다.
# 문장 정확도는 15.38%         number:20
# 형태소 정확도는 35.82%         number:20
# 문장 최종 정확도는59.83%         number:20
# 형태소 최종 정확도는62.78%         number:20
# 미국 '위성 위치 확인 시스템(GPS)'에 대응해 '베이더우(北斗)' 시스템을 개발 중인 중국이 이를 위한 인공위성 발사에 또다시 성공했다.이번에 발사된 위성과 로켓은 중국항천과기집단 산하 중국공간기술연구원과 중국운반로켓기술연구원에서 각각 제작했다.
# 미국 '위성 위치 확인 시스템'에 대응해 '베이더우' 시스템을 개발 중인 중국이 이를 위한 인공위성 발사에 또다시 성공했다.중국은 5일 오전 1시 43분 쓰촨성 시창위성발사센터에서 창정-3호 이 운반 로켓으로 베이더우 3호 시스템 위성 1기를 추가로 궤도에 올리는 데 성공했다고 신화통신이 전했다.
# 문장 정확도는 51.80%         number:21
# 형태소 정확도는 57.58%         number:21
# 문장 최종 정확도는59.45%         number:21
# 형태소 최종 정확도는62.53%         number:21
# 최근 사망한 이슬람국가(IS)의 수괴 아부 바크르 알바그다디의 친누나가 터키 당국에 생포된 것으로 전해졌다.그의 사망 때문에 미군이 이끄는 연합군 등과의 교전에서 이미 수차례 패배해 시리아와 이라크 내 점령지를 잃은 IS는 큰 타격을 받았다.
# 최근 사망한 이슬람국가의 수괴 아부 바크르 알바그다디의 친누나가 터키 당국에 생포된 것으로 전해졌다.AP, 로이터 통신 등에 따르면 터키의 한 고위 당국자는 4일 저녁 시리아 북서부의 알레포 주 앗자즈에서 알바그다디의 친누나인 라스미야 아와드를 붙잡았다고 밝혔다.
# 문장 정확도는 49.65%         number:22
# 형태소 정확도는 56.25%         number:22
# 문장 최종 정확도는59.00%         number:22
# 형태소 최종 정확도는62.24%         number:22
# 핼러윈 파티장에서 총격 사건이 발생해 4명이 숨지는 등 미국의 대표적 축제일인 '핼러윈 데이'가 핏빛으로 물들었다.핼로윈 놀이하던 7세 소녀는 근처 총격전 유탄에 중태
# 핼러윈 파티장에서 총격 사건이 발생해 4명이 숨지는 등 미국의 대표적 축제일인 '핼러윈 데이'가 핏빛으로 물들었다.캘리포니아주 샌프란시스코 베이 지역 인근 부촌의 한 주택에서 지난달 31일 밤 10시 45분쯤 총격 사건이 발생했다.
# 문장 정확도는 62.16%         number:23
# 형태소 정확도는 58.33%         number:23
# 문장 최종 정확도는59.14%         number:23
# 형태소 최종 정확도는62.07%         number:23
# 1960년 칠레 남부에선 관측 사상 가장 강력했던 규모 9.5의 강진이 발생해 1천700명 이상이 사망했고, 2010년에도 규모 8.8의 강진과 쓰나미로 525명이 숨졌다.미국 지질조사국(USGS)에 따르면 진앙은 이야펠에서 북서쪽으로 28㎞ 떨어진 지점이며, 진원의 깊이는 49㎞다.
# 4일 오후 6시53분께 칠레 중부 이야펠 인근에서 규모 6.0의 강진이 발생했다.이번 지진은 수도 산티아고에서 대규모 반정부 시위가 진행되던 와중에 일어났지만, 인명 피해는 없는 것으로 알려졌다.
# 문장 정확도는 23.88%         number:24
# 형태소 정확도는 25.53%         number:24
# 문장 최종 정확도는57.67%         number:24
# 형태소 최종 정확도는60.55%         number:24
# 현대차는 5일, 전국 영업점에서 전날부터 사전계약에 들어갔던 더 뉴 그랜저의 첫날 계약 대수가 1만 7,294대로 나타났다고 밝혔다.더 뉴 그랜저는 6세대 그랜저의 부분변경(페이스리프트) 모델임에도 신차급 변화를 줬다는 평가를 받는다.
# 현대자동차의 '더 뉴 그랜저'가 사전계약 첫날에만 1만 7,294대의 계약 기록을 세우며 역대 최다 신기록을 세웠다.현대차는 5일, 전국 영업점에서 전날부터 사전계약에 들어갔던 더 뉴 그랜저의 첫날 계약 대수가 1만 7,294대로 나타났다고 밝혔다.
# 문장 정확도는 54.81%         number:25
# 형태소 정확도는 60.38%         number:25
# 문장 최종 정확도는57.55%         number:25
# 형태소 최종 정확도는60.54%         number:25
# 영상 전문 스타트업 전문가들이 제작한 웹드라마, 웹예능, 콩트 등을 비롯해 아마추어가 제작한 영상, 일반 소비자들의 솔직한 제품 리뷰도 선보인다.의류 및 패션 분야에서 '미디어 커머스' 온라인 채널 확보경쟁이 치열하다.
# 의류 및 패션 분야에서 '미디어 커머스' 온라인 채널 확보경쟁이 치열하다.온라인 쇼핑 규모는 최초로 110조원을 넘으며 2017년 온라인 쇼핑 규모 대비 약 22.6% 늘어났다.
# 문장 정확도는 37.10%         number:26
# 형태소 정확도는 41.67%         number:26
# 문장 최종 정확도는56.77%         number:26
# 형태소 최종 정확도는59.82%         number:26
# 이날 연예매체 디스패치는 원호가 2013년 10월 서울 강남의 한 지인 집에서 함께 대마를 흡연했으며, 경찰이 이와 관련한 내사를 진행 중이라며 보도했다.대마 흡연 의혹이 불거진 보이 그룹 '몬스타엑스' 전 멤버 원호(본명 이호석·26)에 대해 경찰이 사실관계를 들여다보고 있다.
# 대마 흡연 의혹이 불거진 보이 그룹 '몬스타엑스' 전 멤버 원호에 대해 경찰이 사실관계를 들여다보고 있다.1일 경찰에 따르면 서울지방경찰청 광역수사대는 원호의 대마 흡연 의혹과 관련해 내사 중이다.
# 문장 정확도는 44.36%         number:27
# 형태소 정확도는 70.00%         number:27
# 문장 최종 정확도는56.31%         number:27
# 형태소 최종 정확도는60.20%         number:27
# 위화, 모옌과 더불어 중국의 3대 거장으로 평가받는 문제적 작가 옌롄커가 한국독자들과 만남을 갖는다.옌롄커는 1978년 인민해방군으로 입대해 28년간 직업군인으로 복무한 이력을 갖고 있다.
# 위화, 모옌과 더불어 중국의 3대 거장으로 평가받는 문제적 작가 옌롄커가 한국독자들과 만남을 갖는다.교보문고와 대산문화재단은 '세계작가와의 대화' 프로그램을 신설, 첫 작가로 현재 중국에서 가장 폭발력 있는 작가이자 노벨문학상 후보로 오르내리는 옌롄커를 초청, 독자들과의 만남을 진행한다.
# 문장 정확도는 46.62%         number:28
# 형태소 정확도는 45.28%         number:28
# 문장 최종 정확도는55.96%         number:28
# 형태소 최종 정확도는59.66%         number:28
# 미국 IT 매체 더 버지(The Verge)는 “LG G8X 씽큐와 듀얼 스크린의 멀티태스킹 성능은 지금까지 사용해 본 모바일 제품 중 최고”라고 호평했다.LG G8X 씽큐는 안정성이 뛰어난 LG V50 씽큐 플랫폼을 바탕으로 했다.
# LG G8X 씽큐가 북미 시장 출시 초반부터 듀얼 스크린의 멀티태스킹 경험과 합리적인 가격이 호평을 받았다.LG전자는 지난 1일 북미 시장에 출시한 LG G8X 씽큐와 듀얼 스크린에 대한 외신 호평이 이어지고 있다고 밝혔다.
# 문장 정확도는 33.73%         number:29
# 형태소 정확도는 27.27%         number:29
# 문장 최종 정확도는55.20%         number:29
# 형태소 최종 정확도는58.55%         number:29
# LG전자는 "글로벌 생산지 효율화와 원가개선의 영향으로 영업손실은 전분기 대비 큰폭으로 개선됐다"고 설명했다.LG전자는 30일 3분기 실적발표를 통해 매출액 15조7007억원, 영업이익 7814억원을 기록했다고 밝혔다.
# LG전자 스마트폰 사업이 18분기 연속 적자를 기록했으나 베트남 공장 이전을 통한 생산지 효율화와 원가개선으로 영업손실의 폭을 줄였다.LG전자는 30일 3분기 실적발표를 통해 매출액 15조7007억원, 영업이익 7814억원을 기록했다고 밝혔다.
# 문장 정확도는 68.99%         number:30
# 형태소 정확도는 68.00%         number:30
# 문장 최종 정확도는55.66%         number:30
# 형태소 최종 정확도는58.86%         number:30
# 서적 유통업체 예스24(대표 김석환)는 자체 블록체인 플랫폼 'sey체인' 메인넷을 론칭했다고 5일 밝혔다.독자들은 디지털 콘텐츠 플랫폼 '시프트북스'에서 마음에 드는 작품을 응원하는 활동을 통해 sey코인을 받고 작가들 또한 독자 응원 순위에 따른 보상으로 sey코인을 받는다.
# 서적 유통업체 예스24는 자체 블록체인 플랫폼 'sey체인' 메인넷을 론칭했다고 5일 밝혔다.sey체인은 지난 2018년 8월 이더리움 ERC-20 기반으로 가상화폐 sey토큰을 론칭한 예스24가 독자적인 블록체인 생태계 구축을 목표로 개발했으며 파트너사들과 함께 운영할 수 있는 컨소시엄형 메인넷을 지향한다.
# 문장 정확도는 41.34%         number:31
# 형태소 정확도는 33.85%         number:31
# 문장 최종 정확도는55.19%         number:31
# 형태소 최종 정확도는58.05%         number:31
# 중국에서 '가장 폭발력 있는 작가', '가장 문제적인 작가' 등으로 불리는 옌롄커(염련과·閻連科)가 한국을 방문해 강연을 펼친다.교보문고와 대산문화재단은 5일 "한국 독자와 세계 작가의 접점을 확장하기 위해 '세계 작가와의 대화'를 시작한다"며 "첫 작가로 옌롄커를 초청한다"고 밝혔다.
# 중국에서 '가장 폭발력 있는 작가', '가장 문제적인 작가' 등으로 불리는 옌롄커가 한국을 방문해 강연을 펼친다.교보문고와 대산문화재단은 5일 "한국 독자와 세계 작가의 접점을 확장하기 위해 '세계 작가와의 대화'를 시작한다"며 "첫 작가로 옌롄커를 초청한다"고 밝혔다.
# 문장 정확도는 97.11%         number:32
# 형태소 정확도는 98.55%         number:32
# 문장 최종 정확도는56.50%         number:32
# 형태소 최종 정확도는59.32%         number:32
# 문화재청 궁능유적본부 덕수궁관리소는 오는 8일 낮 12시15분부터 오후 1시까지 서울 덕수궁 돌담길에서 '덕수궁 돌담길 음악회'를 개최한다고 5일 밝혔다.덕수궁을 찾은 관람객 누구나 무료로 감상할 수 있으며 자세한 사항은 덕수궁관리소 누리집에서 확인할 수 있다.
# 문화재청 궁능유적본부 덕수궁관리소는 오는 8일 낮 12시15분부터 오후 1시까지 서울 덕수궁 돌담길에서 '덕수궁 돌담길 음악회'를 개최한다고 5일 밝혔다.문화재청은 지난해 12월 막혀 있던 덕수궁 돌담길 70m 구간의 궁 안쪽에 보행로를 만들어 연결했다.
# 문장 정확도는 64.58%         number:33
# 형태소 정확도는 65.57%         number:33
# 문장 최종 정확도는56.75%         number:33
# 형태소 최종 정확도는59.51%         number:33
# 대한민국 임시정부 수립 100주년을 기념해 제작된 뮤지컬 '도산 안창호'가 오는 16~17일 양일 간 나루아트센터 대극장에서 공연된다.흥사단은 우리가 잘 알지 못했던 도산의 정신과 업적, 나라의 중요성과 독립운동가의 헌신을 뮤지컬을 통해 알리고자 이 작품을 제작했다.
# 대한민국 임시정부 수립 100주년을 기념해 제작된 뮤지컬 '도산 안창호'가 오는 16~17일 양일 간 나루아트센터 대극장에서 공연된다.흥사단은 우리가 잘 알지 못했던 도산의 정신과 업적, 나라의 중요성과 독립운동가의 헌신을 뮤지컬을 통해 알리고자 이 작품을 제작했다.
# 문장 정확도는 100.00%         number:34
# 형태소 정확도는 100.00%         number:34
# 문장 최종 정확도는58.02%         number:34
# 형태소 최종 정확도는60.70%         number:34
# 지난해 무대에 처음 오른 이 무용은 2019 한국문화예술위원회 공연예술 창작산실 올해의 레퍼토리에 선정된 작품이다.환각제 등이 우리 신체를 자극하게 됐을 때 몸은 과연 어떻게 변하게 될까.
# 환각제 등이 우리 신체를 자극하게 됐을 때 몸은 과연 어떻게 변하게 될까.오는 8~9일 이틀간 서울 대학로예술극장 대극장에서 공연되는 'OPIUM'은 환각제로 사용되는 양귀비에서 착안, 감각이 극대화했을 때 나타나는 신체 변형과 변신을 탐구한 현대무용이다.
# 문장 정확도는 33.06%         number:35
# 형태소 정확도는 37.74%         number:35
# 문장 최종 정확도는57.31%         number:35
# 형태소 최종 정확도는60.04%         number:35
# 김현미 국토교통부 장관은 31일 오전 국회에서 열린 ‘대도시권 광역교통 비전 2030’ 발표를 위한 당정 협의에서 이같이 말했다.“광역급행철도(GTX) 수혜범위를 확대하기 위해 수도권 서부권 등에 신규 급행노선을 추가로 검토해 내년 하반기까지 확정·발표하겠습니다.
# "광역급행철도 수혜범위를 확대하기 위해 수도권 서부권 등에 신규 급행노선을 추가로 검토해 내년 하반기까지 확정·발표하겠습니다.수도권 서부권을 관통하는 광역급행철도 신규 노선을 내년 하반기 확정·발표한다.
# 문장 정확도는 53.08%         number:36
# 형태소 정확도는 63.33%         number:36
# 문장 최종 정확도는57.19%         number:36
# 형태소 최종 정확도는60.13%         number:36
# ‘8-플라워 골든 넥타 오일’은 전 세계를 걸쳐 혼합된 8가지 꽃(진귀한 임모르텔, 일랑 일랑, 패츌리, 네롤리, 로즈, 라벤더, 쟈스민, 아이리스)들의 추출물이 함유되어 있다.프랑스 스파 브랜드 달팡(DARPHIN)이 신제품 ‘8-플라워 골든 넥타 오일’을 출시했다고 밝혔다.
# 프랑스 스파 브랜드 달팡이 신제품 '8-플라워 골든 넥타 오일'을 출시했다고 밝혔다.'8-플라워 골든 넥타 오일'은 전 세계를 걸쳐 혼합된 8가지 꽃들의 추출물이 함유되어 있다.
# 문장 정확도는 26.77%         number:37
# 형태소 정확도는 81.48%         number:37
# 문장 최종 정확도는56.37%         number:37
# 형태소 최종 정확도는60.71%         number:37
# 콘텐츠웨이브는 '프리미어12' 공식 스폰서로 참여해 생중계 권한을 확보, 1일부터 대한민국 국가대표팀 전 경기를 고화질(풀HD)로 무료 생중계한다.웨이브, '2019 프리미어12' 온라인 독점 무료 생중계
# 온라인동영상서비스 웨이브가 2020 도쿄올림픽 야구 본선 진출권이 달린 '2019 WBSC 프리미어 12' 경기를 온라인 독점 생중계한다.콘텐츠웨이브는 '프리미어12' 공식 스폰서로 참여해 생중계 권한을 확보, 1일부터 대한민국 국가대표팀 전 경기를 고화질로 무료 생중계한다.
# 문장 정확도는 57.46%         number:38
# 형태소 정확도는 79.25%         number:38
# 문장 최종 정확도는56.40%         number:38
# 형태소 최종 정확도는61.20%         number:38
# 갤럭시 폴드의 흥행 이후 위아래로 여닫는 ‘클램셸’ 형태 폴더블폰까지 공개한 삼성전자가 폴더블폰 시장 주도권을 이어갈 수 있을지 주목된다.고 사장은 중가형 스마트폰 갤럭시 A 시리즈에 대해선 “(수익성이) 목표한 것까지는 아직 안됐다”라며 “더 혁신이 필요하다”고 강조했다.
# 삼성전자가 2020년엔 폴더블폰 생산량을 늘리겠다고 밝혔다.갤럭시 폴드의 흥행 이후 위아래로 여닫는 '클램셸' 형태 폴더블폰까지 공개한 삼성전자가 폴더블폰 시장 주도권을 이어갈 수 있을지 주목된다.
# 문장 정확도는 57.03%         number:39
# 형태소 정확도는 64.52%         number:39
# 문장 최종 정확도는56.41%         number:39
# 형태소 최종 정확도는61.28%         number:39
# 캐시슬라이드가 '안다르 피치레깅스 대란' 초성퀴즈를 출제했다.한편, 해당 퀴즈는 캐시슬라이드 앱에서 참여할 수 있으며 문제가 바뀔 경우 정답 또한 달라진다.
# 캐시슬라이드가 '안다르 피치레깅스 대란' 초성퀴즈를 출제했다.캐시슬라이드는 5일 안다르와 함께 "올 겨울 필수템, 피치레깅스 오늘만 ㅇㅁㅇㅊㅇ"란 초성퀴즈를 냈다.
# 문장 정확도는 48.31%         number:40
# 형태소 정확도는 50.00%         number:40
# 문장 최종 정확도는56.21%         number:40
# 형태소 최종 정확도는61.00%         number:40
# FCMM이 1일부터 오는 3일까지 'FCMM 데이' 이벤트를 진행한다.'FCMM데이'는 일년에 딱 한 번 진행되는 파격 할인 행사로 구스패딩부터, 인기품목인 플리스 자켓, 4계절 필수템인 후드, 팬츠까지 신상을 포함한 전상품을 최대 90% 할인된 가격에 판매한다.
# FCMM이 1일부터 오는 3일까지 'FCMM 데이' 이벤트를 진행한다.'FCMM데이'는 일년에 딱 한 번 진행되는 파격 할인 행사로 구스패딩부터, 인기품목인 플리스 자켓, 4계절 필수템인 후드, 팬츠까지 신상을 포함한 전상품을 최대 90% 할인된 가격에 판매한다.
# 문장 정확도는 100.00%         number:41
# 형태소 정확도는 100.00%         number:41
# 문장 최종 정확도는57.28%         number:41
# 형태소 최종 정확도는61.95%         number:41
# 5일 토스 행운 퀴즈로 '하나멤버스100만원' 관련 퀴즈가 출제되어 화제를 모으고 있다.출제자 측은 포털 사이트에 '시몬스 난연 매트리스'를 검색하면 힌트를 찾을 수 있다고 전했다.
# 토스 행운 퀴즈로 '하나멤버스100만원' 관련 문제가 출제됐다.5일 토스 행운 퀴즈로 '하나멤버스100만원' 관련 퀴즈가 출제되어 화제를 모으고 있다.
# 문장 정확도는 49.73%         number:42
# 형태소 정확도는 51.28%         number:42
# 문장 최종 정확도는57.10%         number:42
# 형태소 최종 정확도는61.70%         number:42
# 티웨이항공은 4일부터 전용 간편 결제 서비스인 '티웨이 페이'를 실시한다고 밝혔다.또한 티웨이항공은 오는 24일까지 티웨이 페이 런칭 기념 이벤트를 진행한다.
# 티웨이항공은 4일부터 전용 간편 결제 서비스인 '티웨이 페이'를 실시한다고 밝혔다.티웨이 페이는 전용 간편 결제 시스템으로 자주 쓰는 결제 카드를 사전에 등록해두면 결제 시마다 추가로 정보를 입력할 필요 없이 편리하게 사용할 수 있다.
# 문장 정확도는 50.23%         number:43
# 형태소 정확도는 48.89%         number:43
# 문장 최종 정확도는56.94%         number:43
# 형태소 최종 정확도는61.40%         number:43
# 오리온은 기존 판형 웨하스의 가격을 인하해 가성비를 높인 ‘오리온 웨하스’를 출시한다고 5일 밝혔다.더불어 작은 크기로 취식 편의성이 높은 ‘오리온 미니 웨하스’와 네겹 제품인 ‘오리온 웨하스-미니’등 웨하스 라인업을 강화했다.
# 오리온은 기존 판형 웨하스의 가격을 인하해 가성비를 높인 '오리온 웨하스'를 출시한다고 5일 밝혔다.오리온 웨하스는 가성비 트렌드에 발맞춰 소비자들이 부담 없이 구매할 수 있도록 60g 규격을 편의점가 기준 900원에 선보인다.
# 문장 정확도는 50.39%         number:44
# 형태소 정확도는 54.90%         number:44
# 문장 최종 정확도는56.79%         number:44
# 형태소 최종 정확도는61.25%         number:44
# 몽벨의 보이기 위한 화려함 보다는 품질 우선의 제품을 만드는 브랜드 정신에 커버낫의 유니크한 제품을 녹여 아웃도어와 캐주얼의 벽을 넘나드는 새로운 제품을 만들어냈다.국내 스트릿 브랜드 커버낫과 44년 전통 아웃도어 브랜드 몽벨이 콜라보레이션을 선보였다.
# 국내 스트릿 브랜드 커버낫과 44년 전통 아웃도어 브랜드 몽벨이 콜라보레이션을 선보였다.몽벨의 보이기 위한 화려함 보다는 품질 우선의 제품을 만드는 브랜드 정신에 커버낫의 유니크한 제품을 녹여 아웃도어와 캐주얼의 벽을 넘나드는 새로운 제품을 만들어냈다.
# 문장 정확도는 24.82%         number:45
# 형태소 정확도는 100.00%         number:45
# 문장 최종 정확도는56.08%         number:45
# 형태소 최종 정확도는62.12%         number:45
# 임 전무는 이정재와의 데이트 장면이 포착될 때마다 패션 아이템이 덩달아 화제가 됐다.지난 1일 한 매체는 이정재와 임 전무 커플이 인천국제공항을 통해 출국하는 모습을 전했다.
# 임세령 대상 전무가 연인 사이인 배우 이정재와 동반 출국하는 현장이 포착되면서, 그의 패션에 또다시 관심이 쏠리고 있다.지난 1일 한 매체는 이정재와 임 전무 커플이 인천국제공항을 통해 출국하는 모습을 전했다.
# 문장 정확도는 64.49%         number:46
# 형태소 정확도는 65.31%         number:46
# 문장 최종 정확도는56.26%         number:46
# 형태소 최종 정확도는62.18%         number:46
# 게임 축제 블리즈컨2019에서 신작 디아블로4와 오버워치2, 월드오브워크래프트 새 확장팩 등이 깜짝 공개됐다.신작 및 기존 서비스작 업데이트 버전 체험 가능
# 게임 축제 블리즈컨2019에서 신작 디아블로4와 오버워치2, 월드오브워크래프트 새 확장팩 등이 깜짝 공개됐다.블리자드엔터테인먼트는 1일 오전 10시 미국 캘리포니아 애너하임 컨벤션 센터에서 블리즈컨2019 개막을 알렸다.
# 문장 정확도는 59.05%         number:47
# 형태소 정확도는 61.22%         number:47
# 문장 최종 정확도는56.32%         number:47
# 형태소 최종 정확도는62.16%         number:47
# 한국계 미국인 제임스 박이 공동창업한 핏빗은 하루 걸음 수나 달린 거리, 소모된 칼로리양, 심장 박동수, 수면 시간과 수면의 질 등을 계측하는 스마트워치 등을 생산한다.핏빗은 1일(현지시간) 보도자료를 통해 "구글이 현금으로 주당 7.35달러에 핏빗을 인수하는 방안에 합의했다"고 밝혔다.
# 웨어러블 시장의 최강자로 자리매김한 '핏빗'이 세계 최대 검색엔진 업체 구글의 모회사 '알파벳'에 인수된다고 미 언론들이 1일 보도했다.한국계 미국인 제임스 박이 공동창업한 핏빗은 하루 걸음 수나 달린 거리, 소모된 칼로리양, 심장 박동수, 수면 시간과 수면의 질 등을 계측하는 스마트워치 등을 생산한다.
# 문장 정확도는 56.80%         number:48
# 형태소 정확도는 67.53%         number:48
# 문장 최종 정확도는56.33%         number:48
# 형태소 최종 정확도는62.28%         number:48
# 지난달 영국에서 냉동 컨테이너안에 숨진 채 발견된 39명이 모두 베트남 출신으로 추정된다는 현지 경찰의 발표에 베트남이 큰 충격에 빠졌습니다.레 티 투 항 베트남 외교부 대변인도 오늘 새벽 긴급 성명을 내고 "심각한 비극"이라며 "희생자 가족에게 위로의 말을 전한다"고 밝혔습니다.
# 지난달 영국에서 냉동 컨테이너안에 숨진 채 발견된 39명이 모두 베트남 출신으로 추정된다는 현지 경찰의 발표에 베트남이 큰 충격에 빠졌습니다.쩐 응옥 안 영국 주재 베트남 대사는 "영국경찰의 공식 통보를 받고 충격을 받았으며 매우 슬프다"고 말했습니다.
# 문장 정확도는 65.10%         number:49
# 형태소 정확도는 58.82%         number:49
# 문장 최종 정확도는56.51%         number:49
# 형태소 최종 정확도는62.21%         number:49
# '온디맨드(O2O)' 업체가 늘어나며 단기고용직인 '긱 이코노미(단기근로)' 종사자가 급증하고 있지만 정규직이 아닌 탓에 관련업계가 관리문제로 몸살을 앓고 있다.채팅방 성희롱 논란에 이어 기사 욕설 논란까지 휩싸인 타다의 경우, 직접 고용이 아닌 알선업체를 통해 기사를 간접 고용하고 있어 직접 교육이 불가능하다고 주장한다.
# '온디맨드' 업체가 늘어나며 단기고용직인 '긱 이코노미' 종사자가 급증하고 있지만 정규직이 아닌 탓에 관련업계가 관리문제로 몸살을 앓고 있다.검증되지 않은 이들이 긱 이코노미 시장에 유입되면서 성희롱과 욕설·바가지 금액 책정 등 피해사례가 늘어나 업체마다 이미지 타격이 적지 않지만 인건비 부담으로 직접 고용이 어렵고 간접고용인 탓에 종사자 교육도 쉽지 않은 상황이다.
# 문장 정확도는 53.23%         number:50
# 형태소 정확도는 59.52%         number:50
# 문장 최종 정확도는56.44%         number:50
# 형태소 최종 정확도는62.15%         number:50
# 검찰이 승합차와 운전자 모두를 빌려주는 모빌리티 플랫폼 ‘타다’ 운행이 불법이라고 판단하고 임원들을 불구속 기소하자, 벤처인들이 강력하게 반발하고 있다.검찰은 어제(28일) 여객자동차운수사업법 위반 혐의로 박재욱 VCNC 대표와 이재웅 쏘카 대표를 각각 불구속 기소했다.
# 검찰이 승합차와 운전자 모두를 빌려주는 모빌리티 플랫폼 '타다' 운행이 불법이라고 판단하고 임원들을 불구속 기소하자, 벤처인들이 강력하게 반발하고 있다.검찰은 어제 여객자동차운수사업법 위반 혐의로 박재욱 VCNC 대표와 이재웅 쏘카 대표를 각각 불구속 기소했다.
# 문장 정확도는 96.97%         number:51
# 형태소 정확도는 100.00%         number:51
# 문장 최종 정확도는57.24%         number:51
# 형태소 최종 정확도는62.89%         number:51
# 한편 이날 출시된 ‘에어팟 프로’는 기존 ‘에어팟’의 셋업 방식을 고스란히 계승했다.애플이 ‘노이즈 캔슬링’ 기능이 탑재된 새로운 디자인의 ‘에어팟 프로’를 공개한 가운데 한국 소비자를 해외 소비자와 차별하고 있다는 지적이 나온다.
# 애플이 '노이즈 캔슬링' 기능이 탑재된 새로운 디자인의 '에어팟 프로'를 공개한 가운데 한국 소비자를 해외 소비자와 차별하고 있다는 지적이 나온다.28일 애플은 공식 자료를 통해 '에어팟 프로'를 30일부터 공식 스토어에서 판매한다고 밝혔다.
# 문장 정확도는 59.09%         number:52
# 형태소 정확도는 67.80%         number:52
# 문장 최종 정확도는57.27%         number:52
# 형태소 최종 정확도는62.99%         number:52
# 애플은 28일(현지시간) 노이즈 캔슬링과 인이어(귀 삽입형) 디자인 등을 갖춘 에어팟 프로를 공개했다.“아이폰11 흥행 잇는다”...애플, 32만원대 ‘에어팟 프로’ 공개
# 아이폰 11 시리즈로 글로벌 흥행을 이어가고 있는 애플이 새로운 프리미엄 무선 이어폰 '에어팟 프로'를 내놨다.애플은 28일 노이즈 캔슬링과 인이어 디자인 등을 갖춘 에어팟 프로를 공개했다.
# 문장 정확도는 43.78%         number:53
# 형태소 정확도는 70.00%         number:53
# 문장 최종 정확도는57.02%         number:53
# 형태소 최종 정확도는63.12%         number:53
